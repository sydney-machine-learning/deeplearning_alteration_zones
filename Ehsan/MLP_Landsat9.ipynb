# %% [markdown]
# ### Libraries

# %%
import contextily as cx
from ipywidgets import interact
from math import floor
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter, MaxNLocator
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy as np
from pyrsgis import raster
from pyrsgis.convert import array_to_table
from pyrsgis.ml import imageChipsFromArray
import random
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.svm import SVC
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model, Sequential

# %% [markdown]
# ### Loading the multispectral image

# %%
# file names
feature_file = './BrokenHill_Landsat9.tif'

# read the image
dsFeatures, arrFeatures = raster.read(feature_file, bands='all')
arrFeatures = arrFeatures.astype(float)
# arrFeatures = np.float16(arrFeatures)

# dsFeatures.__dict__

min_x = dsFeatures.bbox[0][0]
max_x = dsFeatures.bbox[1][0]
min_y = dsFeatures.bbox[0][1]
max_y = dsFeatures.bbox[1][1]

extent = [min_x, max_x, min_y, max_y]

# %% [markdown]
# ### Visualizing spectral bands

# %%
def plot_array_stretched(array, label, n):
    fig, ax = plt.subplots(figsize=(10, 10))
    v_mean = np.array(np.nanmean(array))
    v_std = np.array(np.nanstd(array))
    ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
    plt.yticks(rotation=90, va='center')
    ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
    cb = ax.imshow(array, cmap='Greys_r', extent=extent, vmin=v_mean-(n*v_std), vmax=v_mean+(n*v_std))
    divider = make_axes_locatable(ax)
    cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
    fig.add_axes(cax)
    plt.colorbar(cb, orientation='horizontal', label=label, cax=cax)
    plt.grid(False)
    plt.show()

def plot_array(array, label):
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
    plt.yticks(rotation=90, va='center')
    ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
    cb = ax.imshow(array, cmap='Greys_r', extent=extent)
    divider = make_axes_locatable(ax)
    cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
    fig.add_axes(cax)
    plt.colorbar(cb, orientation='horizontal', label=label, cax=cax)
    plt.grid(False)
    plt.show()

@interact(band=range(1, arrFeatures.shape[0]+1))
def show_dist(band):
    plot_array_stretched(arrFeatures[band-1, :, :], f'Band {band}', 3)
# Out:
# interactive(children=(Dropdown(description='band', options=(1, 2, 3, 4, 5, 6, 7), value=1), Output()), _dom_cl…

# %% [markdown]
# ### Normalizing

# %%
arrFeatures = array_to_table(arrFeatures)
arrFeatures_fuzzy = np.zeros(arrFeatures.shape)

# normalize the image
for i in range(arrFeatures.shape[1]):
    bandMin = arrFeatures[:, i].min()
    bandMax = arrFeatures[:, i].max()
    bandRange = bandMax-bandMin
    for j in range(arrFeatures.shape[0]):
        arrFeatures_fuzzy[j, i] = (arrFeatures[j, i]-bandMin)/bandRange

# %% [markdown]
# ### Loading the training dataset (manual)

# %%
positiveLabel_file = './BrokenHill_Landsat8_Manual_CombinedTraining.tif'
# read and reshape the label file
dsPositiveLabels, arrPositiveLabels = raster.read(positiveLabel_file)
n_class_pos = len(np.unique(arrPositiveLabels))

fig, ax = plt.subplots(figsize=(10, 10))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
plt.yticks(rotation=90, va='center')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
cmap = mpl.colors.ListedColormap(['white', 'blue', 'red'])
image = plt.imshow(arrPositiveLabels, cmap=cmap, extent=extent)
divider = make_axes_locatable(ax)
cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
fig.add_axes(cax)
cbar = plt.colorbar(image, orientation='horizontal', label='Alteration Type', cax=cax)
tick_locs = (np.arange(n_class_pos) + 0.5)*(n_class_pos-1)/n_class_pos
cbar.set_ticks(tick_locs)
cbar.set_ticklabels(['Background', 'Argillic', 'Iron Oxide'])
plt.grid(False)

# %% [markdown]
# ### Generating random samples

# %%
# generate random samples
nonZero_count = np.count_nonzero(arrPositiveLabels)
index = np.transpose(np.where(arrPositiveLabels==0))
index = index.astype(int)
randomIndex = random.sample(range(index.shape[0]), int(nonZero_count/(n_class_pos-1)))
arrNegativeLabels = np.zeros(arrPositiveLabels.shape)

for i in range(len(randomIndex)):
    arrNegativeLabels[index[randomIndex[i], 0], index[randomIndex[i], 1]] = n_class_pos # max value of labels plus one which equals n_class
    
arrPositiveLabels_flat = arrPositiveLabels.flatten()
arrNegativeLabels_flat = arrNegativeLabels.flatten()
# separate and balance the classes
positiveFeatures = arrFeatures_fuzzy[arrPositiveLabels_flat!=0]
positiveLabels = arrPositiveLabels_flat[arrPositiveLabels_flat!=0]
negativeFeatures = arrFeatures_fuzzy[arrNegativeLabels_flat==n_class_pos]
negativeLabels = arrNegativeLabels_flat[arrNegativeLabels_flat==n_class_pos]
# combine the balanced features
features = np.concatenate((positiveFeatures, negativeFeatures), axis=0)
labels = np.concatenate((positiveLabels, negativeLabels), axis=0)
# call the function to split the dataset
train_x, train_y, test_x, test_y = train_test_split(features, labels, train_size=0.7)

# %% [markdown]
# ### Training the model using MLP

# %%
# create the model
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(6, activation='selu', input_shape=(train_x.shape[1], )))
model.add(tf.keras.layers.Dense(5, activation='selu'))
model.add(tf.keras.layers.Dense(4, activation='softmax'))

# print(model.summary())

# run the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
model.fit(train_x, test_x, epochs=80)
# predict for the test dataset
yTestPredicted = model.predict(train_y)
# calculate and display error metrics
yTestPredicted_ = yTestPredicted.argmax(axis=1)

cMatrix = confusion_matrix(test_y, yTestPredicted_)
pScore = precision_score(test_y, yTestPredicted_, average='micro')
rScore = recall_score(test_y, yTestPredicted_, average='micro')
fscore = f1_score(test_y, yTestPredicted_, average='micro')

print("Confusion matrix:\n", cMatrix)
print("\nP-Score: %.3f, R-Score: %.3f, F-Score: %.3f" % (pScore, rScore, fscore))
# Out:
# Epoch 1/80
# 33/33 [==============================] - 1s 2ms/step - loss: 1.2111 - accuracy: 0.3295
# Epoch 2/80
# 33/33 [==============================] - 0s 1ms/step - loss: 1.1517 - accuracy: 0.3343
# Epoch 3/80
# 33/33 [==============================] - 0s 1ms/step - loss: 1.1174 - accuracy: 0.3352
# Epoch 4/80
# 33/33 [==============================] - 0s 1ms/step - loss: 1.0951 - accuracy: 0.3629
# Epoch 5/80
# 33/33 [==============================] - 0s 2ms/step - loss: 1.0768 - accuracy: 0.4410
# Epoch 6/80
# 33/33 [==============================] - 0s 1ms/step - loss: 1.0609 - accuracy: 0.4762
# Epoch 7/80
# 33/33 [==============================] - 0s 1ms/step - loss: 1.0469 - accuracy: 0.4895
# Epoch 8/80
# 33/33 [==============================] - 0s 1ms/step - loss: 1.0356 - accuracy: 0.5619
# Epoch 9/80
# 33/33 [==============================] - 0s 2ms/step - loss: 1.0234 - accuracy: 0.5600
# Epoch 10/80
# 33/33 [==============================] - 0s 1ms/step - loss: 1.0121 - accuracy: 0.6067
# Epoch 11/80
# 33/33 [==============================] - 0s 933us/step - loss: 1.0010 - accuracy: 0.5867
# Epoch 12/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.9910 - accuracy: 0.6286
# Epoch 13/80
# 33/33 [==============================] - 0s 2ms/step - loss: 0.9801 - accuracy: 0.6381
# Epoch 14/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.9663 - accuracy: 0.6505
# Epoch 15/80
# 33/33 [==============================] - 0s 2ms/step - loss: 0.9545 - accuracy: 0.6905
# Epoch 16/80
# 33/33 [==============================] - 0s 2ms/step - loss: 0.9437 - accuracy: 0.6676
# Epoch 17/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.9295 - accuracy: 0.6848
# Epoch 18/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.9195 - accuracy: 0.6943
# Epoch 19/80
# 33/33 [==============================] - 0s 754us/step - loss: 0.9084 - accuracy: 0.6952
# Epoch 20/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.8963 - accuracy: 0.7095
# Epoch 21/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.8828 - accuracy: 0.7229
# Epoch 22/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.8716 - accuracy: 0.6905
# Epoch 23/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.8595 - accuracy: 0.7219
# Epoch 24/80
# 33/33 [==============================] - 0s 2ms/step - loss: 0.8471 - accuracy: 0.7086
# Epoch 25/80
# 33/33 [==============================] - 0s 2ms/step - loss: 0.8364 - accuracy: 0.7162
# Epoch 26/80
# 33/33 [==============================] - 0s 2ms/step - loss: 0.8248 - accuracy: 0.7133
# Epoch 27/80
# 33/33 [==============================] - 0s 2ms/step - loss: 0.8112 - accuracy: 0.7286
# Epoch 28/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.8007 - accuracy: 0.7229
# Epoch 29/80
# 33/33 [==============================] - 0s 2ms/step - loss: 0.7892 - accuracy: 0.7181
# Epoch 30/80
# 33/33 [==============================] - 0s 2ms/step - loss: 0.7811 - accuracy: 0.7305
# Epoch 31/80
# 33/33 [==============================] - 0s 2ms/step - loss: 0.7724 - accuracy: 0.7133
# Epoch 32/80
# 33/33 [==============================] - 0s 847us/step - loss: 0.7644 - accuracy: 0.7257
# Epoch 33/80
# 33/33 [==============================] - 0s 895us/step - loss: 0.7560 - accuracy: 0.7133
# Epoch 34/80
# 33/33 [==============================] - 0s 892us/step - loss: 0.7491 - accuracy: 0.7181
# Epoch 35/80
# 33/33 [==============================] - 0s 548us/step - loss: 0.7410 - accuracy: 0.7248
# Epoch 36/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.7341 - accuracy: 0.7286
# Epoch 37/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.7263 - accuracy: 0.7352
# Epoch 38/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.7216 - accuracy: 0.7295
# Epoch 39/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.7114 - accuracy: 0.7257
# Epoch 40/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.7086 - accuracy: 0.7381
# Epoch 41/80
# 33/33 [==============================] - 0s 650us/step - loss: 0.7018 - accuracy: 0.7390
# Epoch 42/80
# 33/33 [==============================] - 0s 985us/step - loss: 0.6979 - accuracy: 0.7419
# Epoch 43/80
# 33/33 [==============================] - 0s 990us/step - loss: 0.6935 - accuracy: 0.7390
# Epoch 44/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6859 - accuracy: 0.7457
# Epoch 45/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6824 - accuracy: 0.7457
# Epoch 46/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6772 - accuracy: 0.7438
# Epoch 47/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6744 - accuracy: 0.7533
# Epoch 48/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6686 - accuracy: 0.7552
# Epoch 49/80
# 33/33 [==============================] - 0s 751us/step - loss: 0.6673 - accuracy: 0.7438
# Epoch 50/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6617 - accuracy: 0.7562
# Epoch 51/80
# 33/33 [==============================] - 0s 983us/step - loss: 0.6607 - accuracy: 0.7552
# Epoch 52/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6557 - accuracy: 0.7638
# Epoch 53/80
# 33/33 [==============================] - 0s 2ms/step - loss: 0.6528 - accuracy: 0.7638
# Epoch 54/80
# 33/33 [==============================] - 0s 933us/step - loss: 0.6491 - accuracy: 0.7610
# Epoch 55/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6453 - accuracy: 0.7533
# Epoch 56/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6439 - accuracy: 0.7552
# Epoch 57/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6404 - accuracy: 0.7657
# Epoch 58/80
# 33/33 [==============================] - 0s 846us/step - loss: 0.6378 - accuracy: 0.7600
# Epoch 59/80
# 33/33 [==============================] - 0s 953us/step - loss: 0.6317 - accuracy: 0.7562
# Epoch 60/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6287 - accuracy: 0.7667
# Epoch 61/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6285 - accuracy: 0.7657
# Epoch 62/80
# 33/33 [==============================] - 0s 984us/step - loss: 0.6256 - accuracy: 0.7676
# Epoch 63/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6241 - accuracy: 0.7638
# Epoch 64/80
# 33/33 [==============================] - 0s 992us/step - loss: 0.6193 - accuracy: 0.7676
# Epoch 65/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6161 - accuracy: 0.7724
# Epoch 66/80
# 33/33 [==============================] - 0s 993us/step - loss: 0.6129 - accuracy: 0.7695
# Epoch 67/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6116 - accuracy: 0.7724
# Epoch 68/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6080 - accuracy: 0.7724
# Epoch 69/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6080 - accuracy: 0.7686
# Epoch 70/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6039 - accuracy: 0.7752
# Epoch 71/80
# 33/33 [==============================] - 0s 633us/step - loss: 0.6020 - accuracy: 0.7733
# Epoch 72/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6007 - accuracy: 0.7752
# Epoch 73/80
# 33/33 [==============================] - 0s 2ms/step - loss: 0.5933 - accuracy: 0.7790
# Epoch 74/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.5924 - accuracy: 0.7771
# Epoch 75/80
# 33/33 [==============================] - 0s 2ms/step - loss: 0.5889 - accuracy: 0.7800
# Epoch 76/80
# 33/33 [==============================] - 0s 2ms/step - loss: 0.5872 - accuracy: 0.7743
# Epoch 77/80
# 33/33 [==============================] - 0s 2ms/step - loss: 0.5846 - accuracy: 0.7762
# Epoch 78/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.5811 - accuracy: 0.7790
# Epoch 79/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.5797 - accuracy: 0.7790
# Epoch 80/80
# 33/33 [==============================] - 0s 1ms/step - loss: 0.5751 - accuracy: 0.7895
# 15/15 [==============================] - 0s 1ms/step
# Confusion matrix:
#  [[103  37   9]
#  [ 13 131   2]
#  [ 34  17 104]]
#
# P-Score: 0.751, R-Score: 0.751, F-Score: 0.751

# %% [markdown]
# ### Mapping alteration zones

# %%
# load and normalize a new multispectral image
dsPred, arrPred = raster.read('./BrokenHill_Landsat9.tif')
arrPred = arrPred.astype(float)
# arrPred = np.float16(arrPred)
arrPred = array_to_table(arrPred)
arrPred_fuzzy = np.zeros(arrPred.shape)

# normalize the image
for i in range(arrPred.shape[1]):
    bandMin = arrPred[:, i].min()
    bandMax = arrPred[:, i].max()
    bandRange = bandMax-bandMin
    for j in range(arrPred.shape[0]):
        arrPred_fuzzy[j, i] = (arrPred[j, i]-bandMin)/bandRange

# predict and export the probability raster
pred = model.predict(arrPred_fuzzy)
pred_array = np.reshape(pred.argmax(axis=1), (dsPred.RasterYSize, dsPred.RasterXSize))

fig, ax = plt.subplots(figsize=(10, 10))
ax.set_xlim(min_x, max_x)
ax.set_ylim(min_y, max_y)
cx.add_basemap(ax, crs='EPSG:32754', source=cx.providers.Esri.WorldShadedRelief)
ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
plt.yticks(rotation=90, va='center')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
cmap = mpl.colors.ListedColormap(['blue', 'red'])

pred_array_copy = pred_array.copy()
pred_array_copy = pred_array_copy.astype('float')
pred_array_copy[pred_array_copy==3] = float('nan')
image = plt.imshow(pred_array_copy, cmap=cmap, extent=extent)

divider = make_axes_locatable(ax)
cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
fig.add_axes(cax)
cbar = plt.colorbar(image, orientation='horizontal', label='Alteration Type', cax=cax)
tick_locs = (np.arange(n_class_pos-1) + 2.5)*(n_class_pos-2)/(n_class_pos-1)
cbar.set_ticks(tick_locs)
cbar.set_ticklabels(['Argillic', 'Iron Oxide'])
plt.grid(False)

# outFile = './BrokenHill_Landsat8_Manual_MLP_AlterationMap.tif'
# raster.export(pred_array, dsPred, filename=outFile, dtype='float')
# Out:
# 91947/91947 [==============================] - 93s 1ms/step

# %% [markdown]
# ### Training the model using SVM

# %%
model = SVC()
model.fit(train_x, test_x)
# predict for the test dataset
yTestPredicted = model.predict(train_y)
# calculate and display error metrics
cMatrix = confusion_matrix(test_y, yTestPredicted)
pScore = precision_score(test_y, yTestPredicted, average='micro')
rScore = recall_score(test_y, yTestPredicted, average='micro')
fscore = f1_score(test_y, yTestPredicted, average='micro')

print("Confusion matrix:\n", cMatrix)
print("\nP-Score: %.3f, R-Score: %.3f, F-Score: %.3f" % (pScore, rScore, fscore))
# Out:
# Confusion matrix:
#  [[142   2   5]
#  [  0 138   8]
#  [  5  22 128]]
#
# P-Score: 0.907, R-Score: 0.907, F-Score: 0.907

# %% [markdown]
# ### Mapping alteration zones

# %%
# load and normalize a new multispectral image
dsPred, arrPred = raster.read('./BrokenHill_Landsat9.tif')
arrPred = arrPred.astype(float)
# arrPred = np.float16(arrPred)
arrPred = array_to_table(arrPred)
arrPred_fuzzy = np.zeros(arrPred.shape)

# normalize the image
for i in range(arrPred.shape[1]):
    bandMin = arrPred[:, i].min()
    bandMax = arrPred[:, i].max()
    bandRange = bandMax-bandMin
    for j in range(arrPred.shape[0]):
        arrPred_fuzzy[j, i] = (arrPred[j, i]-bandMin)/bandRange

# predict and export the probability raster
pred = model.predict(arrPred_fuzzy)
pred_array = np.reshape(pred, (dsPred.RasterYSize, dsPred.RasterXSize))

fig, ax = plt.subplots(figsize=(10, 10))
ax.set_xlim(min_x, max_x)
ax.set_ylim(min_y, max_y)
cx.add_basemap(ax, crs='EPSG:32754', source=cx.providers.Esri.WorldShadedRelief)
ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
plt.yticks(rotation=90, va='center')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
cmap = mpl.colors.ListedColormap(['blue', 'red'])

pred_array_copy = pred_array.copy()
pred_array_copy = pred_array_copy.astype('float')
pred_array_copy[pred_array_copy==3] = float('nan')
image = plt.imshow(pred_array_copy, cmap=cmap, extent=extent)

divider = make_axes_locatable(ax)
cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
fig.add_axes(cax)
cbar = plt.colorbar(image, orientation='horizontal', label='Alteration Type', cax=cax)
tick_locs = (np.arange(n_class_pos-1) + 2.5)*(n_class_pos-2)/(n_class_pos-1)
cbar.set_ticks(tick_locs)
cbar.set_ticklabels(['Argillic', 'Iron Oxide'])
plt.grid(False)

# outFile = './BrokenHill_Landsat8_Manual_SVM_AlterationMap.tif'
# raster.export(pred_array, dsPred, filename=outFile, dtype='float')

# %% [markdown]
# ### Loading the training dataset (PCA)

# %%
positiveLabel_file = './BrokenHill_Landsat8_PCA_CombinedTraining.tif'
# read and reshape the label file
dsPositiveLabels, arrPositiveLabels = raster.read(positiveLabel_file)
n_class_pos = len(np.unique(arrPositiveLabels))

fig, ax = plt.subplots(figsize=(10, 10))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
plt.yticks(rotation=90, va='center')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
cmap = mpl.colors.ListedColormap(['white', 'blue', 'red'])
image = plt.imshow(arrPositiveLabels, cmap=cmap, extent=extent)
divider = make_axes_locatable(ax)
cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
fig.add_axes(cax)
cbar = plt.colorbar(image, orientation='horizontal', label='Alteration Type', cax=cax)
tick_locs = (np.arange(n_class_pos) + 0.5)*(n_class_pos-1)/n_class_pos
cbar.set_ticks(tick_locs)
cbar.set_ticklabels(['Background', 'Argillic', 'Iron Oxide'])
plt.grid(False)

# %% [markdown]
# ### Generating random samples

# %%
# generate random samples
nonZero_count = np.count_nonzero(arrPositiveLabels)
index = np.transpose(np.where(arrPositiveLabels==0))
index = index.astype(int)
randomIndex = random.sample(range(index.shape[0]), int(nonZero_count/(n_class_pos-1)))
arrNegativeLabels = np.zeros(arrPositiveLabels.shape)

for i in range(len(randomIndex)):
    arrNegativeLabels[index[randomIndex[i], 0], index[randomIndex[i], 1]] = n_class_pos # max value of labels plus one which equals n_class
    
arrPositiveLabels_flat = arrPositiveLabels.flatten()
arrNegativeLabels_flat = arrNegativeLabels.flatten()
# separate and balance the classes
positiveFeatures = arrFeatures_fuzzy[arrPositiveLabels_flat!=0]
positiveLabels = arrPositiveLabels_flat[arrPositiveLabels_flat!=0]
negativeFeatures = arrFeatures_fuzzy[arrNegativeLabels_flat==n_class_pos]
negativeLabels = arrNegativeLabels_flat[arrNegativeLabels_flat==n_class_pos]
# combine the balanced features
features = np.concatenate((positiveFeatures, negativeFeatures), axis=0)
labels = np.concatenate((positiveLabels, negativeLabels), axis=0)
# call the function to split the dataset
train_x, train_y, test_x, test_y = train_test_split(features, labels, train_size=0.7)

# %% [markdown]
# ### Training the model using MLP

# %%
# create the model
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(6, activation='selu', input_shape=(train_x.shape[1], )))
model.add(tf.keras.layers.Dense(5, activation='selu'))
model.add(tf.keras.layers.Dense(4, activation='softmax'))

# print(model.summary())

# run the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
model.fit(train_x, test_x, epochs=40)
# predict for the test dataset
yTestPredicted = model.predict(train_y)
# calculate and display error metrics
yTestPredicted_ = yTestPredicted.argmax(axis=1)

cMatrix = confusion_matrix(test_y, yTestPredicted_)
pScore = precision_score(test_y, yTestPredicted_, average='micro')
rScore = recall_score(test_y, yTestPredicted_, average='micro')
fscore = f1_score(test_y, yTestPredicted_, average='micro')

print("Confusion matrix:\n", cMatrix)
print("\nP-Score: %.3f, R-Score: %.3f, F-Score: %.3f" % (pScore, rScore, fscore))
# Out:
# Epoch 1/40
# 2118/2118 [==============================] - 5s 2ms/step - loss: 0.9739 - accuracy: 0.5200
# Epoch 2/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.8159 - accuracy: 0.6382
# Epoch 3/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.6345 - accuracy: 0.7610
# Epoch 4/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.4975 - accuracy: 0.8158
# Epoch 5/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.4350 - accuracy: 0.8393
# Epoch 6/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.4029 - accuracy: 0.8515
# Epoch 7/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3809 - accuracy: 0.8614
# Epoch 8/40
# 2118/2118 [==============================] - 3s 2ms/step - loss: 0.3665 - accuracy: 0.8677
# Epoch 9/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3547 - accuracy: 0.8750
# Epoch 10/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3450 - accuracy: 0.8790
# Epoch 11/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3371 - accuracy: 0.8841
# Epoch 12/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3299 - accuracy: 0.8882
# Epoch 13/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3239 - accuracy: 0.8915
# Epoch 14/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3187 - accuracy: 0.8937
# Epoch 15/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3138 - accuracy: 0.8956
# Epoch 16/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3119 - accuracy: 0.8978
# Epoch 17/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3091 - accuracy: 0.8976
# Epoch 18/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3077 - accuracy: 0.8982
# Epoch 19/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3068 - accuracy: 0.8990
# Epoch 20/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3059 - accuracy: 0.9008
# Epoch 21/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3052 - accuracy: 0.9003
# Epoch 22/40
# 2118/2118 [==============================] - 3s 2ms/step - loss: 0.3053 - accuracy: 0.9008
# Epoch 23/40
# 2118/2118 [==============================] - 3s 1ms/step - loss: 0.3047 - accuracy: 0.9008
# Epoch 24/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3043 - accuracy: 0.8999
# Epoch 25/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3034 - accuracy: 0.9008
# Epoch 26/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3031 - accuracy: 0.9003
# Epoch 27/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3029 - accuracy: 0.9007
# Epoch 28/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3028 - accuracy: 0.9002
# Epoch 29/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3020 - accuracy: 0.9019
# Epoch 30/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3015 - accuracy: 0.9011
# Epoch 31/40
# 2118/2118 [==============================] - 3s 2ms/step - loss: 0.3012 - accuracy: 0.9011
# Epoch 32/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3010 - accuracy: 0.9016
# Epoch 33/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3006 - accuracy: 0.9022
# Epoch 34/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3001 - accuracy: 0.9018
# Epoch 35/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3000 - accuracy: 0.9016
# Epoch 36/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.2993 - accuracy: 0.9034
# Epoch 37/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.3000 - accuracy: 0.9015
# Epoch 38/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.2997 - accuracy: 0.9015
# Epoch 39/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.2995 - accuracy: 0.9015
# Epoch 40/40
# 2118/2118 [==============================] - 4s 2ms/step - loss: 0.2992 - accuracy: 0.9016
# 908/908 [==============================] - 1s 1ms/step
# Confusion matrix:
#  [[ 5553    85   444]
#  [   57 12215   955]
#  [  400   717  8614]]
#
# P-Score: 0.908, R-Score: 0.908, F-Score: 0.908

# %% [markdown]
# ### Mapping alteration zones

# %%
# load and normalize a new multispectral image
dsPred, arrPred = raster.read('./BrokenHill_Landsat9.tif')
arrPred = arrPred.astype(float)
# arrPred = np.float16(arrPred)
arrPred = array_to_table(arrPred)
arrPred_fuzzy = np.zeros(arrPred.shape)

# normalize the image
for i in range(arrPred.shape[1]):
    bandMin = arrPred[:, i].min()
    bandMax = arrPred[:, i].max()
    bandRange = bandMax-bandMin
    for j in range(arrPred.shape[0]):
        arrPred_fuzzy[j, i] = (arrPred[j, i]-bandMin)/bandRange

# predict and export the probability raster
pred = model.predict(arrPred_fuzzy)
pred_array = np.reshape(pred.argmax(axis=1), (dsPred.RasterYSize, dsPred.RasterXSize))

fig, ax = plt.subplots(figsize=(10, 10))
ax.set_xlim(min_x, max_x)
ax.set_ylim(min_y, max_y)
cx.add_basemap(ax, crs='EPSG:32754', source=cx.providers.Esri.WorldShadedRelief)
ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
plt.yticks(rotation=90, va='center')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
cmap = mpl.colors.ListedColormap(['blue', 'red'])

pred_array_copy = pred_array.copy()
pred_array_copy = pred_array_copy.astype('float')
pred_array_copy[pred_array_copy==3] = float('nan')
image = plt.imshow(pred_array_copy, cmap=cmap, extent=extent)

divider = make_axes_locatable(ax)
cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
fig.add_axes(cax)
cbar = plt.colorbar(image, orientation='horizontal', label='Alteration Type', cax=cax)
tick_locs = (np.arange(n_class_pos-1) + 2.5)*(n_class_pos-2)/(n_class_pos-1)
cbar.set_ticks(tick_locs)
cbar.set_ticklabels(['Argillic', 'Iron Oxide'])
plt.grid(False)

# outFile = './BrokenHill_Landsat8_PCA_MLP_AlterationMap.tif'
# raster.export(pred_array, dsPred, filename=outFile, dtype='float')
# Out:
# 91947/91947 [==============================] - 126s 1ms/step

# %% [markdown]
# ### Training the model using SVM

# %%
model = SVC()
model.fit(train_x, test_x)
# predict for the test dataset
yTestPredicted = model.predict(train_y)
# calculate and display error metrics
cMatrix = confusion_matrix(test_y, yTestPredicted)
pScore = precision_score(test_y, yTestPredicted, average='micro')
rScore = recall_score(test_y, yTestPredicted, average='micro')
fscore = f1_score(test_y, yTestPredicted, average='micro')

print("Confusion matrix:\n", cMatrix)
print("\nP-Score: %.3f, R-Score: %.3f, F-Score: %.3f" % (pScore, rScore, fscore))
# Out:
# Confusion matrix:
#  [[ 5600    90   392]
#  [   23 12680   524]
#  [  422   897  8412]]
#
# P-Score: 0.919, R-Score: 0.919, F-Score: 0.919

# %% [markdown]
# ### Mapping alteration zones

# %%
# load and normalize a new multispectral image
dsPred, arrPred = raster.read('./BrokenHill_Landsat9.tif')
arrPred = arrPred.astype(float)
# arrPred = np.float16(arrPred)
arrPred = array_to_table(arrPred)
arrPred_fuzzy = np.zeros(arrPred.shape)

# normalize the image
for i in range(arrPred.shape[1]):
    bandMin = arrPred[:, i].min()
    bandMax = arrPred[:, i].max()
    bandRange = bandMax-bandMin
    for j in range(arrPred.shape[0]):
        arrPred_fuzzy[j, i] = (arrPred[j, i]-bandMin)/bandRange

# predict and export the probability raster
pred = model.predict(arrPred_fuzzy)
pred_array = np.reshape(pred, (dsPred.RasterYSize, dsPred.RasterXSize))

fig, ax = plt.subplots(figsize=(10, 10))
ax.set_xlim(min_x, max_x)
ax.set_ylim(min_y, max_y)
cx.add_basemap(ax, crs='EPSG:32754', source=cx.providers.Esri.WorldShadedRelief)
ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
plt.yticks(rotation=90, va='center')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
cmap = mpl.colors.ListedColormap(['blue', 'red'])

pred_array_copy = pred_array.copy()
pred_array_copy = pred_array_copy.astype('float')
pred_array_copy[pred_array_copy==3] = float('nan')
image = plt.imshow(pred_array_copy, cmap=cmap, extent=extent)

divider = make_axes_locatable(ax)
cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
fig.add_axes(cax)
cbar = plt.colorbar(image, orientation='horizontal', label='Alteration Type', cax=cax)
tick_locs = (np.arange(n_class_pos-1) + 2.5)*(n_class_pos-2)/(n_class_pos-1)
cbar.set_ticks(tick_locs)
cbar.set_ticklabels(['Argillic', 'Iron Oxide'])
plt.grid(False)

# outFile = './BrokenHill_Landsat8_PCA_SVM_AlterationMap.tif'
# raster.export(pred_array, dsPred, filename=outFile, dtype='float')

# %% [markdown]
# ### Libraries

# %%
import contextily as cx
from ipywidgets import interact
from math import floor
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter, MaxNLocator
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy as np
import pandas as pd
from pyrsgis import raster
from pyrsgis.convert import array_to_table
from pyrsgis.ml import imageChipsFromArray
import random
import seaborn as sns
from sklearn.metrics import accuracy_score, auc, confusion_matrix, f1_score, precision_score, recall_score, roc_auc_score, roc_curve
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.svm import SVC
from statistics import mean
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model, Sequential

# %% [markdown]
# ### Loading the multispectral image

# %%
# file names
feature_file = './BrokenHill_Landsat9.tif'

# read the image
dsFeatures, arrFeatures = raster.read(feature_file, bands='all')
arrFeatures = arrFeatures.astype(float)

min_x = dsFeatures.bbox[0][0]
max_x = dsFeatures.bbox[1][0]
min_y = dsFeatures.bbox[0][1]
max_y = dsFeatures.bbox[1][1]

extent = [min_x, max_x, min_y, max_y]

# %% [markdown]
# ### Visualising spectral bands

# %%
def plot_array_stretched(array, label, n):
    fig, ax = plt.subplots(figsize=(10, 10))
    v_mean = np.array(np.nanmean(array))
    v_std = np.array(np.nanstd(array))
    ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
    plt.yticks(rotation=90, va='center')
    ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
    cb = ax.imshow(array, cmap='Greys_r', extent=extent, vmin=v_mean-(n*v_std), vmax=v_mean+(n*v_std))
    divider = make_axes_locatable(ax)
    cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
    fig.add_axes(cax)
    plt.colorbar(cb, orientation='horizontal', label=label, cax=cax)
    plt.grid(False)
    plt.show()

def plot_array(array, label):
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
    plt.yticks(rotation=90, va='center')
    ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
    cb = ax.imshow(array, cmap='Greys_r', extent=extent)
    divider = make_axes_locatable(ax)
    cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
    fig.add_axes(cax)
    plt.colorbar(cb, orientation='horizontal', label=label, cax=cax)
    plt.grid(False)
    plt.show()

@interact(band=range(1, arrFeatures.shape[0]+1))
def show_dist(band):
    plot_array_stretched(arrFeatures[band-1, :, :], f'Band {band}', 3)
# Out:
# interactive(children=(Dropdown(description='band', options=(1, 2, 3, 4, 5, 6, 7), value=1), Output()), _dom_cl…

# %% [markdown]
# ### Normalising

# %%
arrFeatures = array_to_table(arrFeatures)
arrFeatures_fuzzy = np.zeros(arrFeatures.shape)

# normalise the image
for i in range(arrFeatures.shape[1]):
    bandMin = arrFeatures[:, i].min()
    bandMax = arrFeatures[:, i].max()
    bandRange = bandMax-bandMin
    for j in range(arrFeatures.shape[0]):
        arrFeatures_fuzzy[j, i] = (arrFeatures[j, i]-bandMin)/bandRange

# %% [markdown]
# ### Loading the training dataset (manual)

# %%
positiveLabel_file = './BrokenHill_Landsat8_Manual_CombinedTraining.tif'
# read and reshape the label file
dsPositiveLabels_manual, arrPositiveLabels_manual = raster.read(positiveLabel_file)
n_class_pos = len(np.unique(arrPositiveLabels_manual))

fig, ax = plt.subplots(figsize=(10, 10))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
plt.yticks(rotation=90, va='center')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
cmap = mpl.colors.ListedColormap(['white', 'blue', 'red'])
image = plt.imshow(arrPositiveLabels_manual, cmap=cmap, extent=extent, interpolation='nearest')
divider = make_axes_locatable(ax)
cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
fig.add_axes(cax)
cbar = plt.colorbar(image, orientation='horizontal', label='Alteration Type', cax=cax)
tick_locs = (np.arange(n_class_pos) + 0.5)*(n_class_pos-1)/n_class_pos
cbar.set_ticks(tick_locs)
cbar.set_ticklabels(['Background', 'Argillic', 'Iron Oxide'])
plt.grid(False)

# %% [markdown]
# ### Generating random samples

# %%
# generate random samples
nonZero_count = np.count_nonzero(arrPositiveLabels_manual)
index = np.transpose(np.where(arrPositiveLabels_manual==0))
index = index.astype(int)
randomIndex = random.sample(range(index.shape[0]), int(nonZero_count/(n_class_pos-1)))
arrNegativeLabels = np.zeros(arrPositiveLabels_manual.shape)

for i in range(len(randomIndex)):
    arrNegativeLabels[index[randomIndex[i], 0], index[randomIndex[i], 1]] = n_class_pos # max value of labels plus one which equals n_class
    
arrPositiveLabels_manual_flat = arrPositiveLabels_manual.flatten()
arrNegativeLabels_flat = arrNegativeLabels.flatten()
# separate and balance the classes
positiveFeatures = arrFeatures_fuzzy[arrPositiveLabels_manual_flat!=0]
positiveLabels_manual = arrPositiveLabels_manual_flat[arrPositiveLabels_manual_flat!=0]
negativeFeatures = arrFeatures_fuzzy[arrNegativeLabels_flat==n_class_pos]
negativeLabels = arrNegativeLabels_flat[arrNegativeLabels_flat==n_class_pos]
# combine the balanced features
features = np.concatenate((positiveFeatures, negativeFeatures), axis=0)
labels = np.concatenate((positiveLabels_manual, negativeLabels), axis=0)
labels[labels==n_class_pos] = 0
# call the function to split the dataset
# x: features, y: labels, z: predictions
train_x, test_x, train_y, test_y = train_test_split(features, labels, train_size=0.7)

# %% [markdown]
# ### Training the model using MLP

# %%
def roc_auc(model, test_x, test_y, n_classes):
    roc_auc = []
    test_z = model.predict(test_x)
    test_y_dummies = pd.get_dummies(test_y).values
    
    for i in range(n_classes):
        roc_auc.append(roc_auc_score(test_y_dummies[:, i], test_z[:, i]))
    
    return roc_auc

# plot any graph relating to any model
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics)+1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and Testing '+metric.capitalize())
    plt.xlabel('Epochs')
    plt.ylabel(metric.capitalize())
    plt.legend(['Training '+metric.capitalize(), 'Testing '+metric.capitalize()])
    plt.show()
    
def roc_plot(test_y, test_z, n_classes, labels_name, average='macro'):
    fpr = {}
    tpr = {}
    roc_auc = {}

    test_y_dummies = pd.get_dummies(test_y).values
    
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(test_y_dummies[:, i], test_z[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # roc for each class
    fig, ax = plt.subplots()
    ax.plot([0, 1], [0, 1], 'k--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title('Receiver Operating Characteristic')
    
    for i in range(n_classes):
        ax.plot(fpr[i], tpr[i], label='{}, AUC = {}'.format(labels_name[i], '{0:.4f}'.format(roc_auc[i])))
    
    ax.legend(loc='best')
    ax.grid(alpha=0.5)
    sns.despine()
    plt.show()
    print('ROC AUC score:', roc_auc_score(test_y_dummies, test_z, average=average))

best_model = tf.keras.models.Sequential()
best_accuracy = 0
best_history = None
experimental_runs = 10
cv = 10
metrics_columns = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC_No Alteration', 'AUC_Argillic', 'AUC_Iron Oxide', 'AUC_Aggregate']
temp_metrics_df = pd.DataFrame(np.zeros((cv, len(metrics_columns))), columns=metrics_columns)

for i in range(experimental_runs):
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(5, activation='selu', input_shape=(train_x.shape[1], )))
    model.add(tf.keras.layers.Dense(3, activation='softmax'))

    optimizer = tf.keras.optimizers.Adam(lr=0.01)
    model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    history = model.fit(train_x, train_y, epochs=100, validation_data=(test_x, test_y))
    
    for j in range(cv):
        train_x, test_x, train_y, test_y = train_test_split(features, labels, train_size=0.7)
        # predict for the test dataset
        test_z = model.predict(test_x)
        # calculate and display error metrics
        test_z_class = test_z.argmax(axis=1)
        
        aScore = accuracy_score(test_y, test_z_class)
        pScore = precision_score(test_y, test_z_class, average='macro')
        rScore = recall_score(test_y, test_z_class, average='macro')
        fScore = f1_score(test_y, test_z_class, average='macro')
        cMatrix = confusion_matrix(test_y, test_z_class)
        metrics_array = [aScore, pScore, rScore, fScore]
        roc_auc_class = roc_auc(model, test_x, test_y, n_class_pos)

        for k in range(n_class_pos):
            metrics_array.append(roc_auc_class[k])

        roc_auc_mean = mean(roc_auc_class)
        metrics_array.append(roc_auc_mean)
        temp_metrics_df.loc[j] = metrics_array
        
        if j==cv-1:
            # accuracy can be replaced with other scores
            aScore_avg = temp_metrics_df['Accuracy'].mean()
            
            if best_accuracy < aScore_avg:
                best_model = model
                best_accuracy_avg = aScore_avg
                best_history = history

print(f'\nBest Average Accuracy:\n{best_accuracy_avg}')

test_z = best_model.predict(test_x)
test_z_class = test_z.argmax(axis=1)
aScore = accuracy_score(test_y, test_z_class)
pScore = precision_score(test_y, test_z_class, average='macro')
rScore = recall_score(test_y, test_z_class, average='macro')
fScore = f1_score(test_y, test_z_class, average='macro')
cMatrix = confusion_matrix(test_y, test_z_class)
metrics_array = [aScore, pScore, rScore, fScore]
roc_auc_class = roc_auc(best_model, test_x, test_y, n_class_pos)
metrics_array.extend(roc_auc_class)
roc_auc_mean = mean(roc_auc_class)
metrics_array.append(roc_auc_mean)

print(f'\nConfusion Matrix:\n{cMatrix}')
print(f'\nAccuracy: {aScore}')
print(f'\nPrecision: {pScore}')
print(f'\nRecall: {rScore}')
print(f'\nF1 Score: {fScore}')

plot_metric(history, 'loss')
print('')
plot_metric(history, 'accuracy')
labels_name = ['No Alteration', 'Argillic', 'Iron Oxide']
roc_plot(test_y, test_z, n_class_pos, labels_name)
# Out:
# Epoch 1/100
# 33/33 [==============================] - 1s 6ms/step - loss: 1.0717 - accuracy: 0.4238 - val_loss: 1.0580 - val_accuracy: 0.3511
# Epoch 2/100
# 33/33 [==============================] - 0s 2ms/step - loss: 1.0107 - accuracy: 0.5390 - val_loss: 0.9695 - val_accuracy: 0.6067
# Epoch 3/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.9388 - accuracy: 0.5819 - val_loss: 0.9007 - val_accuracy: 0.5956
# Epoch 4/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.8714 - accuracy: 0.6705 - val_loss: 0.8336 - val_accuracy: 0.7267
# Epoch 5/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.8268 - accuracy: 0.6800 - val_loss: 0.7916 - val_accuracy: 0.6422
# Epoch 6/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.7850 - accuracy: 0.6571 - val_loss: 0.7679 - val_accuracy: 0.6911
# Epoch 7/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.7597 - accuracy: 0.7076 - val_loss: 0.7351 - val_accuracy: 0.7511
# Epoch 8/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.
100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3135 - accuracy: 0.8838 - val_loss: 0.3126 - val_accuracy: 0.8933
# Epoch 42/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3124 - accuracy: 0.8867 - val_loss: 0.3120 - val_accuracy: 0.8956
# Epoch 43/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3147 - accuracy: 0.8886 - val_loss: 0.3060 - val_accuracy: 0.9044
# Epoch 44/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3082 - accuracy: 0.8914 - val_loss: 0.2938 - val_accuracy: 0.9000
# Epoch 45/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3045 - accuracy: 0.8952 - val_loss: 0.3034 - val_accuracy: 0.8933
# Epoch 46/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2924 - accuracy: 0.8895 - val_loss: 0.2831 - val_accuracy: 0.9044
# Epoch 47/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2879 - accuracy: 0.8952 - val_loss: 0.2997 - val_accuracy: 0.9044
# Epoch 48/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2838 - accuracy: 0.8943 - val_loss: 0.2799 - val_accuracy: 0.9089
# Epoch 49/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3000 - accuracy: 0.9019 - val_loss: 0.3215 - val_accuracy: 0.8867
# Epoch 50/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3057 - accuracy: 0.8819 - val_loss: 0.2697 - val_accuracy: 0.9133
# Epoch 51/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2796 - accuracy: 0.9048 - val_loss: 0.2617 - val_accuracy: 0.9178
# Epoch 52/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2764 - accuracy: 0.9029 - val_loss: 0.2635 - val_accuracy: 0.9178
# Epoch 53/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2793 - accuracy: 0.8905 - val_loss: 0.2690 - val_accuracy: 0.9111
# Epoch 54/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2769 - accuracy: 0.8924 - val_loss: 0.2842 - val_accuracy: 0.8889
# Epoch 55/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2685 - accuracy: 0.8943 - val_loss: 0.2793 - val_accuracy: 0.8978
# Epoch 56/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2562 - accuracy: 0.9133 - val_loss: 0.2674 - val_accuracy: 0.9044
# Epoch 57/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2744 - accuracy: 0.9038 - val_loss: 0.2895 - val_accuracy: 0.8867
# Epoch 58/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2629 - accuracy: 0.9076 - val_loss: 0.2438 - val_accuracy: 0.9178
# Epoch 59/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2748 - accuracy: 0.8990 - val_loss: 0.2483 - val_accuracy: 0.9089
# Epoch 60/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2558 - accuracy: 0.9057 - val_loss: 0.2376 - val_accuracy: 0.9200
# Epoch 61/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2465 - accuracy: 0.9076 - val_loss: 0.2481 - val_accuracy: 0.9178
# Epoch 62/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2537 - accuracy: 0.9219 - val_loss: 0.2355 - val_accuracy: 0.9200
# Epoch 63/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2448 - accuracy: 0.9105 - val_loss: 0.2310 - val_accuracy: 0.9200
# Epoch 64/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2416 - accuracy: 0.9114 - val_loss: 0.2443 - val_accuracy: 0.9156
# Epoch 65/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2447 - accuracy: 0.9086 - val_loss: 0.2700 - val_accuracy: 0.9111
# Epoch 66/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2496 - accuracy: 0.9105 - val_loss: 0.2367 - val_accuracy: 0.9178
# Epoch 67/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2384 - accuracy: 0.9143 - val_loss: 0.2441 - val_accuracy: 0.9111
# Epoch 68/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2367 - accuracy: 0.9162 - val_loss: 0.2303 - val_accuracy: 0.9333
# Epoch 69/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2418 - accuracy: 0.9048 - val_loss: 0.2243 - val_accuracy: 0.9200
# Epoch 70/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2361 - accuracy: 0.9086 - val_loss: 0.2255 - val_accuracy: 0.9111
# Epoch 71/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2318 - accuracy: 0.9152 - val_loss: 0.2192 - val_accuracy: 0.9289
# Epoch 72/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.
100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3687 - accuracy: 0.8695 - val_loss: 0.3027 - val_accuracy: 0.9044
# Epoch 32/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3627 - accuracy: 0.8724 - val_loss: 0.2983 - val_accuracy: 0.8956
# Epoch 33/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3718 - accuracy: 0.8667 - val_loss: 0.3073 - val_accuracy: 0.9000
# Epoch 34/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3617 - accuracy: 0.8648 - val_loss: 0.3052 - val_accuracy: 0.8844
# Epoch 35/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3497 - accuracy: 0.8733 - val_loss: 0.2886 - val_accuracy: 0.8956
# Epoch 36/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3415 - accuracy: 0.8752 - val_loss: 0.3369 - val_accuracy: 0.8622
# Epoch 37/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3486 - accuracy: 0.8705 - val_loss: 0.2812 - val_accuracy: 0.9222
# Epoch 38/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3262 - accuracy: 0.8829 - val_loss: 0.2778 - val_accuracy: 0.9111
# Epoch 39/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3175 - accuracy: 0.8876 - val_loss: 0.3035 - val_accuracy: 0.8933
# Epoch 40/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3322 - accuracy: 0.8686 - val_loss: 0.2524 - val_accuracy: 0.9267
# Epoch 41/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3160 - accuracy: 0.8867 - val_loss: 0.2470 - val_accuracy: 0.9200
# Epoch 42/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3105 - accuracy: 0.8886 - val_loss: 0.2448 - val_accuracy: 0.9267
# Epoch 43/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3089 - accuracy: 0.8819 - val_loss: 0.2732 - val_accuracy: 0.9022
# Epoch 44/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3182 - accuracy: 0.8762 - val_loss: 0.2357 - val_accuracy: 0.9222
# Epoch 45/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2992 - accuracy: 0.8867 - val_loss: 0.2475 - val_accuracy: 0.9133
# Epoch 46/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2983 - accuracy: 0.8781 - val_loss: 0.2359 - val_accuracy: 0.9333
# Epoch 47/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2939 - accuracy: 0.8867 - val_loss: 0.2243 - val_accuracy: 0.9244
# Epoch 48/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2911 - accuracy: 0.8867 - val_loss: 0.2426 - val_accuracy: 0.9222
# Epoch 49/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2938 - accuracy: 0.8962 - val_loss: 0.2358 - val_accuracy: 0.9156
# Epoch 50/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3352 - accuracy: 0.8781 - val_loss: 0.2241 - val_accuracy: 0.9267
# Epoch 51/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2962 - accuracy: 0.8886 - val_loss: 0.2846 - val_accuracy: 0.8800
# Epoch 52/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3015 - accuracy: 0.8895 - val_loss: 0.2281 - val_accuracy: 0.9311
# Epoch 53/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2771 - accuracy: 0.8952 - val_loss: 0.2082 - val_accuracy: 0.9467
# Epoch 54/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2933 - accuracy: 0.8981 - val_loss: 0.2798 - val_accuracy: 0.8844
# Epoch 55/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2849 - accuracy: 0.8933 - val_loss: 0.2226 - val_accuracy: 0.9289
# Epoch 56/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2716 - accuracy: 0.9038 - val_loss: 0.2026 - val_accuracy: 0.9511
# Epoch 57/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2688 - accuracy: 0.8895 - val_loss: 0.2183 - val_accuracy: 0.9244
# Epoch 58/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2715 - accuracy: 0.8990 - val_loss: 0.2026 - val_accuracy: 0.9378
# Epoch 59/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2725 - accuracy: 0.8876 - val_loss: 0.2038 - val_accuracy: 0.9378
# Epoch 60/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2782 - accuracy: 0.9000 - val_loss: 0.2066 - val_accuracy: 0.9400
# Epoch 61/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2756 - accuracy: 0.8829 - val_loss: 0.1945 - val_accuracy: 0.9400
# Epoch 62/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2627 - accuracy: 0.8914 - val_loss: 0.1961 - val_accuracy: 0.9444
# Epoch 63/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2727 - accuracy: 0.8971 - val_loss: 0.2325 - val_accuracy: 0.9000
# Epoch 64/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2633 - accuracy: 0.9019 - val_loss: 0.1879 - val_accuracy: 0.9489
# Epoch 65/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2735 - accuracy: 0.9038 - val_loss: 0.1873 - val_accuracy: 0.9422
# Epoch 66/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2556 - accuracy: 0.9057 - val_loss: 0.1985 - val_accuracy: 0.9311
# Epoch 67/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2797 - accuracy: 0.8895 - val_loss: 0.1831 - val_accuracy: 0.9511
# Epoch 68/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2437 - accuracy: 0.9076 - val_loss: 0.1808 - val_accuracy: 0.9511
# Epoch 69/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2494 - accuracy: 0.9010 - val_loss: 0.1841 - val_accuracy: 0.9467
# Epoch 70/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2459 - accuracy: 0.9133 - val_loss: 0.1770 - val_accuracy: 0.9511
# Epoch 71/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2479 - accuracy: 0.9029 - val_loss: 0.2068 - val_accuracy: 0.9222
# Epoch 72/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2475 - accuracy: 0.9124 - val_loss: 0.2155 - val_accuracy: 0.9267
# Epoch 73/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2433 - accuracy: 0.9105 - val_loss: 0.1757 - val_accuracy: 0.9489
# Epoch 74/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2451 - accuracy: 0.9029 - val_loss: 0.1799 - val_accuracy: 0.9422
# Epoch 75/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2448 - accuracy: 0.9076 - val_loss: 0.1834 - val_accuracy: 0.9400
# Epoch 76/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2425 - accuracy: 0.9133 - val_loss: 0.1970 - val_accuracy: 0.9289
# Epoch 77/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2590 - accuracy: 0.9010 - val_loss: 0.1769 - val_accuracy: 0.9422
# Epoch 78/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2474 - accuracy: 0.9057 - val_loss: 0.1681 - val_accuracy: 0.9489
# Epoch 79/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2513 - accuracy: 0.8990 - val_loss: 0.2101 - val_accuracy: 0.9067
# Epoch 80/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2414 - accuracy: 0.9105 - val_loss: 0.1926 - val_accuracy: 0.9333
# Epoch 81/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2472 - accuracy: 0.9095 - val_loss: 0.1899 - val_accuracy: 0.9333
# Epoch 82/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2484 - accuracy: 0.9067 - val_loss: 0.1682 - val_accuracy: 0.9556
# Epoch 83/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2461 - accuracy: 0.9133 - val_loss: 0.1727 - val_accuracy: 0.9444
# Epoch 84/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2272 - accuracy: 0.9143 - val_loss: 0.1646 - val_accuracy: 0.9533
# Epoch 85/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2390 - accuracy: 0.9076 - val_loss: 0.1707 - val_accuracy: 0.9422
# Epoch 86/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2293 - accuracy: 0.9171 - val_loss: 0.1643 - val_accuracy: 0.9511
# Epoch 87/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2306 - accuracy: 0.9124 - val_loss: 0.1760 - val_accuracy: 0.9422
# Epoch 88/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2284 - accuracy: 0.9143 - val_loss: 0.1664 - val_accuracy: 0.9511
# Epoch 89/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2230 - accuracy: 0.9219 - val_loss: 0.1597 - val_accuracy: 0.9511
# Epoch 90/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2201 - accuracy: 0.9171 - val_loss: 0.1713 - val_accuracy: 0.9444
# Epoch 91/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2245 - accuracy: 0.9105 - val_loss: 0.1540 - val_accuracy: 0.9578
# Epoch 92/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2264 - accuracy: 0.9143 - val_loss: 0.1610 - val_accuracy: 0.9556
# Epoch 93/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2458 - accuracy: 0.9114 - val_loss: 0.1673 - val_accuracy: 0.9444
# Epoch 94/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2174 - accuracy: 0.9181 - val_loss: 0.1584 - val_accuracy: 0.9533
# Epoch 95/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2262 - accuracy: 0.9152 - val_loss: 0.1823 - val_accuracy: 0.9289
# Epoch 96/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.
100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2688 - accuracy: 0.8971 - val_loss: 0.3485 - val_accuracy: 0.8756
# Epoch 56/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2663 - accuracy: 0.9000 - val_loss: 0.2887 - val_accuracy: 0.8889
# Epoch 57/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2537 - accuracy: 0.9067 - val_loss: 0.3026 - val_accuracy: 0.8844
# Epoch 58/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2637 - accuracy: 0.9038 - val_loss: 0.2901 - val_accuracy: 0.8911
# Epoch 59/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2457 - accuracy: 0.9105 - val_loss: 0.3062 - val_accuracy: 0.8933
# Epoch 60/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2463 - accuracy: 0.9076 - val_loss: 0.3126 - val_accuracy: 0.8844
# Epoch 61/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2413 - accuracy: 0.9114 - val_loss: 0.3024 - val_accuracy: 0.8911
# Epoch 62/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2629 - accuracy: 0.9029 - val_loss: 0.2834 - val_accuracy: 0.8889
# Epoch 63/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2570 - accuracy: 0.9038 - val_loss: 0.3195 - val_accuracy: 0.8800
# Epoch 64/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2619 - accuracy: 0.9048 - val_loss: 0.2983 - val_accuracy: 0.8889
# Epoch 65/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2381 - accuracy: 0.9152 - val_loss: 0.2591 - val_accuracy: 0.9044
# Epoch 66/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2346 - accuracy: 0.9057 - val_loss: 0.2588 - val_accuracy: 0.9067
# Epoch 67/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2276 - accuracy: 0.9181 - val_loss: 0.2744 - val_accuracy: 0.9044
# Epoch 68/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2416 - accuracy: 0.9114 - val_loss: 0.2539 - val_accuracy: 0.9067
# Epoch 69/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2231 - accuracy: 0.9124 - val_loss: 0.2590 - val_accuracy: 0.9089
# Epoch 70/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2311 - accuracy: 0.9133 - val_loss: 0.2802 - val_accuracy: 0.9000
# Epoch 71/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2362 - accuracy: 0.9162 - val_loss: 0.2898 - val_accuracy: 0.8822
# Epoch 72/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2270 - accuracy: 0.9181 - val_loss: 0.2902 - val_accuracy: 0.9044
# Epoch 73/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2347 - accuracy: 0.9105 - val_loss: 0.2667 - val_accuracy: 0.8956
# Epoch 74/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2196 - accuracy: 0.9133 - val_loss: 0.2676 - val_accuracy: 0.9022
# Epoch 75/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2299 - accuracy: 0.9105 - val_loss: 0.3031 - val_accuracy: 0.8867
# Epoch 76/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2214 - accuracy: 0.9190 - val_loss: 0.2530 - val_accuracy: 0.9178
# Epoch 77/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2130 - accuracy: 0.9248 - val_loss: 0.2617 - val_accuracy: 0.9133
# Epoch 78/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2252 - accuracy: 0.9286 - val_loss: 0.2413 - val_accuracy: 0.9133
# Epoch 79/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2193 - accuracy: 0.9181 - val_loss: 0.2447 - val_accuracy: 0.9156
# Epoch 80/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2134 - accuracy: 0.9190 - val_loss: 0.2592 - val_accuracy: 0.8978
# Epoch 81/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2171 - accuracy: 0.9219 - val_loss: 0.2465 - val_accuracy: 0.9089
# Epoch 82/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2019 - accuracy: 0.9324 - val_loss: 0.2307 - val_accuracy: 0.9222
# Epoch 83/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2164 - accuracy: 0.9210 - val_loss: 0.2288 - val_accuracy: 0.9156
# Epoch 84/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1987 - accuracy: 0.9276 - val_loss: 0.2353 - val_accuracy: 0.9156
# Epoch 85/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1990 - accuracy: 0.9257 - val_loss: 0.2358 - val_accuracy: 0.9200
# Epoch 86/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2146 - accuracy: 0.9238 - val_loss: 0.2297 - val_accuracy: 0.9244
# Epoch 87/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1999 - accuracy: 0.
100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2370 - accuracy: 0.9143 - val_loss: 0.2889 - val_accuracy: 0.8978
# Epoch 60/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2462 - accuracy: 0.9086 - val_loss: 0.2345 - val_accuracy: 0.9133
# Epoch 61/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2394 - accuracy: 0.9181 - val_loss: 0.2415 - val_accuracy: 0.9000
# Epoch 62/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2464 - accuracy: 0.9076 - val_loss: 0.3127 - val_accuracy: 0.8578
# Epoch 63/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2509 - accuracy: 0.9057 - val_loss: 0.2599 - val_accuracy: 0.8933
# Epoch 64/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2319 - accuracy: 0.9171 - val_loss: 0.2627 - val_accuracy: 0.9089
# Epoch 65/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2262 - accuracy: 0.9219 - val_loss: 0.2202 - val_accuracy: 0.9244
# Epoch 66/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2238 - accuracy: 0.9210 - val_loss: 0.2245 - val_accuracy: 0.9200
# Epoch 67/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2271 - accuracy: 0.9190 - val_loss: 0.2184 - val_accuracy: 0.9289
# Epoch 68/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2509 - accuracy: 0.9038 - val_loss: 0.2322 - val_accuracy: 0.9089
# Epoch 69/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2493 - accuracy: 0.9095 - val_loss: 0.2436 - val_accuracy: 0.9156
# Epoch 70/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2302 - accuracy: 0.9181 - val_loss: 0.2308 - val_accuracy: 0.9178
# Epoch 71/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2244 - accuracy: 0.9200 - val_loss: 0.2105 - val_accuracy: 0.9267
# Epoch 72/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2269 - accuracy: 0.9200 - val_loss: 0.3032 - val_accuracy: 0.8822
# Epoch 73/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2157 - accuracy: 0.9190 - val_loss: 0.2106 - val_accuracy: 0.9244
# Epoch 74/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2182 - accuracy: 0.9181 - val_loss: 0.2112 - val_accuracy: 0.9222
# Epoch 75/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2131 - accuracy: 0.9210 - val_loss: 0.2112 - val_accuracy: 0.9222
# Epoch 76/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2127 - accuracy: 0.9219 - val_loss: 0.2568 - val_accuracy: 0.8867
# Epoch 77/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2225 - accuracy: 0.9143 - val_loss: 0.2212 - val_accuracy: 0.9111
# Epoch 78/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2223 - accuracy: 0.9229 - val_loss: 0.2017 - val_accuracy: 0.9311
# Epoch 79/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2114 - accuracy: 0.9267 - val_loss: 0.2027 - val_accuracy: 0.9311
# Epoch 80/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2166 - accuracy: 0.9200 - val_loss: 0.2109 - val_accuracy: 0.9178
# Epoch 81/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2105 - accuracy: 0.9314 - val_loss: 0.2642 - val_accuracy: 0.8844
# Epoch 82/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2260 - accuracy: 0.9124 - val_loss: 0.2248 - val_accuracy: 0.9133
# Epoch 83/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2086 - accuracy: 0.9276 - val_loss: 0.1953 - val_accuracy: 0.9311
# Epoch 84/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2135 - accuracy: 0.9238 - val_loss: 0.1984 - val_accuracy: 0.9267
# Epoch 85/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2084 - accuracy: 0.9305 - val_loss: 0.1982 - val_accuracy: 0.9267
# Epoch 86/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2014 - accuracy: 0.9257 - val_loss: 0.1984 - val_accuracy: 0.9267
# Epoch 87/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2003 - accuracy: 0.9257 - val_loss: 0.1930 - val_accuracy: 0.9333
# Epoch 88/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2022 - accuracy: 0.9257 - val_loss: 0.1918 - val_accuracy: 0.9333
# Epoch 89/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1989 - accuracy: 0.9267 - val_loss: 0.2042 - val_accuracy: 0.9244
# Epoch 90/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2090 - accuracy: 0.9229 - val_loss: 0.1895 - val_accuracy: 0.9289
# Epoch 91/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1954 - accuracy: 0.9333 - val_loss: 0.2125 - val_accuracy: 0.9222
# Epoch 92/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1980 - accuracy: 0.9324 - val_loss: 0.2003 - val_accuracy: 0.9311
# Epoch 93/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2235 - accuracy: 0.9152 - val_loss: 0.2472 - val_accuracy: 0.9044
# Epoch 94/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2144 - accuracy: 0.9248 - val_loss: 0.2301 - val_accuracy: 0.9044
# Epoch 95/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1983 - accuracy: 0.9305 - val_loss: 0.2253 - val_accuracy: 0.9111
# Epoch 96/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1994 - accuracy: 0.9314 - val_loss: 0.2027 - val_accuracy: 0.9222
# Epoch 97/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1891 - accuracy: 0.9305 - val_loss: 0.1844 - val_accuracy: 0.9356
# Epoch 98/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2058 - accuracy: 0.9305 - val_loss: 0.1840 - val_accuracy: 0.9311
# Epoch 99/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1944 - accuracy: 0.9267 - val_loss: 0.2326 - val_accuracy: 0.9200
# Epoch 100/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2351 - accuracy: 0.9076 - val_loss: 0.1829 - val_accuracy: 0.9289
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 572us/step
# 15/15 [==============================] - 0s 622us/step
# 15/15 [==============================] - 0s 631us/step
# 15/15 [==============================] - 0s 712us/step
# 15/15 [==============================] - 0s 714us/step
# 15/15 [==============================] - 0s 362us/step
# 15/15 [==============================] - 0s 671us/step
# 15/15 [==============================] - 0s 714us/step
# 15/15 [==============================] - 0s 857us/step
# 15/15 [==============================] - 0s 680us/step
# 15/15 [==============================] - 0s 640us/step
# 15/15 [==============================] - 0s 861us/step
# 15/15 [==============================] - 0s 714us/step
# 15/15 [==============================] - 0s 526us/step
# 15/15 [==============================] - 0s 652us/step
# 15/15 [==============================] - 0s 742us/step
# 15/15 [==============================] - 0s 714us/step
# 15/15 [==============================] - 0s 857us/step
# 15/15 [==============================] - 0s 525us/step
#
# Best Average Accuracy:
# 0.9335555555555557
# 15/15 [==============================] - 0s 770us/step
# 15/15 [==============================] - 0s 998us/step
#
# Confusion Matrix:
# [[134  10  18]
#  [  0 147   2]
#  [  6   0 133]]
#
# Accuracy: 0.92
#
# Precision: 0.9209098784595225
#
# Recall: 0.9235240691364384
#
# F1 Score: 0.9197201454593752
# ROC AUC score: 0.9881966785547657

# %% [markdown]
# ### Mapping alteration zones

# %%
arrPred_fuzzy = arrFeatures_fuzzy
dsPred = dsFeatures

# predict and export the probability raster
pred = best_model.predict(arrPred_fuzzy)
pred_array = np.reshape(pred.argmax(axis=1), (dsPred.RasterYSize, dsPred.RasterXSize))

fig, ax = plt.subplots(figsize=(10, 10))
ax.set_xlim(min_x, max_x)
ax.set_ylim(min_y, max_y)
cx.add_basemap(ax, crs='EPSG:32754', source=cx.providers.Esri.WorldShadedRelief)
ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
plt.yticks(rotation=90, va='center')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
cmap = mpl.colors.ListedColormap(['blue', 'red'])

pred_array_copy = pred_array.copy()
pred_array_copy = pred_array_copy.astype('float')
pred_array_copy[pred_array_copy==0] = np.nan
image = plt.imshow(pred_array_copy, cmap=cmap, extent=extent, interpolation='nearest')

divider = make_axes_locatable(ax)
cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
fig.add_axes(cax)
cbar = plt.colorbar(image, orientation='horizontal', label='Alteration Type', cax=cax)
tick_locs = (np.arange(n_class_pos-1) + 2.5)*(n_class_pos-2)/(n_class_pos-1)
cbar.set_ticks(tick_locs)
cbar.set_ticklabels(['Argillic', 'Iron Oxide'])
plt.grid(False)

outFile = './Outputs/BrokenHill_Landsat9_Manual_MLP_AlterationMap.tif'
raster.export(pred_array, dsPred, filename=outFile, dtype='float')
# Out:
# 91947/91947 [==============================] - 67s 723us/step

# %% [markdown]
# ### Loading the training dataset (PCA)

# %%
positiveLabel_file = './BrokenHill_Landsat9_PCA_CombinedTraining.tif'
# read and reshape the label file
dsPositiveLabels_pca, arrPositiveLabels_pca = raster.read(positiveLabel_file)
n_class_pos = len(np.unique(arrPositiveLabels_pca))

fig, ax = plt.subplots(figsize=(10, 10))
ax.set_xlim(min_x, max_x)
ax.set_ylim(min_y, max_y)
cx.add_basemap(ax, crs='EPSG:32754', source=cx.providers.Esri.WorldShadedRelief)
ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
plt.yticks(rotation=90, va='center')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
cmap = mpl.colors.ListedColormap(['blue', 'red'])

arrPositiveLabels_pca_copy = arrPositiveLabels_pca.copy()
arrPositiveLabels_pca_copy[arrPositiveLabels_pca_copy==0] = np.nan
image = plt.imshow(arrPositiveLabels_pca_copy, cmap=cmap, extent=extent, interpolation='nearest')

divider = make_axes_locatable(ax)
cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
fig.add_axes(cax)
cbar = plt.colorbar(image, orientation='horizontal', label='Alteration Type', cax=cax)
tick_locs = (np.arange(n_class_pos-1) + 2.5)*(n_class_pos-2)/(n_class_pos-1)
cbar.set_ticks(tick_locs)
cbar.set_ticklabels(['Argillic', 'Iron Oxide'])
plt.grid(False)

# %% [markdown]
# ### Generating random samples

# %%
# generate random samples
nonZero_count = np.count_nonzero(arrPositiveLabels_pca)
index = np.transpose(np.where(arrPositiveLabels_pca==0))
index = index.astype(int)
randomIndex = random.sample(range(index.shape[0]), int(nonZero_count/(n_class_pos-1)))
arrNegativeLabels = np.zeros(arrPositiveLabels_pca.shape)

for i in range(len(randomIndex)):
    arrNegativeLabels[index[randomIndex[i], 0], index[randomIndex[i], 1]] = n_class_pos # max value of labels plus one which equals n_class
    
arrPositiveLabels_pca_flat = arrPositiveLabels_pca.flatten()
arrNegativeLabels_flat = arrNegativeLabels.flatten()
# separate and balance the classes
positiveFeatures = arrFeatures_fuzzy[arrPositiveLabels_pca_flat!=0]
positiveLabels_pca = arrPositiveLabels_pca_flat[arrPositiveLabels_pca_flat!=0]
negativeFeatures = arrFeatures_fuzzy[arrNegativeLabels_flat==n_class_pos]
negativeLabels = arrNegativeLabels_flat[arrNegativeLabels_flat==n_class_pos]
# combine the balanced features
features = np.concatenate((positiveFeatures, negativeFeatures), axis=0)
labels = np.concatenate((positiveLabels_pca, negativeLabels), axis=0)
labels[labels==n_class_pos] = 0
# call the function to split the dataset
train_x, test_x, train_y, test_y = train_test_split(features, labels, train_size=0.7)

# %% [markdown]
# ### Training the model using MLP

# %%
best_model = tf.keras.models.Sequential()
best_accuracy = 0
best_history = None
experimental_runs = 10
cv = 10
metrics_columns = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC_No Alteration', 'AUC_Argillic', 'AUC_Iron Oxide', 'AUC_Aggregate']
temp_metrics_df = pd.DataFrame(np.zeros((cv, len(metrics_columns))), columns=metrics_columns)

for i in range(experimental_runs):
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(5, activation='selu', input_shape=(train_x.shape[1], )))
    model.add(tf.keras.layers.Dense(3, activation='softmax'))

    optimizer = tf.keras.optimizers.Adam(lr=0.01)
    model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    history = model.fit(train_x, train_y, epochs=50, validation_data=(test_x, test_y))
    
    for j in range(cv):
        train_x, test_x, train_y, test_y = train_test_split(features, labels, train_size=0.7)
        # predict for the test dataset
        test_z = model.predict(test_x)
        # calculate and display error metrics
        test_z_class = test_z.argmax(axis=1)

        aScore = accuracy_score(test_y, test_z_class)
        pScore = precision_score(test_y, test_z_class, average='macro')
        rScore = recall_score(test_y, test_z_class, average='macro')
        fScore = f1_score(test_y, test_z_class, average='macro')
        cMatrix = confusion_matrix(test_y, test_z_class)
        metrics_array = [aScore, pScore, rScore, fScore]
        roc_auc_class = roc_auc(model, test_x, test_y, n_class_pos)

        for k in range(n_class_pos):
            metrics_array.append(roc_auc_class[k])

        roc_auc_mean = mean(roc_auc_class)
        metrics_array.append(roc_auc_mean)
        temp_metrics_df.loc[j] = metrics_array
        
        if j==cv-1:
            # accuracy can be replaced with other scores
            aScore_avg = temp_metrics_df['Accuracy'].mean()
            
            if best_accuracy < aScore_avg:
                best_model = model
                best_accuracy_avg = aScore_avg
                best_history = history

print(f'\nBest Average Accuracy:\n{best_accuracy_avg}')

test_z = best_model.predict(test_x)
test_z_class = test_z.argmax(axis=1)
aScore = accuracy_score(test_y, test_z_class)
pScore = precision_score(test_y, test_z_class, average='macro')
rScore = recall_score(test_y, test_z_class, average='macro')
fScore = f1_score(test_y, test_z_class, average='macro')
cMatrix = confusion_matrix(test_y, test_z_class)
metrics_array = [aScore, pScore, rScore, fScore]
roc_auc_class = roc_auc(best_model, test_x, test_y, n_class_pos)
metrics_array.extend(roc_auc_class)
roc_auc_mean = mean(roc_auc_class)
metrics_array.append(roc_auc_mean)

print(f'\nConfusion Matrix:\n{cMatrix}')
print(f'\nAccuracy: {aScore}')
print(f'\nPrecision: {pScore}')
print(f'\nRecall: {rScore}')
print(f'\nF1 Score: {fScore}')

plot_metric(history, 'loss')
print('')
plot_metric(history, 'accuracy')
labels_name = ['No Alteration', 'Argillic', 'Iron Oxide']
roc_plot(test_y, test_z, n_class_pos, labels_name)
# Out:
# Epoch 1/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.5576 - accuracy: 0.7903 - val_loss: 0.2978 - val_accuracy: 0.9098
# Epoch 2/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.2118 - accuracy: 0.9348 - val_loss: 0.1481 - val_accuracy: 0.9613
# Epoch 3/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.1366 - accuracy: 0.9604 - val_loss: 0.1034 - val_accuracy: 0.9694
# Epoch 4/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.1042 - accuracy: 0.9714 - val_loss: 0.0995 - val_accuracy: 0.9707
# Epoch 5/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0908 - accuracy: 0.9757 - val_loss: 0.1116 - val_accuracy: 0.9724
# Epoch 6/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0861 - accuracy: 0.9779 - val_loss: 0.1362 - val_accuracy: 0.9570
# Epoch 7/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0855 - accuracy: 0.9782 - val_loss: 0.0613 - val_accuracy: 0.9844
# Epoch 8/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0798 - accuracy: 0.9801 - val_loss: 0.0584 - val_accuracy: 0.9873
# Epoch 9/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0771 - accuracy: 0.9809 - val_loss: 0.0653 - val_accuracy: 0.9817
# Epoch 10/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0766 - accuracy: 0.9811 - val_loss: 0.0601 - val_accuracy: 0.9825
# Epoch 11/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0750 - accuracy: 0.9819 - val_loss: 0.0738 - val_accuracy: 0.9841
# Epoch 12/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.0750 - accuracy: 0.9817 - val_loss: 0.0912 - val_accuracy: 0.9711
# Epoch 13/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0744 - accuracy: 0.9814 - val_loss: 0.0613 - val_accuracy: 0.9835
# Epoch 14/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.0745 - accuracy: 0.9817 - val_loss: 0.0585 - val_accuracy: 0.9858
# Epoch 15/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.0730 - accuracy: 0.9826 - val_loss: 0.0625 - val_accuracy: 0.9836
# Epoch 16/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0759 - accuracy: 0.9816 - val_loss: 0.0540 - val_accuracy: 0.9857
# Epoch 17/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0733 - accuracy: 0.9831 - val_loss: 0.1457 - val_accuracy: 0.9576
# Epoch 18/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0713 - accuracy: 0.9833 - val_loss: 0.0512 - val_accuracy: 0.9874
# Epoch 19/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0725 - accuracy: 0.9828 - val_loss: 0.0971 - val_accuracy: 0.9710
# Epoch 20/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0746 - accuracy: 0.9817 - val_loss: 0.0861 - val_accuracy: 0.9857
# Epoch 21/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0714 - accuracy: 0.9834 - val_loss: 0.0530 - val_accuracy: 0.9859
# Epoch 22/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0720 - accuracy: 0.9832 - val_loss: 0.1336 - val_accuracy: 0.9651
# Epoch 23/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0701 - accuracy: 0.9836 - val_loss: 0.0484 - val_accuracy: 0.9896
# Epoch 24/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0693 - accuracy: 0.9837 - val_loss: 0.0496 - val_accuracy: 0.9899
# Epoch 25/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0702 - accuracy: 0.9839 - val_loss: 0.0642 - val_accuracy: 0.9838
# Epoch 26/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0724 - accuracy: 0.9832 - val_loss: 0.0616 - val_accuracy: 0.9905
# Epoch 27/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0690 - accuracy: 0.9839 - val_loss: 0.0696 - val_accuracy: 0.9902
# Epoch 28/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0696 - accuracy: 0.9839 - val_loss: 0.0890 - val_accuracy: 0.9729
# Epoch 29/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0727 - accuracy: 0.9831 - val_loss: 0.0922 - val_accuracy: 0.9801
# Epoch 30/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0662 - accuracy: 0.9847 - val_loss: 0.0834 - val_accuracy: 0.9837
# Epoch 31/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0701 - accuracy: 0.9840 - val_loss: 0.0504 - val_accuracy: 0.9898
# Epoch 32/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0676 - accuracy: 0.9839 - val_loss: 0.0794 - val_accuracy: 0.9903
# Epoch 33/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0695 - accuracy: 0.9844 - val_loss: 0.0526 - val_accuracy: 0.9856
# Epoch 34/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0679 - accuracy: 0.9839 - val_loss: 0.0529 - val_accuracy: 0.9854
# Epoch 35/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0692 - accuracy: 0.9840 - val_loss: 0.0708 - val_accuracy: 0.9896
# Epoch 36/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0680 - accuracy: 0.9843 - val_loss: 0.0667 - val_accuracy: 0.9900
# Epoch 37/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0675 - accuracy: 0.9842 - val_loss: 0.2219 - val_accuracy: 0.8907
# Epoch 38/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0688 - accuracy: 0.9840 - val_loss: 0.0544 - val_accuracy: 0.9867
# Epoch 39/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0667 - accuracy: 0.9850 - val_loss: 0.0816 - val_accuracy: 0.9781
# Epoch 40/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0682 - accuracy: 0.9847 - val_loss: 0.0488 - val_accuracy: 0.9882
# Epoch 41/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0682 - accuracy: 0.9844 - val_loss: 0.0599 - val_accuracy: 0.9828
# Epoch 42/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0642 - accuracy: 0.9858 - val_loss: 0.0631 - val_accuracy: 0.9814
# Epoch 43/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0680 - accuracy: 0.9840 - val_loss: 0.0456 - val_accuracy: 0.9893
# Epoch 44/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0671 - accuracy: 0.9845 - val_loss: 0.0881 - val_accuracy: 0.9778
# Epoch 45/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.0663 - accuracy: 0.9848 - val_loss: 0.0472 - val_accuracy: 0.9887
# Epoch 46/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0654 - accuracy: 0.9849 - val_loss: 0.0555 - val_accuracy: 0.9910
# Epoch 47/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0653 - accuracy: 0.9845 - val_loss: 0.0739 - val_accuracy: 0.9876
# Epoch 48/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0649 - accuracy: 0.9850 - val_loss: 0.0454 - val_accuracy: 0.9892
# Epoch 49/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0628 - accuracy: 0.9856 - val_loss: 0.0817 - val_accuracy: 0.9842
# Epoch 50/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0639 - accuracy: 0.9852 - val_loss: 0.0452 - val_accuracy: 0.9906
# 764/764 [==============================] - 1s 710us/step
# 764/764 [==============================] - 1s 727us/step
# 764/764 [==============================] - 1s 712us/step
# 764/764 [==============================] - 1s 699us/step
# 764/764 [==============================] - 1s 723us/step
# 764/764 [==============================] - 1s 708us/step
# 764/764 [==============================] - 1s 698us/step
# 764/764 [==============================] - 1s 700us/step
# 764/764 [==============================] - 1s 715us/step
# 764/764 [==============================] - 1s 699us/step
# 764/764 [==============================] - 1s 699us/step
# 764/764 [==============================] - 1s 702us/step
# 764/764 [==============================] - 1s 713us/step
# 764/764 [==============================] - 1s 735us/step
# 764/764 [==============================] - 1s 738us/step
# 764/764 [==============================] - 1s 878us/step
# 764/764 [==============================] - 1s 789us/step
# 764/764 [==============================] - 1s 790us/step
# 764/764 [==============================] - 1s 788us/step
# 764/764 [==============================] - 1s 788us/step
# Epoch 1/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.5559 - accuracy: 0.8020 - val_loss: 0.2617 - val_accuracy: 0.9194
# Epoch 2/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.1960 - accuracy: 0.9425 - val_loss: 0.1520 - val_accuracy: 0.9603
# Epoch 3/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.1250 - accuracy: 0.9650 - val_loss: 0.0926 - val_accuracy: 0.9735
# Epoch 4/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.1017 - accuracy: 0.9725 - val_loss: 0.1239 - val_accuracy: 0.9698
# Epoch 5/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0936 - accuracy: 0.9745 - val_loss: 0.1192 - val_accuracy: 0.9614
# Epoch 6/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0845 - accuracy: 0.9785 - val_loss: 0.1267 - val_accuracy: 0.9617
# Epoch 7/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.0833 - accuracy: 0.9787 - val_loss: 0.1841 - val_accuracy: 0.9206
# Epoch 8/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0807 - accuracy: 0.9790 - val_loss: 0.0777 - val_accuracy: 0.9880
# Epoch 9/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.
50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0677 - accuracy: 0.9841 - val_loss: 0.0499 - val_accuracy: 0.9888
# Epoch 41/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0628 - accuracy: 0.9851 - val_loss: 0.0540 - val_accuracy: 0.9896
# Epoch 42/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0642 - accuracy: 0.9857 - val_loss: 0.0599 - val_accuracy: 0.9838
# Epoch 43/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0660 - accuracy: 0.9839 - val_loss: 0.0648 - val_accuracy: 0.9830
# Epoch 44/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0652 - accuracy: 0.9849 - val_loss: 0.0507 - val_accuracy: 0.9885
# Epoch 45/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0622 - accuracy: 0.9859 - val_loss: 0.0538 - val_accuracy: 0.9867
# Epoch 46/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0661 - accuracy: 0.9840 - val_loss: 0.0539 - val_accuracy: 0.9865
# Epoch 47/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0619 - accuracy: 0.9855 - val_loss: 0.0668 - val_accuracy: 0.9821
# Epoch 48/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0671 - accuracy: 0.9843 - val_loss: 0.0515 - val_accuracy: 0.9895
# Epoch 49/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0639 - accuracy: 0.9855 - val_loss: 0.0513 - val_accuracy: 0.9912
# Epoch 50/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0632 - accuracy: 0.9856 - val_loss: 0.0699 - val_accuracy: 0.9863
# 764/764 [==============================] - 1s 790us/step
# 764/764 [==============================] - 1s 810us/step
# 764/764 [==============================] - 1s 799us/step
# 764/764 [==============================] - 1s 742us/step
# 764/764 [==============================] - 1s 734us/step
# 764/764 [==============================] - 1s 811us/step
# 764/764 [==============================] - 1s 877us/step
# 764/764 [==============================] - 1s 822us/step
# 764/764 [==============================] - 1s 786us/step
# 764/764 [==============================] - 1s 787us/step
# 764/764 [==============================] - 1s 770us/step
# 764/764 [==============================] - 1s 801us/step
# 764/764 [==============================] - 1s 792us/step
# 764/764 [==============================] - 1s 787us/step
# 764/764 [==============================] - 1s 797us/step
# 764/764 [==============================] - 1s 805us/step
# 764/764 [==============================] - 1s 765us/step
# 764/764 [==============================] - 1s 783us/step
# 764/764 [==============================] - 1s 892us/step
# 764/764 [==============================] - 1s 701us/step
# Epoch 1/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.5490 - accuracy: 0.8032 - val_loss: 0.2866 - val_accuracy: 0.9162
# Epoch 2/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.2186 - accuracy: 0.9328 - val_loss: 0.1678 - val_accuracy: 0.9508
# Epoch 3/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.1377 - accuracy: 0.9594 - val_loss: 0.1035 - val_accuracy: 0.9681
# Epoch 4/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.1057 - accuracy: 0.9710 - val_loss: 0.2108 - val_accuracy: 0.9311
# Epoch 5/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0950 - accuracy: 0.9741 - val_loss: 0.0740 - val_accuracy: 0.9801
# Epoch 6/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0882 - accuracy: 0.9765 - val_loss: 0.1219 - val_accuracy: 0.9618
# Epoch 7/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0826 - accuracy: 0.9786 - val_loss: 0.0683 - val_accuracy: 0.9849
# Epoch 8/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0790 - accuracy: 0.9793 - val_loss: 0.0836 - val_accuracy: 0.9757
# Epoch 9/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0783 - accuracy: 0.9800 - val_loss: 0.0781 - val_accuracy: 0.9881
# Epoch 10/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0785 - accuracy: 0.9797 - val_loss: 0.0744 - val_accuracy: 0.9816
# Epoch 11/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0795 - accuracy: 0.9786 - val_loss: 0.1125 - val_accuracy: 0.9667
# Epoch 12/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.
50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0655 - accuracy: 0.9849 - val_loss: 0.0586 - val_accuracy: 0.9852
# Epoch 44/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0672 - accuracy: 0.9846 - val_loss: 0.0598 - val_accuracy: 0.9843
# Epoch 45/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0642 - accuracy: 0.9846 - val_loss: 0.0693 - val_accuracy: 0.9849
# Epoch 46/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0673 - accuracy: 0.9840 - val_loss: 0.0632 - val_accuracy: 0.9891
# Epoch 47/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0654 - accuracy: 0.9845 - val_loss: 0.0680 - val_accuracy: 0.9878
# Epoch 48/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0666 - accuracy: 0.9844 - val_loss: 0.0618 - val_accuracy: 0.9882
# Epoch 49/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0660 - accuracy: 0.9845 - val_loss: 0.0524 - val_accuracy: 0.9869
# Epoch 50/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0639 - accuracy: 0.9850 - val_loss: 0.0573 - val_accuracy: 0.9851
# 764/764 [==============================] - 1s 793us/step
# 764/764 [==============================] - 1s 752us/step
# 764/764 [==============================] - 1s 704us/step
# 764/764 [==============================] - 1s 731us/step
# 764/764 [==============================] - 1s 689us/step
# 764/764 [==============================] - 1s 711us/step
# 764/764 [==============================] - 1s 687us/step
# 764/764 [==============================] - 1s 703us/step
# 764/764 [==============================] - 1s 696us/step
# 764/764 [==============================] - 1s 708us/step
# 764/764 [==============================] - 1s 677us/step
# 764/764 [==============================] - 1s 699us/step
# 764/764 [==============================] - 1s 690us/step
# 764/764 [==============================] - 1s 686us/step
# 764/764 [==============================] - 1s 677us/step
# 764/764 [==============================] - 1s 711us/step
# 764/764 [==============================] - 1s 690us/step
# 764/764 [==============================] - 1s 696us/step
# 764/764 [==============================] - 1s 676us/step
# 764/764 [==============================] - 1s 702us/step
# Epoch 1/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.5629 - accuracy: 0.7922 - val_loss: 0.2592 - val_accuracy: 0.9238
# Epoch 2/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.2022 - accuracy: 0.9397 - val_loss: 0.1589 - val_accuracy: 0.9517
# Epoch 3/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.1308 - accuracy: 0.9618 - val_loss: 0.0959 - val_accuracy: 0.9739
# Epoch 4/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.1047 - accuracy: 0.9711 - val_loss: 0.0855 - val_accuracy: 0.9730
# Epoch 5/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0913 - accuracy: 0.9761 - val_loss: 0.0719 - val_accuracy: 0.9783
# Epoch 6/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0863 - accuracy: 0.9776 - val_loss: 0.0731 - val_accuracy: 0.9788
# Epoch 7/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0803 - accuracy: 0.9799 - val_loss: 0.0976 - val_accuracy: 0.9800
# Epoch 8/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0781 - accuracy: 0.9801 - val_loss: 0.0584 - val_accuracy: 0.9851
# Epoch 9/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0758 - accuracy: 0.9814 - val_loss: 0.1180 - val_accuracy: 0.9767
# Epoch 10/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0780 - accuracy: 0.9806 - val_loss: 0.0731 - val_accuracy: 0.9870
# Epoch 11/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0741 - accuracy: 0.9816 - val_loss: 0.0720 - val_accuracy: 0.9788
# Epoch 12/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0764 - accuracy: 0.9813 - val_loss: 0.0705 - val_accuracy: 0.9801
# Epoch 13/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0729 - accuracy: 0.9819 - val_loss: 0.0610 - val_accuracy: 0.9818
# Epoch 14/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0705 - accuracy: 0.9832 - val_loss: 0.0539 - val_accuracy: 0.9879
# Epoch 15/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0723 - accuracy: 0.9827 - val_loss: 0.0593 - val_accuracy: 0.9898
# Epoch 16/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0719 - accuracy: 0.9824 - val_loss: 0.0757 - val_accuracy: 0.9785
# Epoch 17/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0690 - accuracy: 0.9832 - val_loss: 0.0606 - val_accuracy: 0.9897
# Epoch 18/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0697 - accuracy: 0.9830 - val_loss: 0.0670 - val_accuracy: 0.9860
# Epoch 19/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0679 - accuracy: 0.9837 - val_loss: 0.0494 - val_accuracy: 0.9877
# Epoch 20/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0680 - accuracy: 0.9833 - val_loss: 0.0519 - val_accuracy: 0.9860
# Epoch 21/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0676 - accuracy: 0.9835 - val_loss: 0.0520 - val_accuracy: 0.9862
# Epoch 22/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0643 - accuracy: 0.9846 - val_loss: 0.0653 - val_accuracy: 0.9895
# Epoch 23/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0675 - accuracy: 0.9833 - val_loss: 0.0498 - val_accuracy: 0.9872
# Epoch 24/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0634 - accuracy: 0.9836 - val_loss: 0.1279 - val_accuracy: 0.9699
# Epoch 25/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0613 - accuracy: 0.9845 - val_loss: 0.0533 - val_accuracy: 0.9878
# Epoch 26/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0607 - accuracy: 0.9851 - val_loss: 0.0480 - val_accuracy: 0.9878
# Epoch 27/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0613 - accuracy: 0.9837 - val_loss: 0.0648 - val_accuracy: 0.9904
# Epoch 28/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0580 - accuracy: 0.9850 - val_loss: 0.0467 - val_accuracy: 0.9904
# Epoch 29/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0555 - accuracy: 0.9854 - val_loss: 0.0946 - val_accuracy: 0.9781
# Epoch 30/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0572 - accuracy: 0.9849 - val_loss: 0.0424 - val_accuracy: 0.9904
# Epoch 31/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0572 - accuracy: 0.9847 - val_loss: 0.0406 - val_accuracy: 0.9895
# Epoch 32/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0564 - accuracy: 0.9850 - val_loss: 0.0757 - val_accuracy: 0.9839
# Epoch 33/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0574 - accuracy: 0.9843 - val_loss: 0.0436 - val_accuracy: 0.9906
# Epoch 34/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0537 - accuracy: 0.9857 - val_loss: 0.1083 - val_accuracy: 0.9694
# Epoch 35/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0568 - accuracy: 0.9851 - val_loss: 0.1350 - val_accuracy: 0.9407
# Epoch 36/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0541 - accuracy: 0.9853 - val_loss: 0.0393 - val_accuracy: 0.9899
# Epoch 37/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0525 - accuracy: 0.9857 - val_loss: 0.0479 - val_accuracy: 0.9861
# Epoch 38/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0542 - accuracy: 0.9852 - val_loss: 0.0647 - val_accuracy: 0.9803
# Epoch 39/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0565 - accuracy: 0.9844 - val_loss: 0.0414 - val_accuracy: 0.9911
# Epoch 40/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0498 - accuracy: 0.9864 - val_loss: 0.0437 - val_accuracy: 0.9877
# Epoch 41/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0477 - accuracy: 0.9872 - val_loss: 0.0795 - val_accuracy: 0.9796
# Epoch 42/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0500 - accuracy: 0.9864 - val_loss: 0.0441 - val_accuracy: 0.9872
# Epoch 43/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0500 - accuracy: 0.9866 - val_loss: 0.0606 - val_accuracy: 0.9816
# Epoch 44/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0508 - accuracy: 0.9861 - val_loss: 0.1737 - val_accuracy: 0.9550
# Epoch 45/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0505 - accuracy: 0.9857 - val_loss: 0.0497 - val_accuracy: 0.9862
# Epoch 46/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0519 - accuracy: 0.9850 - val_loss: 0.0399 - val_accuracy: 0.9882
# Epoch 47/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0475 - accuracy: 0.9860 - val_loss: 0.0858 - val_accuracy: 0.9754
# Epoch 48/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0513 - accuracy: 0.9857 - val_loss: 0.0717 - val_accuracy: 0.9862
# Epoch 49/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0464 - accuracy: 0.9867 - val_loss: 0.0386 - val_accuracy: 0.9918
# Epoch 50/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0481 - accuracy: 0.9863 - val_loss: 0.0431 - val_accuracy: 0.9881
# 764/764 [==============================] - 1s 703us/step
# 764/764 [==============================] - 1s 706us/step
# 764/764 [==============================] - 1s 681us/step
# 764/764 [==============================] - 1s 830us/step
# 764/764 [==============================] - 1s 800us/step
# 764/764 [==============================] - 1s 796us/step
# 764/764 [==============================] - 1s 827us/step
# 764/764 [==============================] - 1s 844us/step
# 764/764 [==============================] - 1s 840us/step
# 764/764 [==============================] - 1s 751us/step
# 764/764 [==============================] - 1s 769us/step
# 764/764 [==============================] - 1s 685us/step
# 764/764 [==============================] - 1s 688us/step
# 764/764 [==============================] - 1s 724us/step
# 764/764 [==============================] - 1s 718us/step
# 764/764 [==============================] - 1s 816us/step
# 764/764 [==============================] - 1s 839us/step
# 764/764 [==============================] - 1s 750us/step
# 764/764 [==============================] - 1s 755us/step
# 764/764 [==============================] - 1s 845us/step
# Epoch 1/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.5017 - accuracy: 0.8266 - val_loss: 0.2566 - val_accuracy: 0.9311
# Epoch 2/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.2025 - accuracy: 0.9389 - val_loss: 0.1510 - val_accuracy: 0.9518
# Epoch 3/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.1393 - accuracy: 0.9583 - val_loss: 0.1092 - val_accuracy: 0.9724
# Epoch 4/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.1058 - accuracy: 0.9704 - val_loss: 0.1297 - val_accuracy: 0.9595
# Epoch 5/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0949 - accuracy: 0.9735 - val_loss: 0.1226 - val_accuracy: 0.9746
# Epoch 6/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0876 - accuracy: 0.9759 - val_loss: 0.0700 - val_accuracy: 0.9845
# Epoch 7/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0853 - accuracy: 0.9768 - val_loss: 0.0996 - val_accuracy: 0.9792
# Epoch 8/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0777 - accuracy: 0.9794 - val_loss: 0.0602 - val_accuracy: 0.9863
# Epoch 9/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0766 - accuracy: 0.9797 - val_loss: 0.0628 - val_accuracy: 0.9876
# Epoch 10/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0731 - accuracy: 0.9813 - val_loss: 0.0820 - val_accuracy: 0.9751
# Epoch 11/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.0724 - accuracy: 0.9808 - val_loss: 0.0626 - val_accuracy: 0.9886
# Epoch 12/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.0691 - accuracy: 0.9820 - val_loss: 0.0558 - val_accuracy: 0.9846
# Epoch 13/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.0689 - accuracy: 0.9816 - val_loss: 0.0563 - val_accuracy: 0.9861
# Epoch 14/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0680 - accuracy: 0.9812 - val_loss: 0.0555 - val_accuracy: 0.9870
# Epoch 15/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0621 - accuracy: 0.9835 - val_loss: 0.1048 - val_accuracy: 0.9694
# Epoch 16/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0630 - accuracy: 0.9827 - val_loss: 0.0506 - val_accuracy: 0.9870
# Epoch 17/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0635 - accuracy: 0.9823 - val_loss: 0.0603 - val_accuracy: 0.9833
# Epoch 18/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0588 - accuracy: 0.9839 - val_loss: 0.0810 - val_accuracy: 0.9772
# Epoch 19/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0628 - accuracy: 0.9828 - val_loss: 0.0464 - val_accuracy: 0.9907
# Epoch 20/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0579 - accuracy: 0.9836 - val_loss: 0.0664 - val_accuracy: 0.9857
# Epoch 21/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0566 - accuracy: 0.9841 - val_loss: 0.0492 - val_accuracy: 0.9913
# Epoch 22/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0576 - accuracy: 0.9840 - val_loss: 0.0531 - val_accuracy: 0.9903
# Epoch 23/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0562 - accuracy: 0.9845 - val_loss: 0.0588 - val_accuracy: 0.9825
# Epoch 24/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0541 - accuracy: 0.9840 - val_loss: 0.0667 - val_accuracy: 0.9825
# Epoch 25/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0537 - accuracy: 0.9846 - val_loss: 0.0622 - val_accuracy: 0.9818
# Epoch 26/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0552 - accuracy: 0.9840 - val_loss: 0.0555 - val_accuracy: 0.9870
# Epoch 27/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0508 - accuracy: 0.9854 - val_loss: 0.0834 - val_accuracy: 0.9777
# Epoch 28/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0539 - accuracy: 0.9845 - val_loss: 0.0674 - val_accuracy: 0.9905
# Epoch 29/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0548 - accuracy: 0.9841 - val_loss: 0.0522 - val_accuracy: 0.9856
# Epoch 30/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0501 - accuracy: 0.9860 - val_loss: 0.0670 - val_accuracy: 0.9831
# Epoch 31/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0518 - accuracy: 0.9851 - val_loss: 0.0393 - val_accuracy: 0.9899
# Epoch 32/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0525 - accuracy: 0.9848 - val_loss: 0.0625 - val_accuracy: 0.9839
# Epoch 33/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0508 - accuracy: 0.9853 - val_loss: 0.0460 - val_accuracy: 0.9913
# Epoch 34/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0505 - accuracy: 0.9854 - val_loss: 0.1049 - val_accuracy: 0.9716
# Epoch 35/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0509 - accuracy: 0.9854 - val_loss: 0.0487 - val_accuracy: 0.9862
# Epoch 36/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.0524 - accuracy: 0.9846 - val_loss: 0.1196 - val_accuracy: 0.9684
# Epoch 37/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.0491 - accuracy: 0.9862 - val_loss: 0.0497 - val_accuracy: 0.9866
# Epoch 38/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.0503 - accuracy: 0.9850 - val_loss: 0.0540 - val_accuracy: 0.9893
# Epoch 39/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0500 - accuracy: 0.9860 - val_loss: 0.0581 - val_accuracy: 0.9843
# Epoch 40/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0476 - accuracy: 0.9869 - val_loss: 0.0435 - val_accuracy: 0.9881
# Epoch 41/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0467 - accuracy: 0.9868 - val_loss: 0.0575 - val_accuracy: 0.9873
# Epoch 42/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0497 - accuracy: 0.9859 - val_loss: 0.0423 - val_accuracy: 0.9929
# Epoch 43/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.0472 - accuracy: 0.9867 - val_loss: 0.0401 - val_accuracy: 0.9922
# Epoch 44/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0452 - accuracy: 0.9873 - val_loss: 0.1336 - val_accuracy: 0.9651
# Epoch 45/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0507 - accuracy: 0.9857 - val_loss: 0.0426 - val_accuracy: 0.9887
# Epoch 46/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0461 - accuracy: 0.9866 - val_loss: 0.1099 - val_accuracy: 0.9724
# Epoch 47/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0505 - accuracy: 0.9859 - val_loss: 0.0523 - val_accuracy: 0.9854
# Epoch 48/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0464 - accuracy: 0.9867 - val_loss: 0.0388 - val_accuracy: 0.9915
# Epoch 49/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0479 - accuracy: 0.9863 - val_loss: 0.0543 - val_accuracy: 0.9859
# Epoch 50/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0480 - accuracy: 0.9861 - val_loss: 0.0414 - val_accuracy: 0.9910
# 764/764 [==============================] - 1s 675us/step
# 764/764 [==============================] - 1s 701us/step
# 764/764 [==============================] - 1s 675us/step
# 764/764 [==============================] - 1s 692us/step
# 764/764 [==============================] - 1s 708us/step
# 764/764 [==============================] - 1s 730us/step
# 764/764 [==============================] - 1s 676us/step
# 764/764 [==============================] - 1s 702us/step
# 764/764 [==============================] - 1s 694us/step
# 764/764 [==============================] - 1s 885us/step
# 764/764 [==============================] - 1s 757us/step
# 764/764 [==============================] - 1s 779us/step
# 764/764 [==============================] - 1s 696us/step
# 764/764 [==============================] - 1s 703us/step
# 764/764 [==============================] - 1s 693us/step
# 764/764 [==============================] - 1s 692us/step
# 764/764 [==============================] - 1s 687us/step
# 764/764 [==============================] - 1s 686us/step
# 764/764 [==============================] - 1s 703us/step
# 764/764 [==============================] - 1s 674us/step
# Epoch 1/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.5703 - accuracy: 0.7838 - val_loss: 0.2763 - val_accuracy: 0.9049
# Epoch 2/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.1895 - accuracy: 0.9433 - val_loss: 0.1758 - val_accuracy: 0.9599
# Epoch 3/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.1255 - accuracy: 0.9644 - val_loss: 0.2232 - val_accuracy: 0.9261
# Epoch 4/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.1025 - accuracy: 0.9715 - val_loss: 0.0843 - val_accuracy: 0.9807
# Epoch 5/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0903 - accuracy: 0.9751 - val_loss: 0.0727 - val_accuracy: 0.9807
# Epoch 6/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0832 - accuracy: 0.9779 - val_loss: 0.1025 - val_accuracy: 0.9660
# Epoch 7/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0790 - accuracy: 0.9790 - val_loss: 0.0712 - val_accuracy: 0.9790
# Epoch 8/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0751 - accuracy: 0.9807 - val_loss: 0.0597 - val_accuracy: 0.9863
# Epoch 9/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0718 - accuracy: 0.9812 - val_loss: 0.0693 - val_accuracy: 0.9842
# Epoch 10/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0692 - accuracy: 0.9824 - val_loss: 0.0721 - val_accuracy: 0.9866
# Epoch 11/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0715 - accuracy: 0.9816 - val_loss: 0.0585 - val_accuracy: 0.9837
# Epoch 12/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0700 - accuracy: 0.9820 - val_loss: 0.0525 - val_accuracy: 0.9863
# Epoch 13/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0671 - accuracy: 0.9828 - val_loss: 0.1273 - val_accuracy: 0.9597
# Epoch 14/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0689 - accuracy: 0.9815 - val_loss: 0.0559 - val_accuracy: 0.9841
# Epoch 15/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0684 - accuracy: 0.9814 - val_loss: 0.0719 - val_accuracy: 0.9808
# Epoch 16/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0632 - accuracy: 0.9835 - val_loss: 0.0503 - val_accuracy: 0.9893
# Epoch 17/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0595 - accuracy: 0.9845 - val_loss: 0.1066 - val_accuracy: 0.9667
# Epoch 18/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0626 - accuracy: 0.9836 - val_loss: 0.0644 - val_accuracy: 0.9823
# Epoch 19/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0600 - accuracy: 0.9839 - val_loss: 0.0601 - val_accuracy: 0.9834
# Epoch 20/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0559 - accuracy: 0.9852 - val_loss: 0.1221 - val_accuracy: 0.9622
# Epoch 21/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0629 - accuracy: 0.9834 - val_loss: 0.0455 - val_accuracy: 0.9888
# Epoch 22/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0576 - accuracy: 0.9847 - val_loss: 0.0516 - val_accuracy: 0.9889
# Epoch 23/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0559 - accuracy: 0.9849 - val_loss: 0.0530 - val_accuracy: 0.9865
# Epoch 24/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0563 - accuracy: 0.9845 - val_loss: 0.0790 - val_accuracy: 0.9838
# Epoch 25/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0594 - accuracy: 0.9836 - val_loss: 0.0589 - val_accuracy: 0.9902
# Epoch 26/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0546 - accuracy: 0.9850 - val_loss: 0.0624 - val_accuracy: 0.9811
# Epoch 27/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0531 - accuracy: 0.9854 - val_loss: 0.0642 - val_accuracy: 0.9882
# Epoch 28/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0572 - accuracy: 0.9840 - val_loss: 0.1100 - val_accuracy: 0.9566
# Epoch 29/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0577 - accuracy: 0.9838 - val_loss: 0.0645 - val_accuracy: 0.9873
# Epoch 30/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0517 - accuracy: 0.9859 - val_loss: 0.0532 - val_accuracy: 0.9858
# Epoch 31/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.0522 - accuracy: 0.9856 - val_loss: 0.0471 - val_accuracy: 0.9870
# Epoch 32/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.0500 - accuracy: 0.9865 - val_loss: 0.0449 - val_accuracy: 0.9922
# Epoch 33/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.0502 - accuracy: 0.9861 - val_loss: 0.0475 - val_accuracy: 0.9889
# Epoch 34/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0518 - accuracy: 0.9856 - val_loss: 0.0452 - val_accuracy: 0.9867
# Epoch 35/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0495 - accuracy: 0.9862 - val_loss: 0.0632 - val_accuracy: 0.9894
# Epoch 36/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0513 - accuracy: 0.9854 - val_loss: 0.0793 - val_accuracy: 0.9825
# Epoch 37/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0514 - accuracy: 0.9855 - val_loss: 0.0459 - val_accuracy: 0.9860
# Epoch 38/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0504 - accuracy: 0.9854 - val_loss: 0.0374 - val_accuracy: 0.9909
# Epoch 39/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0503 - accuracy: 0.9856 - val_loss: 0.0572 - val_accuracy: 0.9898
# Epoch 40/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0470 - accuracy: 0.9871 - val_loss: 0.1026 - val_accuracy: 0.9749
# Epoch 41/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0526 - accuracy: 0.9853 - val_loss: 0.1053 - val_accuracy: 0.9706
# Epoch 42/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0454 - accuracy: 0.9873 - val_loss: 0.0549 - val_accuracy: 0.9840
# Epoch 43/50
# ...
# Epoch 9/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0776 - accuracy: 0.9803 - val_loss: 0.0598 - val_accuracy: 0.9862
# Epoch 10/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0753 - accuracy: 0.9820 - val_loss: 0.0597 - val_accuracy: 0.9852
# Epoch 11/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0787 - accuracy: 0.9804 - val_loss: 0.0609 - val_accuracy: 0.9895
# Epoch 12/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0744 - accuracy: 0.9810 - val_loss: 0.0911 - val_accuracy: 0.9728
# Epoch 13/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0719 - accuracy: 0.9828 - val_loss: 0.0832 - val_accuracy: 0.9785
# Epoch 14/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0703 - accuracy: 0.9833 - val_loss: 0.0836 - val_accuracy: 0.9790
# Epoch 15/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0760 - accuracy: 0.9812 - val_loss: 0.0837 - val_accuracy: 0.9763
# Epoch 16/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0705 - accuracy: 0.9829 - val_loss: 0.0766 - val_accuracy: 0.9775
# Epoch 17/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0727 - accuracy: 0.9820 - val_loss: 0.0622 - val_accuracy: 0.9855
# Epoch 18/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0730 - accuracy: 0.9830 - val_loss: 0.0544 - val_accuracy: 0.9885
# Epoch 19/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0743 - accuracy: 0.9824 - val_loss: 0.0645 - val_accuracy: 0.9840
# Epoch 20/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.0688 - accuracy: 0.9833 - val_loss: 0.0591 - val_accuracy: 0.9915
# Epoch 21/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.0705 - accuracy: 0.9830 - val_loss: 0.0564 - val_accuracy: 0.9891
# Epoch 22/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0692 - accuracy: 0.9839 - val_loss: 0.0569 - val_accuracy: 0.9863
# Epoch 23/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0720 - accuracy: 0.9829 - val_loss: 0.0696 - val_accuracy: 0.9848
# Epoch 24/50
# 1781/1781 [==============================] - 3s 2ms/step - loss: 0.0654 - accuracy: 0.9848 - val_loss: 0.0993 - val_accuracy: 0.9730
# Epoch 25/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0711 - accuracy: 0.9831 - val_loss: 0.0557 - val_accuracy: 0.9905
# Epoch 26/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0692 - accuracy: 0.9838 - val_loss: 0.0633 - val_accuracy: 0.9827
# Epoch 27/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0690 - accuracy: 0.9839 - val_loss: 0.0592 - val_accuracy: 0.9858
# Epoch 28/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0678 - accuracy: 0.9843 - val_loss: 0.0786 - val_accuracy: 0.9799
# Epoch 29/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0687 - accuracy: 0.9846 - val_loss: 0.0580 - val_accuracy: 0.9898
# Epoch 30/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0703 - accuracy: 0.9833 - val_loss: 0.0643 - val_accuracy: 0.9904
# Epoch 31/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0669 - accuracy: 0.9844 - val_loss: 0.0542 - val_accuracy: 0.9871
# Epoch 32/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0656 - accuracy: 0.9848 - val_loss: 0.0662 - val_accuracy: 0.9882
# Epoch 33/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0722 - accuracy: 0.9827 - val_loss: 0.0550 - val_accuracy: 0.9866
# Epoch 34/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0668 - accuracy: 0.9848 - val_loss: 0.0565 - val_accuracy: 0.9874
# Epoch 35/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0666 - accuracy: 0.9846 - val_loss: 0.0531 - val_accuracy: 0.9885
# Epoch 36/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0662 - accuracy: 0.9848 - val_loss: 0.0700 - val_accuracy: 0.9870
# Epoch 37/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0643 - accuracy: 0.9858 - val_loss: 0.0952 - val_accuracy: 0.9767
# Epoch 38/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0630 - accuracy: 0.9859 - val_loss: 0.0591 - val_accuracy: 0.9839
# Epoch 39/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0652 - accuracy: 0.9856 - val_loss: 0.0605 - val_accuracy: 0.9864
# Epoch 40/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0653 - accuracy: 0.9858 - val_loss: 0.0928 - val_accuracy: 0.9786
# Epoch 41/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0644 - accuracy: 0.9855 - val_loss: 0.0548 - val_accuracy: 0.9889
# Epoch 42/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0668 - accuracy: 0.9851 - val_loss: 0.0706 - val_accuracy: 0.9804
# Epoch 43/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0654 - accuracy: 0.9849 - val_loss: 0.0805 - val_accuracy: 0.9812
# Epoch 44/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0633 - accuracy: 0.9855 - val_loss: 0.0509 - val_accuracy: 0.9914
# Epoch 45/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0662 - accuracy: 0.9845 - val_loss: 0.0771 - val_accuracy: 0.9855
# Epoch 46/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0634 - accuracy: 0.9857 - val_loss: 0.0552 - val_accuracy: 0.9924
# Epoch 47/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0677 - accuracy: 0.9845 - val_loss: 0.0684 - val_accuracy: 0.9810
# Epoch 48/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0641 - accuracy: 0.9854 - val_loss: 0.1348 - val_accuracy: 0.9499
# Epoch 49/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0645 - accuracy: 0.9855 - val_loss: 0.0682 - val_accuracy: 0.9845
# Epoch 50/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0655 - accuracy: 0.9852 - val_loss: 0.0781 - val_accuracy: 0.9891
# 764/764 [==============================] - 1s 683us/step
# 764/764 [==============================] - 1s 648us/step
# 764/764 [==============================] - 1s 661us/step
# 764/764 [==============================] - 1s 669us/step
# 764/764 [==============================] - 1s 680us/step
# 764/764 [==============================] - 1s 693us/step
# 764/764 [==============================] - 1s 690us/step
# 764/764 [==============================] - 1s 767us/step
# 764/764 [==============================] - 1s 756us/step
# 764/764 [==============================] - 1s 709us/step
# 764/764 [==============================] - 1s 700us/step
# 764/764 [==============================] - 1s 673us/step
# 764/764 [==============================] - 1s 667us/step
# 764/764 [==============================] - 1s 667us/step
# 764/764 [==============================] - 1s 683us/step
# 764/764 [==============================] - 1s 713us/step
# 764/764 [==============================] - 1s 685us/step
# 764/764 [==============================] - 1s 681us/step
# 764/764 [==============================] - 1s 763us/step
# 764/764 [==============================] - 1s 674us/step
# Epoch 1/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.5398 - accuracy: 0.8137 - val_loss: 0.2426 - val_accuracy: 0.9418
# Epoch 2/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.1753 - accuracy: 0.9508 - val_loss: 0.1152 - val_accuracy: 0.9749
# Epoch 3/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.1168 - accuracy: 0.9684 - val_loss: 0.1412 - val_accuracy: 0.9630
# Epoch 4/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0996 - accuracy: 0.9738 - val_loss: 0.0702 - val_accuracy: 0.9815
# Epoch 5/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0901 - accuracy: 0.9770 - val_loss: 0.0792 - val_accuracy: 0.9757
# Epoch 6/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0862 - accuracy: 0.9779 - val_loss: 0.0735 - val_accuracy: 0.9799
# Epoch 7/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0817 - accuracy: 0.9797 - val_loss: 0.0615 - val_accuracy: 0.9852
# Epoch 8/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0809 - accuracy: 0.9799 - val_loss: 0.0708 - val_accuracy: 0.9827
# Epoch 9/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0817 - accuracy: 0.9796 - val_loss: 0.0790 - val_accuracy: 0.9865
# Epoch 10/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0792 - accuracy: 0.9805 - val_loss: 0.0615 - val_accuracy: 0.9853
# Epoch 11/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0799 - accuracy: 0.9805 - val_loss: 0.0573 - val_accuracy: 0.9857
# Epoch 12/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0779 - accuracy: 0.9810 - val_loss: 0.1238 - val_accuracy: 0.9636
# Epoch 13/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0781 - accuracy: 0.9806 - val_loss: 0.0699 - val_accuracy: 0.9860
# Epoch 14/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0746 - accuracy: 0.9820 - val_loss: 0.0553 - val_accuracy: 0.9893
# Epoch 15/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0754 - accuracy: 0.9816 - val_loss: 0.0545 - val_accuracy: 0.9892
# Epoch 16/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0739 - accuracy: 0.9818 - val_loss: 0.0533 - val_accuracy: 0.9850
# Epoch 17/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0734 - accuracy: 0.9819 - val_loss: 0.0622 - val_accuracy: 0.9869
# Epoch 18/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0683 - accuracy: 0.9832 - val_loss: 0.0779 - val_accuracy: 0.9762
# Epoch 19/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0710 - accuracy: 0.9823 - val_loss: 0.0779 - val_accuracy: 0.9763
# Epoch 20/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0730 - accuracy: 0.9818 - val_loss: 0.0542 - val_accuracy: 0.9900
# Epoch 21/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0678 - accuracy: 0.9835 - val_loss: 0.1267 - val_accuracy: 0.9698
# Epoch 22/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0656 - accuracy: 0.9841 - val_loss: 0.0482 - val_accuracy: 0.9903
# Epoch 23/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0650 - accuracy: 0.9840 - val_loss: 0.0530 - val_accuracy: 0.9850
# Epoch 24/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0690 - accuracy: 0.9824 - val_loss: 0.0471 - val_accuracy: 0.9865
# Epoch 25/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0663 - accuracy: 0.9834 - val_loss: 0.0822 - val_accuracy: 0.9802
# Epoch 26/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0635 - accuracy: 0.9838 - val_loss: 0.0513 - val_accuracy: 0.9856
# Epoch 27/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0656 - accuracy: 0.9832 - val_loss: 0.0519 - val_accuracy: 0.9910
# Epoch 28/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0659 - accuracy: 0.9836 - val_loss: 0.0507 - val_accuracy: 0.9856
# Epoch 29/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0625 - accuracy: 0.9843 - val_loss: 0.0464 - val_accuracy: 0.9867
# Epoch 30/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0622 - accuracy: 0.9843 - val_loss: 0.0410 - val_accuracy: 0.9885
# Epoch 31/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0628 - accuracy: 0.9840 - val_loss: 0.2415 - val_accuracy: 0.9341
# Epoch 32/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0604 - accuracy: 0.9851 - val_loss: 0.0464 - val_accuracy: 0.9858
# Epoch 33/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0577 - accuracy: 0.9851 - val_loss: 0.0566 - val_accuracy: 0.9874
# Epoch 34/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0599 - accuracy: 0.9848 - val_loss: 0.0420 - val_accuracy: 0.9868
# Epoch 35/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0607 - accuracy: 0.9840 - val_loss: 0.0529 - val_accuracy: 0.9917
# Epoch 36/50
# 1781/1781 [==============================] - 3s 1ms/step - loss: 0.0591 - accuracy: 0.9849 - val_loss: 0.0421 - val_accuracy: 0.9873
# Epoch 37/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0607 - accuracy: 0.9843 - val_loss: 0.0528 - val_accuracy: 0.9876
# Epoch 38/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0594 - accuracy: 0.9850 - val_loss: 0.0508 - val_accuracy: 0.9838
# Epoch 39/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0573 - accuracy: 0.9848 - val_loss: 0.0482 - val_accuracy: 0.9837
# Epoch 40/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0555 - accuracy: 0.9857 - val_loss: 0.0383 - val_accuracy: 0.9894
# Epoch 41/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0554 - accuracy: 0.9860 - val_loss: 0.0418 - val_accuracy: 0.9911
# Epoch 42/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0573 - accuracy: 0.9850 - val_loss: 0.0347 - val_accuracy: 0.9908
# Epoch 43/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0550 - accuracy: 0.9860 - val_loss: 0.0722 - val_accuracy: 0.9836
# Epoch 44/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0547 - accuracy: 0.9859 - val_loss: 0.0345 - val_accuracy: 0.9907
# Epoch 45/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0540 - accuracy: 0.9859 - val_loss: 0.1208 - val_accuracy: 0.9677
# Epoch 46/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0546 - accuracy: 0.9855 - val_loss: 0.0627 - val_accuracy: 0.9810
# Epoch 47/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0539 - accuracy: 0.9857 - val_loss: 0.0378 - val_accuracy: 0.9911
# Epoch 48/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0523 - accuracy: 0.9861 - val_loss: 0.0429 - val_accuracy: 0.9907
# Epoch 49/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0530 - accuracy: 0.9866 - val_loss: 0.0586 - val_accuracy: 0.9869
# Epoch 50/50
# 1781/1781 [==============================] - 2s 1ms/step - loss: 0.0544 - accuracy: 0.9856 - val_loss: 0.0360 - val_accuracy: 0.9880
# 764/764 [==============================] - 1s 807us/step
# 764/764 [==============================] - 1s 666us/step
# 764/764 [==============================] - 0s 614us/step
# 764/764 [==============================] - 0s 621us/step
# 764/764 [==============================] - 1s 656us/step
# 764/764 [==============================] - 1s 651us/step
# 764/764 [==============================] - 1s 631us/step
# 764/764 [==============================] - 0s 627us/step
# 764/764 [==============================] - 1s 645us/step
# 764/764 [==============================] - 0s 623us/step
# 764/764 [==============================] - 0s 626us/step
# 764/764 [==============================] - 1s 633us/step
# 764/764 [==============================] - 0s 622us/step
# 764/764 [==============================] - 1s 678us/step
# 764/764 [==============================] - 1s 654us/step
# 764/764 [==============================] - 1s 659us/step
# 764/764 [==============================] - 1s 689us/step
# 764/764 [==============================] - 0s 609us/step
# 764/764 [==============================] - 0s 618us/step
# 764/764 [==============================] - 0s 592us/step
#
# Best Average Accuracy:
# 0.9879919728058318
# 764/764 [==============================] - 0s 592us/step
# 764/764 [==============================] - 0s 635us/step
#
# Confusion Matrix:
# [[7773   87  199]
#  [   0 8091    2]
#  [  20    0 8245]]
#
# Accuracy: 0.9873858377360036
#
# Precision: 0.9876656828958986
#
# Recall: 0.987281585387819
#
# F1 Score: 0.987333921924565
# ROC AUC score: 0.9993135235845605

# %% [markdown]
# ### Mapping alteration zones

# %%
arrPred_fuzzy = arrFeatures_fuzzy
dsPred = dsFeatures

# predict and export the probability raster
pred = best_model.predict(arrPred_fuzzy)
pred_array = np.reshape(pred.argmax(axis=1), (dsPred.RasterYSize, dsPred.RasterXSize))

fig, ax = plt.subplots(figsize=(10, 10))
ax.set_xlim(min_x, max_x)
ax.set_ylim(min_y, max_y)
cx.add_basemap(ax, crs='EPSG:32754', source=cx.providers.Esri.WorldShadedRelief)
ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
plt.yticks(rotation=90, va='center')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
cmap = mpl.colors.ListedColormap(['blue', 'red'])

pred_array_copy = pred_array.copy()
pred_array_copy = pred_array_copy.astype('float')
pred_array_copy[pred_array_copy==0] = np.nan
image = plt.imshow(pred_array_copy, cmap=cmap, extent=extent, interpolation='nearest')

divider = make_axes_locatable(ax)
cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
fig.add_axes(cax)
cbar = plt.colorbar(image, orientation='horizontal', label='Alteration Type', cax=cax)
tick_locs = (np.arange(n_class_pos-1) + 2.5)*(n_class_pos-2)/(n_class_pos-1)
cbar.set_ticks(tick_locs)
cbar.set_ticklabels(['Argillic', 'Iron Oxide'])
plt.grid(False)

outFile = './Outputs/BrokenHill_Landsat9_PCA_MLP_AlterationMap.tif'
raster.export(pred_array, dsPred, filename=outFile, dtype='float')
# Out:
# 91947/91947 [==============================] - 57s 624us/step

# %%
pred_manual = pred.argmax(axis=1)[arrPositiveLabels_manual_flat!=0]
aScore = accuracy_score(positiveLabels_manual, pred_manual)
print(f'Accuracy based on ground truth data: {aScore}')
# Out:
# Accuracy based on ground truth data: 0.833

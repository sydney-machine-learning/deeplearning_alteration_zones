# %% [markdown]
# ### Libraries

# %%
import contextily as cx
from ipywidgets import interact
from math import floor
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter, MaxNLocator
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy as np
import pandas as pd
from pyrsgis import raster
from pyrsgis.ml import imageChipsFromArray
import random
import seaborn as sns
from sklearn.metrics import accuracy_score, auc, confusion_matrix, f1_score, precision_score, recall_score, roc_auc_score, roc_curve
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from statistics import mean
import tensorflow as tf

# %% [markdown]
# ### Loading the multispectral image

# %%
# file names
feature_file = './BrokenHill_ASTER.tif'

# read the image
dsFeatures, arrFeatures = raster.read(feature_file, bands='all')
arrFeatures = np.float16(arrFeatures)

min_x = dsFeatures.bbox[0][0]
max_x = dsFeatures.bbox[1][0]
min_y = dsFeatures.bbox[0][1]
max_y = dsFeatures.bbox[1][1]

extent = [min_x, max_x, min_y, max_y]

# %% [markdown]
# ### Visualising spectral bands

# %%
def plot_array_stretched(array, label, n):
    fig, ax = plt.subplots(figsize=(10, 10))
    v_mean = np.array(np.nanmean(array))
    v_std = np.array(np.nanstd(array))
    ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
    plt.yticks(rotation=90, va='center')
    ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
    cb = ax.imshow(array, cmap='Greys_r', extent=extent, vmin=v_mean-(n*v_std), vmax=v_mean+(n*v_std))
    divider = make_axes_locatable(ax)
    cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
    fig.add_axes(cax)
    plt.colorbar(cb, orientation='horizontal', label=label, cax=cax)
    plt.grid(False)
    plt.show()

def plot_array(array, label):
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
    plt.yticks(rotation=90, va='center')
    ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
    cb = ax.imshow(array, cmap='Greys_r', extent=extent)
    divider = make_axes_locatable(ax)
    cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
    fig.add_axes(cax)
    plt.colorbar(cb, orientation='horizontal', label=label, cax=cax)
    plt.grid(False)
    plt.show()

@interact(band=range(1, arrFeatures.shape[0]+1))
def show_dist(band):
    plot_array(arrFeatures[band-1, :, :], f'Band {band}')
# Out:
# interactive(children=(Dropdown(description='band', options=(1, 2, 3, 4, 5, 6, 7, 8, 9), value=1), Output()), _…

# %% [markdown]
# ### Generating chips

# %%
# normalise the image and generate chips
arrFeatures_fuzzy = np.zeros(arrFeatures.shape)

for i in range(arrFeatures.shape[0]):
    bandMin = arrFeatures[i, :, :].min()
    bandMax = arrFeatures[i, :, :].max()
    bandRange = bandMax-bandMin
    for j in range(arrFeatures.shape[1]):
        for k in range(arrFeatures.shape[2]):
            arrFeatures_fuzzy[i, j, k] = (arrFeatures[i, j, k]-bandMin)/bandRange

# create chips using pyrsgis
features_chips = imageChipsFromArray(arrFeatures_fuzzy, x_size=5, y_size=5)

# %% [markdown]
# ### Loading the training dataset (manual)

# %%
positiveLabel_file = './BrokenHill_ASTER_Manual_CombinedTraining.tif'
# read and reshape the label file
dsPositiveLabels_manual, arrPositiveLabels_manual = raster.read(positiveLabel_file)
n_class_pos = len(np.unique(arrPositiveLabels_manual))

fig, ax = plt.subplots(figsize=(10, 10))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
plt.yticks(rotation=90, va='center')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
cmap = mpl.colors.ListedColormap(['white', 'blue', 'green'])
image = plt.imshow(arrPositiveLabels_manual, cmap=cmap, extent=extent, interpolation='nearest')
divider = make_axes_locatable(ax)
cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
fig.add_axes(cax)
cbar = plt.colorbar(image, orientation='horizontal', label='Alteration Type', cax=cax)
tick_locs = (np.arange(n_class_pos) + 0.5)*(n_class_pos-1)/n_class_pos
cbar.set_ticks(tick_locs)
cbar.set_ticklabels(['Background', 'Argillic', 'Propylitic'])
plt.grid(False)

# %% [markdown]
# ### Generating random samples

# %%
# generate random samples
nonZero_count = np.count_nonzero(arrPositiveLabels_manual)
index = np.transpose(np.where(arrPositiveLabels_manual==0))
index = index.astype(int)
randomIndex = random.sample(range(index.shape[0]), int(nonZero_count/(n_class_pos-1)))
arrNegativeLabels = np.zeros(arrPositiveLabels_manual.shape)

for i in range(len(randomIndex)):
    arrNegativeLabels[index[randomIndex[i], 0], index[randomIndex[i], 1]] = n_class_pos # max value of labels plus one which equals n_class
    
arrPositiveLabels_manual_flat = arrPositiveLabels_manual.flatten()
arrNegativeLabels_flat = arrNegativeLabels.flatten()
# separate and balance the classes
positiveFeatures = features_chips[arrPositiveLabels_manual_flat!=0]
positiveLabels_manual = arrPositiveLabels_manual_flat[arrPositiveLabels_manual_flat!=0]
negativeFeatures = features_chips[arrNegativeLabels_flat==n_class_pos]
negativeLabels = arrNegativeLabels_flat[arrNegativeLabels_flat==n_class_pos]
# combine the balanced features
features = np.concatenate((positiveFeatures, negativeFeatures), axis=0)
labels = np.concatenate((positiveLabels_manual, negativeLabels), axis=0)
labels[labels==n_class_pos] = 0

# %% [markdown]
# ### Splitting features and labels into training and test datasets

# %%
# define a function to split features and labels
def train_test_split(features, labels, trainProp=0.7):
    dataSize = features.shape[0]
    sliceIndex = int(dataSize*trainProp)
    randIndex = np.arange(dataSize)
    random.shuffle(randIndex)
    train_x = features[[randIndex[:sliceIndex]], :, :, :][0]
    test_x = features[[randIndex[sliceIndex:]], :, :, :][0]
    train_y = labels[randIndex[:sliceIndex]]
    test_y = labels[randIndex[sliceIndex:]]
    return(train_x, train_y, test_x, test_y)

# call the function to split the dataset
train_x, train_y, test_x, test_y = train_test_split(features, labels)

# %% [markdown]
# ### Training the model

# %%
def roc_auc(model, test_x, test_y, n_classes):
    roc_auc = []
    test_z = model.predict(test_x)
    test_y_dummies = pd.get_dummies(test_y).values
    
    for i in range(n_classes):
        roc_auc.append(roc_auc_score(test_y_dummies[:, i], test_z[:, i]))
    
    return roc_auc

# plot any graph relating to any model
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics)+1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and Testing '+metric.capitalize())
    plt.xlabel('Epochs')
    plt.ylabel(metric.capitalize())
    plt.legend(['Training '+metric.capitalize(), 'Testing '+metric.capitalize()])
    plt.show()
    
def roc_plot(test_y, test_z, n_classes, labels_name, average='macro'):
    fpr = {}
    tpr = {}
    roc_auc = {}

    test_y_dummies = pd.get_dummies(test_y).values
    
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(test_y_dummies[:, i], test_z[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # roc for each class
    fig, ax = plt.subplots()
    ax.plot([0, 1], [0, 1], 'k--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title('Receiver Operating Characteristic')
    
    for i in range(n_classes):
        ax.plot(fpr[i], tpr[i], label='{}, AUC = {}'.format(labels_name[i], '{0:.4f}'.format(roc_auc[i])))
    
    ax.legend(loc='best')
    ax.grid(alpha=0.5)
    sns.despine()
    plt.show()
    print('ROC AUC score:', roc_auc_score(test_y_dummies, test_z, average=average))

best_model = tf.keras.models.Sequential()
best_accuracy = 0
best_history = None
experimental_runs = 10
cv = 10
metrics_columns = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC_No Alteration', 'AUC_Argillic', 'AUC_Propylitic', 'AUC_Aggregate']
temp_metrics_df = pd.DataFrame(np.zeros((cv, len(metrics_columns))), columns=metrics_columns)

for i in range(experimental_runs):
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Conv2D(32, kernel_size=1, padding='valid', activation='relu', input_shape=(train_x.shape[1], train_x.shape[2], train_x.shape[3])))
    model.add(tf.keras.layers.Dropout(0.25))
    model.add(tf.keras.layers.Conv2D(48, kernel_size=1, padding='valid', activation='relu'))
    model.add(tf.keras.layers.Dropout(0.25))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(64, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(3, activation='softmax'))

    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(train_x, train_y, epochs=100, validation_data=(test_x, test_y))

    for j in range(cv):
        train_x, train_y, test_x, test_y = train_test_split(features, labels)
        # predict for the test dataset
        test_z = model.predict(test_x)
        # calculate and display error metrics
        test_z_class = test_z.argmax(axis=1)

        aScore = accuracy_score(test_y, test_z_class)
        pScore = precision_score(test_y, test_z_class, average='macro')
        rScore = recall_score(test_y, test_z_class, average='macro')
        fScore = f1_score(test_y, test_z_class, average='macro')
        cMatrix = confusion_matrix(test_y, test_z_class)
        metrics_array = [aScore, pScore, rScore, fScore]
        roc_auc_class = roc_auc(model, test_x, test_y, n_class_pos)

        for k in range(n_class_pos):
            metrics_array.append(roc_auc_class[k])

        roc_auc_mean = mean(roc_auc_class)
        metrics_array.append(roc_auc_mean)
        temp_metrics_df.loc[j] = metrics_array
        
        if j==cv-1:
            # accuracy can be replaced with other scores
            aScore_avg = temp_metrics_df['Accuracy'].mean()
            
            if best_accuracy < aScore_avg:
                best_model = model
                best_accuracy_avg = aScore_avg
                best_history = history

print(f'\nBest Average Accuracy:\n{best_accuracy_avg}')

test_z = best_model.predict(test_x)
test_z_class = test_z.argmax(axis=1)
aScore = accuracy_score(test_y, test_z_class)
pScore = precision_score(test_y, test_z_class, average='macro')
rScore = recall_score(test_y, test_z_class, average='macro')
fScore = f1_score(test_y, test_z_class, average='macro')
cMatrix = confusion_matrix(test_y, test_z_class)
metrics_array = [aScore, pScore, rScore, fScore]
roc_auc_class = roc_auc(best_model, test_x, test_y, n_class_pos)
metrics_array.extend(roc_auc_class)
roc_auc_mean = mean(roc_auc_class)
metrics_array.append(roc_auc_mean)

print(f'\nConfusion Matrix:\n{cMatrix}')
print(f'\nAccuracy: {aScore}')
print(f'\nPrecision: {pScore}')
print(f'\nRecall: {rScore}')
print(f'\nF1 Score: {fScore}')

plot_metric(history, 'loss')
print('')
plot_metric(history, 'accuracy')
labels_name = ['No Alteration', 'Argillic', 'Propylitic']
roc_plot(test_y, test_z, n_class_pos, labels_name)
# Out:
# Epoch 1/100
# 134/134 [==============================] - 1s 3ms/step - loss: 0.8663 - accuracy: 0.5754 - val_loss: 0.5204 - val_accuracy: 0.7783
# Epoch 2/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.5098 - accuracy: 0.7889 - val_loss: 0.3567 - val_accuracy: 0.8730
# Epoch 3/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.3820 - accuracy: 0.8586 - val_loss: 0.2733 - val_accuracy: 0.8955
# Epoch 4/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.2616 - accuracy: 0.9064 - val_loss: 0.1863 - val_accuracy: 0.9371
# Epoch 5/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.2142 - accuracy: 0.9268 - val_loss: 0.1443 - val_accuracy: 0.9464
# Epoch 6/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1836 - accuracy: 0.9338 - val_loss: 0.1337 - val_accuracy: 0.9502
# Epoch 7/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1994 - accuracy: 0.9303 - val_loss: 0.1325 - val_accuracy: 0.9535
# Epoch 8/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1610 - accuracy: 0.9500 - val_loss: 0.1099 - val_accuracy: 0.9611
# Epoch 9/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1663 - accuracy: 0.9442 - val_loss: 0.1010 - val_accuracy: 0.9650
# Epoch 10/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1389 - accuracy: 0.9564 - val_loss: 0.1685 - val_accuracy: 0.9398
# Epoch 11/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1513 - accuracy: 0.9545 - val_loss: 0.1330 - val_accuracy: 0.9551
# Epoch 12/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1469 - accuracy: 0.9503 - val_loss: 0.1481 - val_accuracy: 0.9524
# Epoch 13/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1343 - accuracy: 0.9561 - val_loss: 0.1191 - val_accuracy: 0.9622
# Epoch 14/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1372 - accuracy: 0.9573 - val_loss: 0.1347 - val_accuracy: 0.9529
# Epoch 15/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1249 - accuracy: 0.9606 - val_loss: 0.1432 - val_accuracy: 0.9442
# Epoch 16/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1308 - accuracy: 0.9620 - val_loss: 0.1055 - val_accuracy: 0.9661
# Epoch 17/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1268 - accuracy: 0.9627 - val_loss: 0.1088 - val_accuracy: 0.9650
# Epoch 18/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1195 - accuracy: 0.9625 - val_loss: 0.0653 - val_accuracy: 0.9825
# Epoch 19/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1047 - accuracy: 0.9681 - val_loss: 0.0840 - val_accuracy: 0.9721
# Epoch 20/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1153 - accuracy: 0.9641 - val_loss: 0.1137 - val_accuracy: 0.9622
# Epoch 21/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0932 - accuracy: 0.9714 - val_loss: 0.0617 - val_accuracy: 0.9819
# Epoch 22/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1055 - accuracy: 0.9688 - val_loss: 0.1099 - val_accuracy: 0.9661
# Epoch 23/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1001 - accuracy: 0.9695 - val_loss: 0.1519 - val_accuracy: 0.9529
# Epoch 24/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1040 - accuracy: 0.9695 - val_loss: 0.0712 - val_accuracy: 0.9781
# Epoch 25/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0986 - accuracy: 0.9700 - val_loss: 0.0785 - val_accuracy: 0.9726
# Epoch 26/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0949 - accuracy: 0.9714 - val_loss: 0.0657 - val_accuracy: 0.9808
# Epoch 27/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0932 - accuracy: 0.9721 - val_loss: 0.1418 - val_accuracy: 0.9557
# Epoch 28/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0944 - accuracy: 0.9709 - val_loss: 0.1785 - val_accuracy: 0.9409
# Epoch 29/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0892 - accuracy: 0.9728 - val_loss: 0.0547 - val_accuracy: 0.9808
# Epoch 30/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0835 - accuracy: 0.9744 - val_loss: 0.0889 - val_accuracy: 0.9726
# Epoch 31/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1006 - accuracy: 0.9665 - val_loss: 0.0652 - val_accuracy: 0.9770
# Epoch 32/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0914 - accuracy: 0.9740 - val_loss: 0.1296 - val_accuracy: 0.9568
# Epoch 33/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0908 - accuracy: 0.9723 - val_loss: 0.1063 - val_accuracy: 0.9666
# Epoch 34/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0874 - accuracy: 0.9735 - val_loss: 0.0810 - val_accuracy: 0.9743
# Epoch 35/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0888 - accuracy: 0.9737 - val_loss: 0.0593 - val_accuracy: 0.9814
# Epoch 36/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0788 - accuracy: 0.9754 - val_loss: 0.0547 - val_accuracy: 0.9808
# Epoch 37/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0720 - accuracy: 0.9775 - val_loss: 0.0581 - val_accuracy: 0.9808
# Epoch 38/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0732 - accuracy: 0.9770 - val_loss: 0.0657 - val_accuracy: 0.9781
# Epoch 39/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0742 - accuracy: 0.9798 - val_loss: 0.0576 - val_accuracy: 0.9825
# Epoch 40/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0797 - accuracy: 0.9744 - val_loss: 0.0469 - val_accuracy: 0.9869
# Epoch 41/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0770 - accuracy: 0.9754 - val_loss: 0.0859 - val_accuracy: 0.9726
# Epoch 42/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0739 - accuracy: 0.9796 - val_loss: 0.0808 - val_accuracy: 0.9732
# Epoch 43/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0640 - accuracy: 0.9812 - val_loss: 0.0756 - val_accuracy: 0.9765
# Epoch 44/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0804 - accuracy: 0.9763 - val_loss: 0.0617 - val_accuracy: 0.9797
# Epoch 45/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0830 - accuracy: 0.9749 - val_loss: 0.0607 - val_accuracy: 0.9797
# Epoch 46/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0677 - accuracy: 0.9805 - val_loss: 0.0402 - val_accuracy: 0.9880
# Epoch 47/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0683 - accuracy: 0.9805 - val_loss: 0.0503 - val_accuracy: 0.9825
# Epoch 48/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0815 - accuracy: 0.9740 - val_loss: 0.0818 - val_accuracy: 0.9748
# Epoch 49/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0806 - accuracy: 0.9791 - val_loss: 0.0415 - val_accuracy: 0.9885
# Epoch 50/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0746 - accuracy: 0.9777 - val_loss: 0.0743 - val_accuracy: 0.9830
# Epoch 51/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0626 - accuracy: 0.9826 - val_loss: 0.0615 - val_accuracy: 0.9787
# Epoch 52/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0716 - accuracy: 0.9798 - val_loss: 0.0416 - val_accuracy: 0.9885
# Epoch 53/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0750 - accuracy: 0.9787 - val_loss: 0.0421 - val_accuracy: 0.9858
# Epoch 54/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0695 - accuracy: 0.9798 - val_loss: 0.0544 - val_accuracy: 0.9830
# Epoch 55/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0763 - accuracy: 0.9784 - val_loss: 0.0598 - val_accuracy: 0.9841
# Epoch 56/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 0.9831 - val_loss: 0.0634 - val_accuracy: 0.9808
# Epoch 57/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0839 - accuracy: 0.9747 - val_loss: 0.0530 - val_accuracy: 0.9825
# Epoch 58/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0586 - accuracy: 0.9815 - val_loss: 0.0522 - val_accuracy: 0.9825
# Epoch 59/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0634 - accuracy: 0.9808 - val_loss: 0.1098 - val_accuracy: 0.9633
# Epoch 60/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0590 - accuracy: 0.9829 - val_loss: 0.0491 - val_accuracy: 0.9852
# Epoch 61/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0848 - accuracy: 0.9756 - val_loss: 0.0543 - val_accuracy: 0.9808
# Epoch 62/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0781 - accuracy: 0.9756 - val_loss: 0.1765 - val_accuracy: 0.9414
# Epoch 63/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0694 - accuracy: 0.9831 - val_loss: 0.1008 - val_accuracy: 0.9677
# Epoch 64/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0724 - accuracy: 0.9801 - val_loss: 0.0587 - val_accuracy: 0.9825
# Epoch 65/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0757 - accuracy: 0.9758 - val_loss: 0.0831 - val_accuracy: 0.9737
# Epoch 66/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0661 - accuracy: 0.9803 - val_loss: 0.0683 - val_accuracy: 0.9781
# Epoch 67/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0812 - accuracy: 0.9779 - val_loss: 0.1189 - val_accuracy: 0.9611
# Epoch 68/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0631 - accuracy: 0.9815 - val_loss: 0.0477 - val_accuracy: 0.9830
# Epoch 69/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0761 - accuracy: 0.9761 - val_loss: 0.0538 - val_accuracy: 0.9830
# Epoch 70/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0586 - accuracy: 0.9838 - val_loss: 0.0433 - val_accuracy: 0.9863
# Epoch 71/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0702 - accuracy: 0.9784 - val_loss: 0.0499 - val_accuracy: 0.9841
# Epoch 72/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0633 - accuracy: 0.9836 - val_loss: 0.0364 - val_accuracy: 0.9912
# Epoch 73/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0711 - accuracy: 0.9787 - val_loss: 0.0361 - val_accuracy: 0.9901
# Epoch 74/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0608 - accuracy: 0.9826 - val_loss: 0.0396 - val_accuracy: 0.9869
# Epoch 75/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0561 - accuracy: 0.9855 - val_loss: 0.0958 - val_accuracy: 0.9715
# Epoch 76/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 0.9824 - val_loss: 0.0456 - val_accuracy: 0.9863
# Epoch 77/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0788 - accuracy: 0.9789 - val_loss: 0.0603 - val_accuracy: 0.9803
# Epoch 78/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0824 - accuracy: 0.9763 - val_loss: 0.1019 - val_accuracy: 0.9715
# Epoch 79/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0683 - accuracy: 0.9794 - val_loss: 0.0440 - val_accuracy: 0.9896
# Epoch 80/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0535 - accuracy: 0.9845 - val_loss: 0.0444 - val_accuracy: 0.9863
# Epoch 81/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0753 - accuracy: 0.9754 - val_loss: 0.1387 - val_accuracy: 0.9557
# Epoch 82/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0648 - accuracy: 0.9822 - val_loss: 0.0370 - val_accuracy: 0.9901
# Epoch 83/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0597 - accuracy: 0.9819 - val_loss: 0.0414 - val_accuracy: 0.9874
# Epoch 84/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0649 - accuracy: 0.9796 - val_loss: 0.0360 - val_accuracy: 0.9896
# Epoch 85/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0570 - accuracy: 0.9848 - val_loss: 0.0661 - val_accuracy: 0.9797
# Epoch 86/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0668 - accuracy: 0.9810 - val_loss: 0.0471 - val_accuracy: 0.9858
# Epoch 87/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0487 - accuracy: 0.9864 - val_loss: 0.0706 - val_accuracy: 0.9781
# Epoch 88/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0584 - accuracy: 0.9833 - val_loss: 0.0347 - val_accuracy: 0.9901
# Epoch 89/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0547 - accuracy: 0.9855 - val_loss: 0.0662 - val_accuracy: 0.9781
# Epoch 90/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0803 - accuracy: 0.9770 - val_loss: 0.0471 - val_accuracy: 0.9847
# Epoch 91/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0664 - accuracy: 0.9789 - val_loss: 0.0480 - val_accuracy: 0.9885
# Epoch 92/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0575 - accuracy: 0.9843 - val_loss: 0.0800 - val_accuracy: 0.9759
# Epoch 93/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0778 - accuracy: 0.9779 - val_loss: 0.1015 - val_accuracy: 0.9693
# Epoch 94/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0600 - accuracy: 0.9815 - val_loss: 0.0349 - val_accuracy: 0.9912
# Epoch 95/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0533 - accuracy: 0.9857 - val_loss: 0.0348 - val_accuracy: 0.9912
# Epoch 96/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0536 - accuracy: 0.9829 - val_loss: 0.0451 - val_accuracy: 0.9869
# Epoch 97/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0656 - accuracy: 0.9808 - val_loss: 0.0873 - val_accuracy: 0.9721
# Epoch 98/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0669 - accuracy: 0.9794 - val_loss: 0.0425 - val_accuracy: 0.9880
# Epoch 99/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0528 - accuracy: 0.9845 - val_loss: 0.0358 - val_accuracy: 0.9896
# Epoch 100/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0496 - accuracy: 0.9862 - val_loss: 0.0774 - val_accuracy: 0.9759
# 58/58 [==============================] - 0s 895us/step
# 58/58 [==============================] - 0s 829us/step
# 58/58 [==============================] - 0s 803us/step
# 58/58 [==============================] - 0s 842us/step
# 58/58 [==============================] - 0s 807us/step
# 58/58 [==============================] - 0s 842us/step
# 58/58 [==============================] - 0s 823us/step
# 58/58 [==============================] - 0s 807us/step
# 58/58 [==============================] - 0s 859us/step
# 58/58 [==============================] - 0s 861us/step
# 58/58 [==============================] - 0s 842us/step
# 58/58 [==============================] - 0s 842us/step
# 58/58 [==============================] - 0s 841us/step
# 58/58 [==============================] - 0s 857us/step
# 58/58 [==============================] - 0s 789us/step
# 58/58 [==============================] - 0s 842us/step
# 58/58 [==============================] - 0s 825us/step
# 58/58 [==============================] - 0s 771us/step
# 58/58 [==============================] - 0s 772us/step
# 58/58 [==============================] - 0s 782us/step
# Epoch 1/100
# 134/134 [==============================] - 1s 3ms/step - loss: 0.9594 - accuracy: 0.4975 - val_loss: 0.5109 - val_accuracy: 0.8281
# Epoch 2/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.4882 - accuracy: 0.7938 - val_loss: 0.3149 - val_accuracy: 0.8894
# Epoch 3/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.3414 - accuracy: 0.8689 - val_loss: 0.2076 - val_accuracy: 0.9250
# Epoch 4/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.2391 - accuracy: 0.9188 - val_loss: 0.1690 - val_accuracy: 0.9420
# Epoch 5/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1861 - accuracy: 0.9402 - val_loss: 0.1281 - val_accuracy: 0.9589
# Epoch 6/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1519 - accuracy: 0.9543 - val_loss: 0.1104 - val_accuracy: 0.9655
# Epoch 7/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1347 - accuracy: 0.9580 - val_loss: 0.1101 - val_accuracy: 0.9650
# Epoch 8/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1255 - accuracy: 0.9597 - val_loss: 0.0896 - val_accuracy: 0.9732
# Epoch 9/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1272 - accuracy: 0.9618 - val_loss: 0.0918 - val_accuracy: 0.9721
# Epoch 10/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1259 - accuracy: 0.9611 - val_loss: 0.0969 - val_accuracy: 0.9683
# Epoch 11/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1243 - accuracy: 0.9641 - val_loss: 0.0930 - val_accuracy: 0.9704
# Epoch 12/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1042 - accuracy: 0.9655 - val_loss: 0.1901 - val_accuracy: 0.9365
# Epoch 13/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1135 - accuracy: 0.9622 - val_loss: 0.0841 - val_accuracy: 0.9710
# Epoch 14/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1001 - accuracy: 0.9690 - val_loss: 0.1064 - val_accuracy: 0.9650
# Epoch 15/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1010 - accuracy: 0.9690 - val_loss: 0.0760 - val_accuracy: 0.9759
# Epoch 16/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1081 - accuracy: 0.9669 - val_loss: 0.0741 - val_accuracy: 0.9748
# Epoch 17/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1020 - accuracy: 0.9674 - val_loss: 0.0814 - val_accuracy: 0.9748
# Epoch 18/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1079 - accuracy: 0.9679 - val_loss: 0.0771 - val_accuracy: 0.9732
# Epoch 19/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0926 - accuracy: 0.9707 - val_loss: 0.0821 - val_accuracy: 0.9754
# Epoch 20/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0907 - accuracy: 0.9756 - val_loss: 0.1821 - val_accuracy: 0.9228
# Epoch 21/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0926 - accuracy: 0.9716 - val_loss: 0.0918 - val_accuracy: 0.9721
# Epoch 22/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0954 - accuracy: 0.9707 - val_loss: 0.2642 - val_accuracy: 0.9184
# Epoch 23/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0989 - accuracy: 0.9658 - val_loss: 0.0769 - val_accuracy: 0.9754
# Epoch 24/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0808 - accuracy: 0.9747 - val_loss: 0.1278 - val_accuracy: 0.9595
# Epoch 25/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0801 - accuracy: 0.9747 - val_loss: 0.1041 - val_accuracy: 0.9639
# Epoch 26/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0834 - accuracy: 0.9740 - val_loss: 0.0733 - val_accuracy: 0.9765
# Epoch 27/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0908 - accuracy: 0.9707 - val_loss: 0.0849 - val_accuracy: 0.9743
# Epoch 28/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0857 - accuracy: 0.9749 - val_loss: 0.0665 - val_accuracy: 0.9814
# Epoch 29/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0844 - accuracy: 0.9751 - val_loss: 0.0975 - val_accuracy: 0.9704
# Epoch 30/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1030 - accuracy: 0.9667 - val_loss: 0.2129 - val_accuracy: 0.9409
# Epoch 31/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0944 - accuracy: 0.9700 - val_loss: 0.0749 - val_accuracy: 0.9748
# Epoch 32/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0835 - accuracy: 0.9730 - val_loss: 0.0679 - val_accuracy: 0.9792
# Epoch 33/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0822 - accuracy: 0.9756 - val_loss: 0.0654 - val_accuracy: 0.9803
# Epoch 34/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0782 - accuracy: 0.9749 - val_loss: 0.0930 - val_accuracy: 0.9726
# Epoch 35/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0821 - accuracy: 0.9754 - val_loss: 0.0635 - val_accuracy: 0.9819
# Epoch 36/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0791 - accuracy: 0.9756 - val_loss: 0.0591 - val_accuracy: 0.9814
# Epoch 37/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0872 - accuracy: 0.9723 - val_loss: 0.0637 - val_accuracy: 0.9836
# Epoch 38/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0695 - accuracy: 0.9770 - val_loss: 0.0889 - val_accuracy: 0.9754
# Epoch 39/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0688 - accuracy: 0.9787 - val_loss: 0.0636 - val_accuracy: 0.9792
# Epoch 40/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0771 - accuracy: 0.9756 - val_loss: 0.0937 - val_accuracy: 0.9732
# Epoch 41/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0875 - accuracy: 0.9719 - val_loss: 0.0656 - val_accuracy: 0.9814
# Epoch 42/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0782 - accuracy: 0.9749 - val_loss: 0.0739 - val_accuracy: 0.9792
# Epoch 43/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0801 - accuracy: 0.9751 - val_loss: 0.0555 - val_accuracy: 0.9869
# Epoch 44/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0814 - accuracy: 0.9763 - val_loss: 0.0618 - val_accuracy: 0.9814
# Epoch 45/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0786 - accuracy: 0.9791 - val_loss: 0.0988 - val_accuracy: 0.9715
# Epoch 46/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0771 - accuracy: 0.9775 - val_loss: 0.0533 - val_accuracy: 0.9847
# Epoch 47/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0702 - accuracy: 0.9775 - val_loss: 0.0766 - val_accuracy: 0.9765
# Epoch 48/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0688 - accuracy: 0.9789 - val_loss: 0.0573 - val_accuracy: 0.9847
# Epoch 49/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0838 - accuracy: 0.9735 - val_loss: 0.0944 - val_accuracy: 0.9721
# Epoch 50/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0612 - accuracy: 0.9810 - val_loss: 0.0640 - val_accuracy: 0.9825
# Epoch 51/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0753 - accuracy: 0.9777 - val_loss: 0.0683 - val_accuracy: 0.9792
# Epoch 52/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0576 - accuracy: 0.9836 - val_loss: 0.0688 - val_accuracy: 0.9803
# Epoch 53/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0718 - accuracy: 0.9805 - val_loss: 0.0654 - val_accuracy: 0.9847
# Epoch 54/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0759 - accuracy: 0.9791 - val_loss: 0.0612 - val_accuracy: 0.9836
# Epoch 55/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0772 - accuracy: 0.9763 - val_loss: 0.0840 - val_accuracy: 0.9754
# Epoch 56/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0645 - accuracy: 0.9805 - val_loss: 0.0520 - val_accuracy: 0.9852
# Epoch 57/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0582 - accuracy: 0.9833 - val_loss: 0.0532 - val_accuracy: 0.9852
# Epoch 58/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0756 - accuracy: 0.9765 - val_loss: 0.0924 - val_accuracy: 0.9704
# Epoch 59/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0675 - accuracy: 0.9810 - val_loss: 0.0900 - val_accuracy: 0.9715
# Epoch 60/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0802 - accuracy: 0.9758 - val_loss: 0.0860 - val_accuracy: 0.9770
# Epoch 61/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0673 - accuracy: 0.9779 - val_loss: 0.0502 - val_accuracy: 0.9880
# Epoch 62/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9794 - val_loss: 0.0634 - val_accuracy: 0.9797
# Epoch 63/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9794 - val_loss: 0.0585 - val_accuracy: 0.9852
# Epoch 64/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0585 - accuracy: 0.9829 - val_loss: 0.0794 - val_accuracy: 0.9770
# Epoch 65/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0673 - accuracy: 0.9801 - val_loss: 0.1010 - val_accuracy: 0.9666
# Epoch 66/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0615 - accuracy: 0.9803 - val_loss: 0.0513 - val_accuracy: 0.9885
# Epoch 67/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0645 - accuracy: 0.9819 - val_loss: 0.0577 - val_accuracy: 0.9836
# Epoch 68/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0603 - accuracy: 0.9812 - val_loss: 0.0969 - val_accuracy: 0.9688
# Epoch 69/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0752 - accuracy: 0.9754 - val_loss: 0.0663 - val_accuracy: 0.9808
# Epoch 70/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9779 - val_loss: 0.0583 - val_accuracy: 0.9863
# Epoch 71/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0668 - accuracy: 0.9803 - val_loss: 0.1025 - val_accuracy: 0.9677
# Epoch 72/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9798 - val_loss: 0.0896 - val_accuracy: 0.9754
# Epoch 73/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0619 - accuracy: 0.9798 - val_loss: 0.0731 - val_accuracy: 0.9803
# Epoch 74/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0553 - accuracy: 0.9836 - val_loss: 0.0842 - val_accuracy: 0.9776
# Epoch 75/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0618 - accuracy: 0.9829 - val_loss: 0.0574 - val_accuracy: 0.9830
# Epoch 76/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0673 - accuracy: 0.9801 - val_loss: 0.0619 - val_accuracy: 0.9825
# Epoch 77/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0576 - accuracy: 0.9850 - val_loss: 0.1167 - val_accuracy: 0.9666
# Epoch 78/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0599 - accuracy: 0.9829 - val_loss: 0.0467 - val_accuracy: 0.9891
# Epoch 79/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0612 - accuracy: 0.9805 - val_loss: 0.0546 - val_accuracy: 0.9836
# Epoch 80/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0604 - accuracy: 0.9822 - val_loss: 0.1036 - val_accuracy: 0.9704
# Epoch 81/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0643 - accuracy: 0.9794 - val_loss: 0.0522 - val_accuracy: 0.9863
# Epoch 82/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0535 - accuracy: 0.9840 - val_loss: 0.0660 - val_accuracy: 0.9814
# Epoch 83/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0544 - accuracy: 0.9833 - val_loss: 0.1771 - val_accuracy: 0.9518
# Epoch 84/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0671 - accuracy: 0.9772 - val_loss: 0.0754 - val_accuracy: 0.9754
# Epoch 85/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0660 - accuracy: 0.9805 - val_loss: 0.0669 - val_accuracy: 0.9858
# Epoch 86/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0695 - accuracy: 0.9794 - val_loss: 0.0816 - val_accuracy: 0.9748
# Epoch 87/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0543 - accuracy: 0.9831 - val_loss: 0.0748 - val_accuracy: 0.9819
# Epoch 88/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0601 - accuracy: 0.9829 - val_loss: 0.0802 - val_accuracy: 0.9770
# Epoch 89/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0511 - accuracy: 0.9857 - val_loss: 0.1000 - val_accuracy: 0.9776
# Epoch 90/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0742 - accuracy: 0.9768 - val_loss: 0.0481 - val_accuracy: 0.9901
# Epoch 91/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0570 - accuracy: 0.9840 - val_loss: 0.0630 - val_accuracy: 0.9814
# Epoch 92/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0598 - accuracy: 0.9819 - val_loss: 0.0593 - val_accuracy: 0.9863
# Epoch 93/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0559 - accuracy: 0.9833 - val_loss: 0.0592 - val_accuracy: 0.9836
# Epoch 94/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0520 - accuracy: 0.9833 - val_loss: 0.0838 - val_accuracy: 0.9710
# Epoch 95/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0490 - accuracy: 0.9857 - val_loss: 0.0559 - val_accuracy: 0.9880
# Epoch 96/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0671 - accuracy: 0.9794 - val_loss: 0.0677 - val_accuracy: 0.9797
# Epoch 97/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0526 - accuracy: 0.9840 - val_loss: 0.0522 - val_accuracy: 0.9880
# Epoch 98/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0491 - accuracy: 0.9845 - val_loss: 0.0521 - val_accuracy: 0.9874
# Epoch 99/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0552 - accuracy: 0.9836 - val_loss: 0.0706 - val_accuracy: 0.9836
# Epoch 100/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0520 - accuracy: 0.9845 - val_loss: 0.0524 - val_accuracy: 0.9863
# 58/58 [==============================] - 0s 947us/step
# 58/58 [==============================] - 0s 947us/step
# 58/58 [==============================] - 0s 965us/step
# 58/58 [==============================] - 0s 895us/step
# 58/58 [==============================] - 0s 877us/step
# 58/58 [==============================] - 0s 934us/step
# 58/58 [==============================] - 0s 965us/step
# 58/58 [==============================] - 0s 860us/step
# 58/58 [==============================] - 0s 877us/step
# 58/58 [==============================] - 0s 903us/step
# 58/58 [==============================] - 0s 861us/step
# 58/58 [==============================] - 0s 835us/step
# 58/58 [==============================] - 0s 842us/step
# 58/58 [==============================] - 0s 843us/step
# 58/58 [==============================] - 0s 843us/step
# 58/58 [==============================] - 0s 870us/step
# 58/58 [==============================] - 0s 871us/step
# 58/58 [==============================] - 0s 859us/step
# 58/58 [==============================] - 0s 860us/step
# 58/58 [==============================] - 0s 860us/step
# Epoch 1/100
# 134/134 [==============================] - 1s 3ms/step - loss: 1.0280 - accuracy: 0.4544 - val_loss: 0.7602 - val_accuracy: 0.6415
# Epoch 2/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.6148 - accuracy: 0.7260 - val_loss: 0.4357 - val_accuracy: 0.8062
# Epoch 3/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.4365 - accuracy: 0.8220 - val_loss: 0.4107 - val_accuracy: 0.8041
# Epoch 4/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.3328 - accuracy: 0.8764 - val_loss: 0.2152 - val_accuracy: 0.9119
# Epoch 5/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.2026 - accuracy: 0.9353 - val_loss: 0.1924 - val_accuracy: 0.9310
# Epoch 6/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1620 - accuracy: 0.9503 - val_loss: 0.0980 - val_accuracy: 0.9693
# Epoch 7/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1427 - accuracy: 0.9587 - val_loss: 0.0970 - val_accuracy: 0.9666
# Epoch 8/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1302 - accuracy: 0.9613 - val_loss: 0.0873 - val_accuracy: 0.9754
# Epoch 9/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1282 - accuracy: 0.9618 - val_loss: 0.0917 - val_accuracy: 0.9683
# Epoch 10/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1177 - accuracy: 0.9648 - val_loss: 0.1317 - val_accuracy: 0.9524
# Epoch 11/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1154 - accuracy: 0.9611 - val_loss: 0.1577 - val_accuracy: 0.9365
# Epoch 12/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1170 - accuracy: 0.9669 - val_loss: 0.1138 - val_accuracy: 0.9600
# Epoch 13/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1153 - accuracy: 0.9646 - val_loss: 0.0682 - val_accuracy: 0.9759
# Epoch 14/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1289 - accuracy: 0.9627 - val_loss: 0.1026 - val_accuracy: 0.9688
# Epoch 15/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1162 - accuracy: 0.9681 - val_loss: 0.1513 - val_accuracy: 0.9447
# Epoch 16/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1201 - accuracy: 0.9627 - val_loss: 0.0723 - val_accuracy: 0.9748
# Epoch 17/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1118 - accuracy: 0.9667 - val_loss: 0.0638 - val_accuracy: 0.9776
# Epoch 18/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0943 - accuracy: 0.9707 - val_loss: 0.0812 - val_accuracy: 0.9737
# Epoch 19/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0931 - accuracy: 0.9726 - val_loss: 0.0515 - val_accuracy: 0.9808
# Epoch 20/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1037 - accuracy: 0.9693 - val_loss: 0.0711 - val_accuracy: 0.9754
# Epoch 21/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0931 - accuracy: 0.9735 - val_loss: 0.0544 - val_accuracy: 0.9819
# Epoch 22/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0994 - accuracy: 0.9721 - val_loss: 0.0631 - val_accuracy: 0.9770
# Epoch 23/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0834 - accuracy: 0.9758 - val_loss: 0.0560 - val_accuracy: 0.9787
# Epoch 24/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0950 - accuracy: 0.9707 - val_loss: 0.0753 - val_accuracy: 0.9743
# Epoch 25/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0923 - accuracy: 0.9747 - val_loss: 0.0669 - val_accuracy: 0.9787
# Epoch 26/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0852 - accuracy: 0.9747 - val_loss: 0.1043 - val_accuracy: 0.9633
# Epoch 27/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0811 - accuracy: 0.9765 - val_loss: 0.0541 - val_accuracy: 0.9803
# Epoch 28/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0950 - accuracy: 0.9711 - val_loss: 0.0541 - val_accuracy: 0.9808
# Epoch 29/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1012 - accuracy: 0.9726 - val_loss: 0.0479 - val_accuracy: 0.9858
# Epoch 30/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0858 - accuracy: 0.9749 - val_loss: 0.0634 - val_accuracy: 0.9808
# Epoch 31/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0889 - accuracy: 0.9737 - val_loss: 0.0626 - val_accuracy: 0.9781
# Epoch 32/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0817 - accuracy: 0.9758 - val_loss: 0.0596 - val_accuracy: 0.9803
# Epoch 33/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0791 - accuracy: 0.9768 - val_loss: 0.0457 - val_accuracy: 0.9880
# Epoch 34/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0862 - accuracy: 0.9749 - val_loss: 0.0641 - val_accuracy: 0.9797
# Epoch 35/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0757 - accuracy: 0.9777 - val_loss: 0.0646 - val_accuracy: 0.9814
# Epoch 36/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0816 - accuracy: 0.9754 - val_loss: 0.0773 - val_accuracy: 0.9732
# Epoch 37/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0965 - accuracy: 0.9697 - val_loss: 0.1430 - val_accuracy: 0.9458
# Epoch 38/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0822 - accuracy: 0.9770 - val_loss: 0.0426 - val_accuracy: 0.9841
# Epoch 39/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0782 - accuracy: 0.9782 - val_loss: 0.2755 - val_accuracy: 0.8955
# Epoch 40/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0992 - accuracy: 0.9702 - val_loss: 0.0470 - val_accuracy: 0.9847
# Epoch 41/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0679 - accuracy: 0.9803 - val_loss: 0.0425 - val_accuracy: 0.9863
# Epoch 42/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0810 - accuracy: 0.9777 - val_loss: 0.0752 - val_accuracy: 0.9776
# Epoch 43/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0753 - accuracy: 0.9784 - val_loss: 0.0711 - val_accuracy: 0.9748
# Epoch 44/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0740 - accuracy: 0.9812 - val_loss: 0.0470 - val_accuracy: 0.9830
# Epoch 45/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0868 - accuracy: 0.9721 - val_loss: 0.0430 - val_accuracy: 0.9874
# Epoch 46/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0846 - accuracy: 0.9779 - val_loss: 0.0501 - val_accuracy: 0.9836
# Epoch 47/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0650 - accuracy: 0.9833 - val_loss: 0.0409 - val_accuracy: 0.9880
# Epoch 48/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0765 - accuracy: 0.9775 - val_loss: 0.0725 - val_accuracy: 0.9732
# Epoch 49/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0772 - accuracy: 0.9768 - val_loss: 0.0587 - val_accuracy: 0.9792
# Epoch 50/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0787 - accuracy: 0.9796 - val_loss: 0.0604 - val_accuracy: 0.9797
# Epoch 51/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0709 - accuracy: 0.9801 - val_loss: 0.0780 - val_accuracy: 0.9737
# Epoch 52/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0657 - accuracy: 0.9791 - val_loss: 0.0371 - val_accuracy: 0.9885
# Epoch 53/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0809 - accuracy: 0.9749 - val_loss: 0.0857 - val_accuracy: 0.9748
# Epoch 54/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0587 - accuracy: 0.9833 - val_loss: 0.0360 - val_accuracy: 0.9880
# Epoch 55/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0718 - accuracy: 0.9810 - val_loss: 0.0558 - val_accuracy: 0.9808
# Epoch 56/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0777 - accuracy: 0.9763 - val_loss: 0.0427 - val_accuracy: 0.9874
# Epoch 57/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0758 - accuracy: 0.9796 - val_loss: 0.0474 - val_accuracy: 0.9874
# Epoch 58/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0712 - accuracy: 0.9801 - val_loss: 0.0497 - val_accuracy: 0.9874
# Epoch 59/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0672 - accuracy: 0.9805 - val_loss: 0.0925 - val_accuracy: 0.9655
# Epoch 60/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0720 - accuracy: 0.9794 - val_loss: 0.0374 - val_accuracy: 0.9880
# Epoch 61/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0612 - accuracy: 0.9819 - val_loss: 0.0769 - val_accuracy: 0.9765
# Epoch 62/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0666 - accuracy: 0.9810 - val_loss: 0.0472 - val_accuracy: 0.9841
# Epoch 63/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0714 - accuracy: 0.9796 - val_loss: 0.0429 - val_accuracy: 0.9858
# Epoch 64/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0682 - accuracy: 0.9794 - val_loss: 0.0505 - val_accuracy: 0.9896
# Epoch 65/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0659 - accuracy: 0.9805 - val_loss: 0.0534 - val_accuracy: 0.9836
# Epoch 66/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0668 - accuracy: 0.9812 - val_loss: 0.0648 - val_accuracy: 0.9803
# Epoch 67/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0624 - accuracy: 0.9836 - val_loss: 0.0547 - val_accuracy: 0.9814
# Epoch 68/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0600 - accuracy: 0.9840 - val_loss: 0.0517 - val_accuracy: 0.9819
# Epoch 69/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0671 - accuracy: 0.9822 - val_loss: 0.0414 - val_accuracy: 0.9858
# Epoch 70/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0619 - accuracy: 0.9822 - val_loss: 0.0459 - val_accuracy: 0.9869
# Epoch 71/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0661 - accuracy: 0.9798 - val_loss: 0.0438 - val_accuracy: 0.9869
# Epoch 72/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0621 - accuracy: 0.9833 - val_loss: 0.1302 - val_accuracy: 0.9453
# Epoch 73/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 0.9829 - val_loss: 0.0410 - val_accuracy: 0.9880
# Epoch 74/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0709 - accuracy: 0.9761 - val_loss: 0.0348 - val_accuracy: 0.9885
# Epoch 75/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0662 - accuracy: 0.9815 - val_loss: 0.1233 - val_accuracy: 0.9551
# Epoch 76/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0946 - accuracy: 0.9711 - val_loss: 0.0387 - val_accuracy: 0.9891
# Epoch 77/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0526 - accuracy: 0.9852 - val_loss: 0.0362 - val_accuracy: 0.9907
# Epoch 78/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0633 - accuracy: 0.9824 - val_loss: 0.0483 - val_accuracy: 0.9841
# Epoch 79/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0621 - accuracy: 0.9838 - val_loss: 0.0360 - val_accuracy: 0.9901
# Epoch 80/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0623 - accuracy: 0.9831 - val_loss: 0.0372 - val_accuracy: 0.9869
# Epoch 81/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0677 - accuracy: 0.9796 - val_loss: 0.0468 - val_accuracy: 0.9869
# Epoch 82/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0625 - accuracy: 0.9833 - val_loss: 0.1084 - val_accuracy: 0.9655
# Epoch 83/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0812 - accuracy: 0.9758 - val_loss: 0.0448 - val_accuracy: 0.9847
# Epoch 84/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0592 - accuracy: 0.9824 - val_loss: 0.0909 - val_accuracy: 0.9655
# Epoch 85/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0555 - accuracy: 0.9852 - val_loss: 0.0497 - val_accuracy: 0.9830
# Epoch 86/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0652 - accuracy: 0.9819 - val_loss: 0.0663 - val_accuracy: 0.9819
# Epoch 87/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0754 - accuracy: 0.9777 - val_loss: 0.0385 - val_accuracy: 0.9885
# Epoch 88/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0666 - accuracy: 0.9791 - val_loss: 0.0717 - val_accuracy: 0.9765
# Epoch 89/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0639 - accuracy: 0.9822 - val_loss: 0.0473 - val_accuracy: 0.9841
# Epoch 90/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0660 - accuracy: 0.9824 - val_loss: 0.0495 - val_accuracy: 0.9852
# Epoch 91/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0798 - accuracy: 0.9777 - val_loss: 0.0716 - val_accuracy: 0.9759
# Epoch 92/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0656 - accuracy: 0.9805 - val_loss: 0.0431 - val_accuracy: 0.9874
# Epoch 93/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0607 - accuracy: 0.9822 - val_loss: 0.0599 - val_accuracy: 0.9825
# Epoch 94/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0562 - accuracy: 0.9848 - val_loss: 0.0532 - val_accuracy: 0.9830
# Epoch 95/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0529 - accuracy: 0.9862 - val_loss: 0.0487 - val_accuracy: 0.9825
# Epoch 96/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0593 - accuracy: 0.9817 - val_loss: 0.0411 - val_accuracy: 0.9891
# Epoch 97/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0592 - accuracy: 0.9812 - val_loss: 0.0481 - val_accuracy: 0.9847
# Epoch 98/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0613 - accuracy: 0.9824 - val_loss: 0.0423 - val_accuracy: 0.9869
# Epoch 99/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0546 - accuracy: 0.9843 - val_loss: 0.0744 - val_accuracy: 0.9776
# Epoch 100/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.0513 - accuracy: 0.9869 - val_loss: 0.2916 - val_accuracy: 0.9168
# 58/58 [==============================] - 0s 911us/step
# 58/58 [==============================] - 0s 948us/step
# 58/58 [==============================] - 0s 861us/step
# 58/58 [==============================] - 0s 826us/step
# 58/58 [==============================] - 0s 966us/step
# 58/58 [==============================] - 0s 905us/step
# 58/58 [==============================] - 0s 860us/step
# 58/58 [==============================] - 0s 895us/step
# 58/58 [==============================] - 0s 860us/step
# 58/58 [==============================] - 0s 912us/step
# 58/58 [==============================] - 0s 842us/step
# 58/58 [==============================] - 0s 824us/step
# 58/58 [==============================] - 0s 877us/step
# 58/58 [==============================] - 0s 891us/step
# 58/58 [==============================] - 0s 824us/step
# 58/58 [==============================] - 0s 860us/step
# 58/58 [==============================] - 0s 860us/step
# 58/58 [==============================] - 0s 895us/step
# 58/58 [==============================] - 0s 824us/step
# 58/58 [==============================] - 0s 918us/step
# Epoch 1/100
# 134/134 [==============================] - 1s 3ms/step - loss: 0.7810 - accuracy: 0.6223 - val_loss: 0.4178 - val_accuracy: 0.8396
# Epoch 2/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.4254 - accuracy: 0.8262 - val_loss: 0.2734 - val_accuracy: 0.8976
# Epoch 3/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.2910 - accuracy: 0.8954 - val_loss: 0.1953 - val_accuracy: 0.9299
# Epoch 4/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.2185 - accuracy: 0.9282 - val_loss: 0.1281 - val_accuracy: 0.9644
# Epoch 5/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1700 - accuracy: 0.9493 - val_loss: 0.1008 - val_accuracy: 0.9743
# Epoch 6/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1526 - accuracy: 0.9536 - val_loss: 0.1011 - val_accuracy: 0.9693
# Epoch 7/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1378 - accuracy: 0.9618 - val_loss: 0.1729 - val_accuracy: 0.9349
# Epoch 8/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1357 - accuracy: 0.9571 - val_loss: 0.1402 - val_accuracy: 0.9491
# Epoch 9/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1293 - accuracy: 0.9604 - val_loss: 0.0770 - val_accuracy: 0.9765
# Epoch 10/100
# 134/134 [==============================] - 0s 2ms/step - loss: 0.1193 - accuracy: 0.9629 - val_loss: 0.0920 - val_accuracy: 0.9732
# Epoch 11/100
# ...
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 1ms/step
# Epoch 1/100
# 134/134 [==============================] - 1s 3ms/step - loss: 0.9792 - accuracy: 0.4989 - val_loss: 0.5241 - val_accuracy: 0.8451
# Epoch 2/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.4799 - accuracy: 0.7983 - val_loss: 0.2797 - val_accuracy: 0.8966
# Epoch 3/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.3017 - accuracy: 0.8912 - val_loss: 0.2706 - val_accuracy: 0.8916
# Epoch 4/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.2092 - accuracy: 0.9353 - val_loss: 0.1612 - val_accuracy: 0.9420
# Epoch 5/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1703 - accuracy: 0.9472 - val_loss: 0.1092 - val_accuracy: 0.9639
# Epoch 6/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1557 - accuracy: 0.9496 - val_loss: 0.0990 - val_accuracy: 0.9655
# Epoch 7/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1552 - accuracy: 0.9470 - val_loss: 0.0987 - val_accuracy: 0.9672
# Epoch 8/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1402 - accuracy: 0.9573 - val_loss: 0.0740 - val_accuracy: 0.9770
# Epoch 9/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1259 - accuracy: 0.9627 - val_loss: 0.0922 - val_accuracy: 0.9693
# Epoch 10/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1294 - accuracy: 0.9587 - val_loss: 0.1141 - val_accuracy: 0.9568
# Epoch 11/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1169 - accuracy: 0.9650 - val_loss: 0.1023 - val_accuracy: 0.9650
# Epoch 12/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1283 - accuracy: 0.9620 - val_loss: 0.0791 - val_accuracy: 0.9797
# Epoch 13/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1218 - accuracy: 0.9632 - val_loss: 0.0675 - val_accuracy: 0.9776
# Epoch 14/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1179 - accuracy: 0.9655 - val_loss: 0.0762 - val_accuracy: 0.9759
# Epoch 15/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1091 - accuracy: 0.9632 - val_loss: 0.0887 - val_accuracy: 0.9715
# Epoch 16/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0920 - accuracy: 0.9747 - val_loss: 0.0622 - val_accuracy: 0.9792
# Epoch 17/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1084 - accuracy: 0.9700 - val_loss: 0.2028 - val_accuracy: 0.9163
# Epoch 18/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.1053 - accuracy: 0.9686 - val_loss: 0.0681 - val_accuracy: 0.9776
# Epoch 19/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0925 - accuracy: 0.9723 - val_loss: 0.0503 - val_accuracy: 0.9880
# Epoch 20/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0922 - accuracy: 0.9719 - val_loss: 0.0593 - val_accuracy: 0.9819
# Epoch 21/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0872 - accuracy: 0.9765 - val_loss: 0.0499 - val_accuracy: 0.9841
# Epoch 22/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0965 - accuracy: 0.9704 - val_loss: 0.0535 - val_accuracy: 0.9830
# Epoch 23/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0964 - accuracy: 0.9721 - val_loss: 0.0548 - val_accuracy: 0.9836
# Epoch 24/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0855 - accuracy: 0.9749 - val_loss: 0.0498 - val_accuracy: 0.9858
# Epoch 25/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0910 - accuracy: 0.9716 - val_loss: 0.0583 - val_accuracy: 0.9808
# Epoch 26/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0925 - accuracy: 0.9730 - val_loss: 0.0773 - val_accuracy: 0.9693
# Epoch 27/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0926 - accuracy: 0.9730 - val_loss: 0.0733 - val_accuracy: 0.9743
# Epoch 28/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0898 - accuracy: 0.9740 - val_loss: 0.1397 - val_accuracy: 0.9507
# Epoch 29/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0950 - accuracy: 0.9704 - val_loss: 0.0565 - val_accuracy: 0.9825
# Epoch 30/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0807 - accuracy: 0.9756 - val_loss: 0.0430 - val_accuracy: 0.9880
# Epoch 31/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0832 - accuracy: 0.9747 - val_loss: 0.0484 - val_accuracy: 0.9863
# Epoch 32/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0987 - accuracy: 0.9700 - val_loss: 0.0585 - val_accuracy: 0.9880
# Epoch 33/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0865 - accuracy: 0.9721 - val_loss: 0.0441 - val_accuracy: 0.9874
# Epoch 34/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0848 - accuracy: 0.9749 - val_loss: 0.0580 - val_accuracy: 0.9830
# Epoch 35/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0780 - accuracy: 0.9805 - val_loss: 0.0551 - val_accuracy: 0.9825
# Epoch 36/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0813 - accuracy: 0.9775 - val_loss: 0.0645 - val_accuracy: 0.9759
# Epoch 37/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0702 - accuracy: 0.9789 - val_loss: 0.2176 - val_accuracy: 0.9239
# Epoch 38/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0873 - accuracy: 0.9777 - val_loss: 0.0520 - val_accuracy: 0.9825
# Epoch 39/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0769 - accuracy: 0.9772 - val_loss: 0.0414 - val_accuracy: 0.9885
# Epoch 40/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0898 - accuracy: 0.9749 - val_loss: 0.0478 - val_accuracy: 0.9869
# Epoch 41/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0789 - accuracy: 0.9763 - val_loss: 0.0378 - val_accuracy: 0.9901
# Epoch 42/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0775 - accuracy: 0.9777 - val_loss: 0.0499 - val_accuracy: 0.9836
# Epoch 43/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0798 - accuracy: 0.9768 - val_loss: 0.0390 - val_accuracy: 0.9896
# Epoch 44/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0850 - accuracy: 0.9749 - val_loss: 0.0967 - val_accuracy: 0.9655
# Epoch 45/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0815 - accuracy: 0.9765 - val_loss: 0.0417 - val_accuracy: 0.9869
# Epoch 46/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0755 - accuracy: 0.9791 - val_loss: 0.0469 - val_accuracy: 0.9869
# Epoch 47/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0681 - accuracy: 0.9808 - val_loss: 0.0588 - val_accuracy: 0.9819
# Epoch 48/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0821 - accuracy: 0.9763 - val_loss: 0.0416 - val_accuracy: 0.9869
# Epoch 49/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0773 - accuracy: 0.9768 - val_loss: 0.0380 - val_accuracy: 0.9907
# Epoch 50/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0781 - accuracy: 0.9779 - val_loss: 0.0378 - val_accuracy: 0.9907
# Epoch 51/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0744 - accuracy: 0.9789 - val_loss: 0.1367 - val_accuracy: 0.9518
# Epoch 52/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0675 - accuracy: 0.9822 - val_loss: 0.0361 - val_accuracy: 0.9896
# Epoch 53/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0737 - accuracy: 0.9796 - val_loss: 0.0389 - val_accuracy: 0.9896
# Epoch 54/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0809 - accuracy: 0.9775 - val_loss: 0.0419 - val_accuracy: 0.9863
# Epoch 55/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0718 - accuracy: 0.9784 - val_loss: 0.0592 - val_accuracy: 0.9825
# Epoch 56/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0605 - accuracy: 0.9857 - val_loss: 0.0522 - val_accuracy: 0.9847
# Epoch 57/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0777 - accuracy: 0.9770 - val_loss: 0.0579 - val_accuracy: 0.9814
# Epoch 58/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0678 - accuracy: 0.9791 - val_loss: 0.0393 - val_accuracy: 0.9891
# Epoch 59/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0748 - accuracy: 0.9768 - val_loss: 0.0345 - val_accuracy: 0.9901
# Epoch 60/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0637 - accuracy: 0.9833 - val_loss: 0.0553 - val_accuracy: 0.9808
# Epoch 61/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0697 - accuracy: 0.9794 - val_loss: 0.0493 - val_accuracy: 0.9830
# Epoch 62/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0758 - accuracy: 0.9796 - val_loss: 0.0485 - val_accuracy: 0.9852
# Epoch 63/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0768 - accuracy: 0.9787 - val_loss: 0.0571 - val_accuracy: 0.9819
# Epoch 64/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0718 - accuracy: 0.9784 - val_loss: 0.0414 - val_accuracy: 0.9891
# Epoch 65/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0875 - accuracy: 0.9733 - val_loss: 0.0458 - val_accuracy: 0.9891
# Epoch 66/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0673 - accuracy: 0.9805 - val_loss: 0.0338 - val_accuracy: 0.9918
# Epoch 67/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0649 - accuracy: 0.9819 - val_loss: 0.0533 - val_accuracy: 0.9841
# Epoch 68/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0636 - accuracy: 0.9812 - val_loss: 0.0915 - val_accuracy: 0.9688
# Epoch 69/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0706 - accuracy: 0.9787 - val_loss: 0.0334 - val_accuracy: 0.9907
# Epoch 70/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0737 - accuracy: 0.9789 - val_loss: 0.0688 - val_accuracy: 0.9776
# Epoch 71/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0716 - accuracy: 0.9791 - val_loss: 0.0524 - val_accuracy: 0.9803
# Epoch 72/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0609 - accuracy: 0.9812 - val_loss: 0.0347 - val_accuracy: 0.9907
# Epoch 73/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0631 - accuracy: 0.9815 - val_loss: 0.0451 - val_accuracy: 0.9863
# Epoch 74/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0566 - accuracy: 0.9840 - val_loss: 0.0397 - val_accuracy: 0.9891
# Epoch 75/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0583 - accuracy: 0.9817 - val_loss: 0.0323 - val_accuracy: 0.9912
# Epoch 76/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0668 - accuracy: 0.9808 - val_loss: 0.0750 - val_accuracy: 0.9776
# Epoch 77/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0771 - accuracy: 0.9747 - val_loss: 0.0409 - val_accuracy: 0.9869
# Epoch 78/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0680 - accuracy: 0.9808 - val_loss: 0.0620 - val_accuracy: 0.9814
# Epoch 79/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0702 - accuracy: 0.9791 - val_loss: 0.0464 - val_accuracy: 0.9852
# Epoch 80/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0560 - accuracy: 0.9824 - val_loss: 0.0678 - val_accuracy: 0.9781
# Epoch 81/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0593 - accuracy: 0.9819 - val_loss: 0.0329 - val_accuracy: 0.9912
# Epoch 82/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0531 - accuracy: 0.9848 - val_loss: 0.0415 - val_accuracy: 0.9880
# Epoch 83/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0531 - accuracy: 0.9850 - val_loss: 0.0337 - val_accuracy: 0.9912
# Epoch 84/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0538 - accuracy: 0.9843 - val_loss: 0.0333 - val_accuracy: 0.9891
# Epoch 85/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0610 - accuracy: 0.9824 - val_loss: 0.0317 - val_accuracy: 0.9918
# Epoch 86/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0572 - accuracy: 0.9845 - val_loss: 0.0392 - val_accuracy: 0.9891
# Epoch 87/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9824 - val_loss: 0.0343 - val_accuracy: 0.9901
# Epoch 88/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0582 - accuracy: 0.9824 - val_loss: 0.0378 - val_accuracy: 0.9880
# Epoch 89/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0594 - accuracy: 0.9833 - val_loss: 0.0420 - val_accuracy: 0.9880
# Epoch 90/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0560 - accuracy: 0.9838 - val_loss: 0.0378 - val_accuracy: 0.9896
# Epoch 91/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0639 - accuracy: 0.9822 - val_loss: 0.0702 - val_accuracy: 0.9787
# Epoch 92/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0552 - accuracy: 0.9850 - val_loss: 0.0728 - val_accuracy: 0.9765
# Epoch 93/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0600 - accuracy: 0.9831 - val_loss: 0.0929 - val_accuracy: 0.9661
# Epoch 94/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0625 - accuracy: 0.9829 - val_loss: 0.0396 - val_accuracy: 0.9880
# Epoch 95/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0599 - accuracy: 0.9831 - val_loss: 0.0750 - val_accuracy: 0.9787
# Epoch 96/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0619 - accuracy: 0.9840 - val_loss: 0.0363 - val_accuracy: 0.9891
# Epoch 97/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0613 - accuracy: 0.9824 - val_loss: 0.0402 - val_accuracy: 0.9896
# Epoch 98/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0578 - accuracy: 0.9831 - val_loss: 0.0453 - val_accuracy: 0.9869
# Epoch 99/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0910 - accuracy: 0.9723 - val_loss: 0.0388 - val_accuracy: 0.9885
# Epoch 100/100
# 134/134 [==============================] - 0s 3ms/step - loss: 0.0492 - accuracy: 0.9857 - val_loss: 0.0829 - val_accuracy: 0.9759
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 990us/step
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 935us/step
# 58/58 [==============================] - 0s 965us/step
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 988us/step
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 968us/step
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 967us/step
# 58/58 [==============================] - 0s 965us/step
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 983us/step
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 946us/step
#
# Best Average Accuracy:
# 0.973782156540777
# 58/58 [==============================] - 0s 958us/step
# 58/58 [==============================] - 0s 930us/step
#
# Confusion Matrix:
# [[543  34   3]
#  [  0 615   0]
#  [  6   0 626]]
#
# Accuracy: 0.976464148877942
#
# Precision: 0.9773044244057435
#
# Recall: 0.9755710752218828
#
# F1 Score: 0.9759590902128369
# ROC AUC score: 0.9975113862575217

# %% [markdown]
# ### Mapping alteration zones

# %%
pred_features_chips = features_chips
dsPred = dsFeatures

# predict and export the probability raster
pred = best_model.predict(pred_features_chips)
pred_array = np.reshape(pred.argmax(axis=1), (dsPred.RasterYSize, dsPred.RasterXSize))

fig, ax = plt.subplots(figsize=(10, 10))
ax.set_xlim(min_x, max_x)
ax.set_ylim(min_y, max_y)
cx.add_basemap(ax, crs='EPSG:32754', source=cx.providers.Esri.WorldShadedRelief)
ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
plt.yticks(rotation=90, va='center')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
cmap = mpl.colors.ListedColormap(['blue', 'green'])

pred_array_copy = pred_array.copy()
pred_array_copy = pred_array_copy.astype('float')
pred_array_copy[pred_array_copy==0] = np.nan
image = plt.imshow(pred_array_copy, cmap=cmap, extent=extent, interpolation='nearest')

divider = make_axes_locatable(ax)
cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
fig.add_axes(cax)
cbar = plt.colorbar(image, orientation='horizontal', label='Alteration Type', cax=cax)
tick_locs = (np.arange(n_class_pos-1) + 2.5)*(n_class_pos-2)/(n_class_pos-1)
cbar.set_ticks(tick_locs)
cbar.set_ticklabels(['Argillic', 'Propylitic'])
plt.grid(False)

outFile = './Outputs/BrokenHill_ASTER_Manual_CNN_AlterationMap_ks_5.tif'
raster.export(pred_array, dsPred, filename=outFile, dtype='float')
# Out:
# 367904/367904 [==============================] - 369s 1ms/step

# %% [markdown]
# ### Loading the training dataset (PCA)

# %%
positiveLabel_file = './BrokenHill_ASTER_PCA_CombinedTraining.tif'
# read and reshape the label file
dsPositiveLabels_pca, arrPositiveLabels_pca = raster.read(positiveLabel_file)
n_class_pos = len(np.unique(arrPositiveLabels_pca))

fig, ax = plt.subplots(figsize=(10, 10))
ax.set_xlim(min_x, max_x)
ax.set_ylim(min_y, max_y)
cx.add_basemap(ax, crs='EPSG:32754', source=cx.providers.Esri.WorldShadedRelief)
ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
plt.yticks(rotation=90, va='center')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
cmap = mpl.colors.ListedColormap(['blue', 'green'])

arrPositiveLabels_pca_copy = arrPositiveLabels_pca.copy()
arrPositiveLabels_pca_copy[arrPositiveLabels_pca_copy==0] = np.nan
image = plt.imshow(arrPositiveLabels_pca_copy, cmap=cmap, extent=extent, interpolation='nearest')

divider = make_axes_locatable(ax)
cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
fig.add_axes(cax)
cbar = plt.colorbar(image, orientation='horizontal', label='Alteration Type', cax=cax)
tick_locs = (np.arange(n_class_pos-1) + 2.5)*(n_class_pos-2)/(n_class_pos-1)
cbar.set_ticks(tick_locs)
cbar.set_ticklabels(['Argillic', 'Propylitic'])
plt.grid(False)

# %% [markdown]
# ### Generating random samples

# %%
# generate random samples
nonZero_count = np.count_nonzero(arrPositiveLabels_pca)
index = np.transpose(np.where(arrPositiveLabels_pca==0))
index = index.astype(int)
randomIndex = random.sample(range(index.shape[0]), int(nonZero_count/(n_class_pos-1)))
arrNegativeLabels = np.zeros(arrPositiveLabels_pca.shape)

for i in range(len(randomIndex)):
    arrNegativeLabels[index[randomIndex[i], 0], index[randomIndex[i], 1]] = n_class_pos # max value of labels plus one which equals n_class
    
arrPositiveLabels_pca_flat = arrPositiveLabels_pca.flatten()
arrNegativeLabels_flat = arrNegativeLabels.flatten()
# separate and balance the classes
positiveFeatures = features_chips[arrPositiveLabels_pca_flat!=0]
positiveLabels_pca = arrPositiveLabels_pca_flat[arrPositiveLabels_pca_flat!=0]
negativeFeatures = features_chips[arrNegativeLabels_flat==n_class_pos]
negativeLabels = arrNegativeLabels_flat[arrNegativeLabels_flat==n_class_pos]
# combine the balanced features
features = np.concatenate((positiveFeatures, negativeFeatures), axis=0)
labels = np.concatenate((positiveLabels_pca, negativeLabels), axis=0)
labels[labels==n_class_pos] = 0

# %% [markdown]
# ### Splitting features and labels into training and test datasets

# %%
# define a function to split features and labels
def train_test_split(features, labels, trainProp=0.7):
    dataSize = features.shape[0]
    sliceIndex = int(dataSize*trainProp)
    randIndex = np.arange(dataSize)
    random.shuffle(randIndex)
    train_x = features[[randIndex[:sliceIndex]], :, :, :][0]
    test_x = features[[randIndex[sliceIndex:]], :, :, :][0]
    train_y = labels[randIndex[:sliceIndex]]
    test_y = labels[randIndex[sliceIndex:]]
    return(train_x, train_y, test_x, test_y)

# call the function to split the dataset
train_x, train_y, test_x, test_y = train_test_split(features, labels)

# %% [markdown]
# ### Training the model

# %%
def roc_auc(model, test_x, test_y, n_classes):
    roc_auc = []
    test_z = model.predict(test_x)
    test_y_dummies = pd.get_dummies(test_y).values
    
    for i in range(n_classes):
        roc_auc.append(roc_auc_score(test_y_dummies[:, i], test_z[:, i]))
    
    return roc_auc

# plot any graph relating to any model
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics)+1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and Testing '+metric.capitalize())
    plt.xlabel('Epochs')
    plt.ylabel(metric.capitalize())
    plt.legend(['Training '+metric.capitalize(), 'Testing '+metric.capitalize()])
    plt.show()
    
def roc_plot(test_y, test_z, n_classes, labels_name, average='macro'):
    fpr = {}
    tpr = {}
    roc_auc = {}

    test_y_dummies = pd.get_dummies(test_y).values
    
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(test_y_dummies[:, i], test_z[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # roc for each class
    fig, ax = plt.subplots()
    ax.plot([0, 1], [0, 1], 'k--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title('Receiver Operating Characteristic')
    
    for i in range(n_classes):
        ax.plot(fpr[i], tpr[i], label='{}, AUC = {}'.format(labels_name[i], '{0:.4f}'.format(roc_auc[i])))
    
    ax.legend(loc='best')
    ax.grid(alpha=0.5)
    sns.despine()
    plt.show()
    print('ROC AUC score:', roc_auc_score(test_y_dummies, test_z, average=average))

best_model = tf.keras.models.Sequential()
best_accuracy = 0
best_history = None
experimental_runs = 5
cv = 10
metrics_columns = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC_No Alteration', 'AUC_Argillic', 'AUC_Propylitic', 'AUC_Aggregate']
temp_metrics_df = pd.DataFrame(np.zeros((cv, len(metrics_columns))), columns=metrics_columns)

for i in range(experimental_runs):
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Conv2D(32, kernel_size=1, padding='valid', activation='relu', input_shape=(train_x.shape[1], train_x.shape[2], train_x.shape[3])))
    model.add(tf.keras.layers.Dropout(0.25))
    model.add(tf.keras.layers.Conv2D(48, kernel_size=1, padding='valid', activation='relu'))
    model.add(tf.keras.layers.Dropout(0.25))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(64, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(3, activation='softmax'))

    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(train_x, train_y, epochs=50, validation_data=(test_x, test_y))

    for j in range(cv):
        train_x, train_y, test_x, test_y = train_test_split(features, labels)
        # predict for the test dataset
        test_z = model.predict(test_x)
        # calculate and display error metrics
        test_z_class = test_z.argmax(axis=1)

        aScore = accuracy_score(test_y, test_z_class)
        pScore = precision_score(test_y, test_z_class, average='macro')
        rScore = recall_score(test_y, test_z_class, average='macro')
        fScore = f1_score(test_y, test_z_class, average='macro')
        cMatrix = confusion_matrix(test_y, test_z_class)
        metrics_array = [aScore, pScore, rScore, fScore]
        roc_auc_class = roc_auc(model, test_x, test_y, n_class_pos)

        for k in range(n_class_pos):
            metrics_array.append(roc_auc_class[k])

        roc_auc_mean = mean(roc_auc_class)
        metrics_array.append(roc_auc_mean)
        temp_metrics_df.loc[j] = metrics_array
        
        if j==cv-1:
            # accuracy can be replaced with other scores
            aScore_avg = temp_metrics_df['Accuracy'].mean()
            
            if best_accuracy < aScore_avg:
                best_model = model
                best_accuracy_avg = aScore_avg
                best_history = history

print(f'\nBest Average Accuracy:\n{best_accuracy_avg}')

test_z = best_model.predict(test_x)
test_z_class = test_z.argmax(axis=1)
aScore = accuracy_score(test_y, test_z_class)
pScore = precision_score(test_y, test_z_class, average='macro')
rScore = recall_score(test_y, test_z_class, average='macro')
fScore = f1_score(test_y, test_z_class, average='macro')
cMatrix = confusion_matrix(test_y, test_z_class)
metrics_array = [aScore, pScore, rScore, fScore]
roc_auc_class = roc_auc(best_model, test_x, test_y, n_class_pos)
metrics_array.extend(roc_auc_class)
roc_auc_mean = mean(roc_auc_class)
metrics_array.append(roc_auc_mean)

print(f'\nConfusion Matrix:\n{cMatrix}')
print(f'\nAccuracy: {aScore}')
print(f'\nPrecision: {pScore}')
print(f'\nRecall: {rScore}')
print(f'\nF1 Score: {fScore}')

plot_metric(history, 'loss')
print('')
plot_metric(history, 'accuracy')
labels_name = ['No Alteration', 'Argillic', 'Propylitic']
roc_plot(test_y, test_z, n_class_pos, labels_name)
# Out:
# Epoch 1/50
# 12873/12873 [==============================] - 304s 24ms/step - loss: 0.3323 - accuracy: 0.8640 - val_loss: 0.1363 - val_accuracy: 0.9560
# Epoch 2/50
# 12873/12873 [==============================] - 301s 23ms/step - loss: 0.1657 - accuracy: 0.9442 - val_loss: 0.1205 - val_accuracy: 0.9495
# Epoch 3/50
# 12873/12873 [==============================] - 303s 24ms/step - loss: 0.1400 - accuracy: 0.9534 - val_loss: 0.0676 - val_accuracy: 0.9819
# Epoch 4/50
# 12873/12873 [==============================] - 301s 23ms/step - loss: 0.1351 - accuracy: 0.9552 - val_loss: 0.0886 - val_accuracy: 0.9830
# Epoch 5/50
# 12873/12873 [==============================] - 315s 24ms/step - loss: 0.1371 - accuracy: 0.9547 - val_loss: 0.0745 - val_accuracy: 0.9701
# Epoch 6/50
# 12873/12873 [==============================] - 293s 23ms/step - loss: 0.1320 - accuracy: 0.9569 - val_loss: 0.0636 - val_accuracy: 0.9782
# Epoch 7/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.1333 - accuracy: 0.9567 - val_loss: 0.1022 - val_accuracy: 0.9598
# Epoch 8/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.1266 - accuracy: 0.9596 - val_loss: 0.1217 - val_accuracy: 0.9546
# Epoch 9/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.1211 - accuracy: 0.9611 - val_loss: 0.5694 - val_accuracy: 0.8471
# Epoch 10/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.1233 - accuracy: 0.9609 - val_loss: 0.0500 - val_accuracy: 0.9838
# Epoch 11/50
# 12873/12873 [==============================] - 290s 23ms/step - loss: 0.1156 - accuracy: 0.9628 - val_loss: 0.0689 - val_accuracy: 0.9822
# Epoch 12/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.1122 - accuracy: 0.9641 - val_loss: 0.0697 - val_accuracy: 0.9767
# Epoch 13/50
# 12873/12873 [==============================] - 290s 23ms/step - loss: 0.1113 - accuracy: 0.9650 - val_loss: 0.2362 - val_accuracy: 0.9088
# Epoch 14/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.1076 - accuracy: 0.9659 - val_loss: 0.1175 - val_accuracy: 0.9528
# Epoch 15/50
# 12873/12873 [==============================] - 290s 23ms/step - loss: 0.1049 - accuracy: 0.9663 - val_loss: 0.1367 - val_accuracy: 0.9447
# Epoch 16/50
# 12873/12873 [==============================] - 292s 23ms/step - loss: 0.1058 - accuracy: 0.9665 - val_loss: 1.1084 - val_accuracy: 0.7311
# Epoch 17/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.1029 - accuracy: 0.9673 - val_loss: 0.0826 - val_accuracy: 0.9705
# Epoch 18/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.1039 - accuracy: 0.9674 - val_loss: 0.0571 - val_accuracy: 0.9840
# Epoch 19/50
# 12873/12873 [==============================] - 293s 23ms/step - loss: 0.1021 - accuracy: 0.9678 - val_loss: 0.0900 - val_accuracy: 0.9789
# Epoch 20/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.0996 - accuracy: 0.9686 - val_loss: 0.0421 - val_accuracy: 0.9912
# Epoch 21/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.0995 - accuracy: 0.9690 - val_loss: 0.2547 - val_accuracy: 0.8940
# Epoch 22/50
# 12873/12873 [==============================] - 292s 23ms/step - loss: 0.0964 - accuracy: 0.9698 - val_loss: 0.1289 - val_accuracy: 0.9566
# Epoch 23/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.0987 - accuracy: 0.9694 - val_loss: 0.0881 - val_accuracy: 0.9741
# Epoch 24/50
# 12873/12873 [==============================] - 290s 23ms/step - loss: 0.0999 - accuracy: 0.9689 - val_loss: 0.0719 - val_accuracy: 0.9769
# Epoch 25/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.0991 - accuracy: 0.9695 - val_loss: 0.6541 - val_accuracy: 0.8140
# Epoch 26/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.0962 - accuracy: 0.9707 - val_loss: 1.2743 - val_accuracy: 0.7209
# Epoch 27/50
# 12873/12873 [==============================] - 290s 23ms/step - loss: 0.0966 - accuracy: 0.9709 - val_loss: 2.0415 - val_accuracy: 0.6662
# Epoch 28/50
# 12873/12873 [==============================] - 292s 23ms/step - loss: 0.0940 - accuracy: 0.9721 - val_loss: 1.2502 - val_accuracy: 0.7613
# Epoch 29/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.1018 - accuracy: 0.9693 - val_loss: 2.6227 - val_accuracy: 0.6844
# Epoch 30/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.1044 - accuracy: 0.9695 - val_loss: 2.6105 - val_accuracy: 0.6486
# Epoch 31/50
# 12873/12873 [==============================] - 290s 23ms/step - loss: 0.0994 - accuracy: 0.9705 - val_loss: 1.5716 - val_accuracy: 0.7379
# Epoch 32/50
# 12873/12873 [==============================] - 289s 22ms/step - loss: 0.0967 - accuracy: 0.9712 - val_loss: 3.2539 - val_accuracy: 0.6479
# Epoch 33/50
# 12873/12873 [==============================] - 290s 23ms/step - loss: 0.0975 - accuracy: 0.9712 - val_loss: 1.4214 - val_accuracy: 0.7350
# Epoch 34/50
# 12873/12873 [==============================] - 290s 23ms/step - loss: 0.0922 - accuracy: 0.9729 - val_loss: 4.1123 - val_accuracy: 0.5942
# Epoch 35/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.0934 - accuracy: 0.9723 - val_loss: 3.7110 - val_accuracy: 0.6214
# Epoch 36/50
# 12873/12873 [==============================] - 289s 22ms/step - loss: 0.0960 - accuracy: 0.9723 - val_loss: 2.3492 - val_accuracy: 0.6950
# Epoch 37/50
# 12873/12873 [==============================] - 289s 22ms/step - loss: 0.0923 - accuracy: 0.9730 - val_loss: 3.2771 - val_accuracy: 0.6431
# Epoch 38/50
# 12873/12873 [==============================] - 289s 22ms/step - loss: 0.0946 - accuracy: 0.9723 - val_loss: 2.3106 - val_accuracy: 0.7306
# Epoch 39/50
# 12873/12873 [==============================] - 289s 22ms/step - loss: 0.0927 - accuracy: 0.9732 - val_loss: 4.5232 - val_accuracy: 0.6131
# Epoch 40/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.0940 - accuracy: 0.9728 - val_loss: 3.7513 - val_accuracy: 0.5994
# Epoch 41/50
# 12873/12873 [==============================] - 290s 23ms/step - loss: 0.0920 - accuracy: 0.9735 - val_loss: 3.8497 - val_accuracy: 0.6338
# Epoch 42/50
# 12873/12873 [==============================] - 289s 22ms/step - loss: 0.0978 - accuracy: 0.9712 - val_loss: 4.0350 - val_accuracy: 0.6100
# Epoch 43/50
# 12873/12873 [==============================] - 290s 23ms/step - loss: 0.0920 - accuracy: 0.9735 - val_loss: 3.8836 - val_accuracy: 0.5666
# Epoch 44/50
# 12873/12873 [==============================] - 288s 22ms/step - loss: 0.0963 - accuracy: 0.9729 - val_loss: 5.0156 - val_accuracy: 0.5509
# Epoch 45/50
# 12873/12873 [==============================] - 289s 22ms/step - loss: 0.0930 - accuracy: 0.9730 - val_loss: 2.0175 - val_accuracy: 0.7119
# Epoch 46/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.0905 - accuracy: 0.9742 - val_loss: 3.9746 - val_accuracy: 0.6394
# Epoch 47/50
# 12873/12873 [==============================] - 292s 23ms/step - loss: 0.0878 - accuracy: 0.9747 - val_loss: 5.0145 - val_accuracy: 0.6053
# Epoch 48/50
# 12873/12873 [==============================] - 290s 23ms/step - loss: 0.0863 - accuracy: 0.9754 - val_loss: 0.6125 - val_accuracy: 0.8801
# Epoch 49/50
# 12873/12873 [==============================] - 294s 23ms/step - loss: 0.0936 - accuracy: 0.9733 - val_loss: 5.3996 - val_accuracy: 0.5409
# Epoch 50/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.0927 - accuracy: 0.9735 - val_loss: 3.7799 - val_accuracy: 0.6330
# 5517/5517 [==============================] - 38s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 36s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 36s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 38s 7ms/step
# 5517/5517 [==============================] - 36s 7ms/step
# 5517/5517 [==============================] - 36s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 38s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 38s 7ms/step
# 5517/5517 [==============================] - 38s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 38s 7ms/step
# Epoch 1/50
# 12873/12873 [==============================] - 285s 22ms/step - loss: 0.2753 - accuracy: 0.8933 - val_loss: 0.1047 - val_accuracy: 0.9689
# Epoch 2/50
# 12873/12873 [==============================] - 283s 22ms/step - loss: 0.1583 - accuracy: 0.9450 - val_loss: 0.0704 - val_accuracy: 0.9774
# Epoch 3/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.1378 - accuracy: 0.9533 - val_loss: 0.0569 - val_accuracy: 0.9868
# Epoch 4/50
# 12873/12873 [==============================] - 299s 23ms/step - loss: 0.1232 - accuracy: 0.9590 - val_loss: 0.1621 - val_accuracy: 0.9445
# Epoch 5/50
# 12873/12873 [==============================] - 299s 23ms/step - loss: 0.1290 - accuracy: 0.9570 - val_loss: 0.0574 - val_accuracy: 0.9821
# Epoch 6/50
# 12873/12873 [==============================] - 288s 22ms/step - loss: 0.1219 - accuracy: 0.9597 - val_loss: 0.1756 - val_accuracy: 0.9406
# Epoch 7/50
# 12873/12873 [==============================] - 293s 23ms/step - loss: 0.1183 - accuracy: 0.9610 - val_loss: 0.0572 - val_accuracy: 0.9871
# Epoch 8/50
# 12873/12873 [==============================] - 293s 23ms/step - loss: 0.1230 - accuracy: 0.9592 - val_loss: 0.0545 - val_accuracy: 0.9827
# Epoch 9/50
# 12873/12873 [==============================] - 289s 22ms/step - loss: 0.1069 - accuracy: 0.9659 - val_loss: 0.7850 - val_accuracy: 0.7993
# Epoch 10/50
# 12873/12873 [==============================] - 289s 22ms/step - loss: 0.1104 - accuracy: 0.9656 - val_loss: 3.2317 - val_accuracy: 0.5887
# Epoch 11/50
# 12873/12873 [==============================] - 290s 23ms/step - loss: 0.1147 - accuracy: 0.9650 - val_loss: 2.5625 - val_accuracy: 0.6562
# Epoch 12/50
# 12873/12873 [==============================] - 288s 22ms/step - loss: 0.1059 - accuracy: 0.9677 - val_loss: 3.2116 - val_accuracy: 0.5939
# Epoch 13/50
# 12873/12873 [==============================] - 287s 22ms/step - loss: 0.1037 - accuracy: 0.9683 - val_loss: 3.8032 - val_accuracy: 0.5786
# Epoch 14/50
# 12873/12873 [==============================] - 286s 22ms/step - loss: 0.1020 - accuracy: 0.9693 - val_loss: 0.7964 - val_accuracy: 0.8060
# Epoch 15/50
# 12873/12873 [==============================] - 286s 22ms/step - loss: 0.1040 - accuracy: 0.9689 - val_loss: 3.4772 - val_accuracy: 0.6070
# Epoch 16/50
# 12873/12873 [==============================] - 286s 22ms/step - loss: 0.1010 - accuracy: 0.9698 - val_loss: 5.0431 - val_accuracy: 0.5599
# Epoch 17/50
# 12873/12873 [==============================] - 285s 22ms/step - loss: 0.1037 - accuracy: 0.9694 - val_loss: 4.2656 - val_accuracy: 0.5809
# Epoch 18/50
# 12873/12873 [==============================] - 285s 22ms/step - loss: 0.0984 - accuracy: 0.9704 - val_loss: 4.2231 - val_accuracy: 0.5882
# Epoch 19/50
# 12873/12873 [==============================] - 285s 22ms/step - loss: 0.0993 - accuracy: 0.9708 - val_loss: 5.0792 - val_accuracy: 0.5675
# Epoch 20/50
# 12873/12873 [==============================] - 285s 22ms/step - loss: 0.1004 - accuracy: 0.9701 - val_loss: 3.1803 - val_accuracy: 0.6444
# Epoch 21/50
# 12873/12873 [==============================] - 285s 22ms/step - loss: 0.0959 - accuracy: 0.9715 - val_loss: 4.2837 - val_accuracy: 0.6045
# Epoch 22/50
# 12873/12873 [==============================] - 285s 22ms/step - loss: 0.0947 - accuracy: 0.9720 - val_loss: 5.0299 - val_accuracy: 0.5784
# Epoch 23/50
# 12873/12873 [==============================] - 286s 22ms/step - loss: 0.0982 - accuracy: 0.9710 - val_loss: 2.5861 - val_accuracy: 0.6397
# Epoch 24/50
# 12873/12873 [==============================] - 290s 22ms/step - loss: 0.0988 - accuracy: 0.9714 - val_loss: 4.3617 - val_accuracy: 0.6047
# Epoch 25/50
# 12873/12873 [==============================] - 285s 22ms/step - loss: 0.1000 - accuracy: 0.9710 - val_loss: 4.6565 - val_accuracy: 0.5563
# Epoch 26/50
# 12873/12873 [==============================] - 288s 22ms/step - loss: 0.0909 - accuracy: 0.9735 - val_loss: 5.4052 - val_accuracy: 0.5656
# Epoch 27/50
# 12873/12873 [==============================] - 286s 22ms/step - loss: 0.0920 - accuracy: 0.9729 - val_loss: 3.6175 - val_accuracy: 0.6380
# Epoch 28/50
# 12873/12873 [==============================] - 285s 22ms/step - loss: 0.0892 - accuracy: 0.9740 - val_loss: 4.5323 - val_accuracy: 0.5872
# Epoch 29/50
# 12873/12873 [==============================] - 286s 22ms/step - loss: 0.0900 - accuracy: 0.9740 - val_loss: 3.1230 - val_accuracy: 0.6098
# Epoch 30/50
# 12873/12873 [==============================] - 285s 22ms/step - loss: 0.0892 - accuracy: 0.9743 - val_loss: 5.0223 - val_accuracy: 0.5695
# Epoch 31/50
# 12873/12873 [==============================] - 286s 22ms/step - loss: 0.0846 - accuracy: 0.9754 - val_loss: 5.6563 - val_accuracy: 0.5515
# Epoch 32/50
# 12873/12873 [==============================] - 286s 22ms/step - loss: 0.0850 - accuracy: 0.9756 - val_loss: 4.8434 - val_accuracy: 0.5578
# Epoch 33/50
# 12873/12873 [==============================] - 285s 22ms/step - loss: 0.0840 - accuracy: 0.9754 - val_loss: 4.7783 - val_accuracy: 0.5710
# Epoch 34/50
# 12873/12873 [==============================] - 285s 22ms/step - loss: 0.0820 - accuracy: 0.9765 - val_loss: 4.6756 - val_accuracy: 0.5679
# Epoch 35/50
# 12873/12873 [==============================] - 285s 22ms/step - loss: 0.0836 - accuracy: 0.9758 - val_loss: 3.7874 - val_accuracy: 0.5986
# Epoch 36/50
# 12873/12873 [==============================] - 287s 22ms/step - loss: 0.0809 - accuracy: 0.9765 - val_loss: 4.5542 - val_accuracy: 0.5743
# Epoch 37/50
# 12873/12873 [==============================] - 278s 22ms/step - loss: 0.0820 - accuracy: 0.9764 - val_loss: 4.6279 - val_accuracy: 0.5598
# Epoch 38/50
# 12873/12873 [==============================] - 278s 22ms/step - loss: 0.0824 - accuracy: 0.9762 - val_loss: 0.8473 - val_accuracy: 0.7399
# Epoch 39/50
# 12873/12873 [==============================] - 277s 22ms/step - loss: 0.0807 - accuracy: 0.9769 - val_loss: 4.7937 - val_accuracy: 0.5670
# Epoch 40/50
# 12873/12873 [==============================] - 302s 23ms/step - loss: 0.0811 - accuracy: 0.9763 - val_loss: 4.4219 - val_accuracy: 0.5655
# Epoch 41/50
# 12873/12873 [==============================] - 315s 25ms/step - loss: 0.0770 - accuracy: 0.9777 - val_loss: 3.8849 - val_accuracy: 0.5723
# Epoch 42/50
# 12873/12873 [==============================] - 283s 22ms/step - loss: 0.0781 - accuracy: 0.9773 - val_loss: 4.7415 - val_accuracy: 0.5272
# Epoch 43/50
# 12873/12873 [==============================] - 282s 22ms/step - loss: 0.0784 - accuracy: 0.9779 - val_loss: 4.5162 - val_accuracy: 0.5656
# Epoch 44/50
# 12873/12873 [==============================] - 281s 22ms/step - loss: 0.0816 - accuracy: 0.9770 - val_loss: 3.6785 - val_accuracy: 0.6079
# Epoch 45/50
# 12873/12873 [==============================] - 285s 22ms/step - loss: 0.0789 - accuracy: 0.9776 - val_loss: 5.0197 - val_accuracy: 0.5601
# Epoch 46/50
# 12873/12873 [==============================] - 285s 22ms/step - loss: 0.0793 - accuracy: 0.9774 - val_loss: 0.1009 - val_accuracy: 0.9758
# Epoch 47/50
# 12873/12873 [==============================] - 280s 22ms/step - loss: 0.0759 - accuracy: 0.9786 - val_loss: 3.4076 - val_accuracy: 0.6166
# Epoch 48/50
# 12873/12873 [==============================] - 275s 21ms/step - loss: 0.0754 - accuracy: 0.9784 - val_loss: 1.9594 - val_accuracy: 0.7258
# Epoch 49/50
# 12873/12873 [==============================] - 275s 21ms/step - loss: 0.0750 - accuracy: 0.9784 - val_loss: 3.9914 - val_accuracy: 0.5962
# Epoch 50/50
# 12873/12873 [==============================] - 275s 21ms/step - loss: 0.0767 - accuracy: 0.9784 - val_loss: 3.7930 - val_accuracy: 0.5807
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 36s 7ms/step
# 5517/5517 [==============================] - 36s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 36s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 36s 7ms/step
# 5517/5517 [==============================] - 36s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 36s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 36s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# 5517/5517 [==============================] - 37s 7ms/step
# Epoch 1/50
# 12873/12873 [==============================] - 275s 21ms/step - loss: 0.3064 - accuracy: 0.8766 - val_loss: 0.2931 - val_accuracy: 0.8938
# Epoch 2/50
# 12873/12873 [==============================] - 273s 21ms/step - loss: 0.1719 - accuracy: 0.9399 - val_loss: 0.1304 - val_accuracy: 0.9516
# Epoch 3/50
# 12873/12873 [==============================] - 274s 21ms/step - loss: 0.1500 - accuracy: 0.9487 - val_loss: 0.1411 - val_accuracy: 0.9474
# Epoch 4/50
# 12873/12873 [==============================] - 272s 21ms/step - loss: 0.1489 - accuracy: 0.9487 - val_loss: 0.1046 - val_accuracy: 0.9631
# Epoch 5/50
# 12873/12873 [==============================] - 273s 21ms/step - loss: 0.1455 - accuracy: 0.9502 - val_loss: 0.0683 - val_accuracy: 0.9809
# Epoch 6/50
# 12873/12873 [==============================] - 273s 21ms/step - loss: 0.1293 - accuracy: 0.9576 - val_loss: 0.0874 - val_accuracy: 0.9715
# Epoch 7/50
# 12873/12873 [==============================] - 275s 21ms/step - loss: 0.1587 - accuracy: 0.9448 - val_loss: 0.3790 - val_accuracy: 0.8906
# Epoch 8/50
# 12873/12873 [==============================] - 280s 22ms/step - loss: 0.1298 - accuracy: 0.9573 - val_loss: 0.0998 - val_accuracy: 0.9694
# Epoch 9/50
# 12873/12873 [==============================] - 280s 22ms/step - loss: 0.1297 - accuracy: 0.9579 - val_loss: 1.4217 - val_accuracy: 0.6676
# Epoch 10/50
# 12873/12873 [==============================] - 280s 22ms/step - loss: 0.1119 - accuracy: 0.9656 - val_loss: 2.2731 - val_accuracy: 0.6321
# Epoch 11/50
# 12873/12873 [==============================] - 281s 22ms/step - loss: 0.1070 - accuracy: 0.9678 - val_loss: 3.7172 - val_accuracy: 0.5729
# Epoch 12/50
# 12873/12873 [==============================] - 283s 22ms/step - loss: 0.1043 - accuracy: 0.9687 - val_loss: 3.1507 - val_accuracy: 0.6051
# Epoch 13/50
# 12873/12873 [==============================] - 283s 22ms/step - loss: 0.1094 - accuracy: 0.9678 - val_loss: 0.0638 - val_accuracy: 0.9877
# Epoch 14/50
# 12873/12873 [==============================] - 285s 22ms/step - loss: 0.1062 - accuracy: 0.9690 - val_loss: 3.4655 - val_accuracy: 0.6149
# Epoch 15/50
# 12873/12873 [==============================] - 286s 22ms/step - loss: 0.1062 - accuracy: 0.9687 - val_loss: 4.2328 - val_accuracy: 0.5797
# Epoch 16/50
# 12873/12873 [==============================] - 286s 22ms/step - loss: 0.1013 - accuracy: 0.9703 - val_loss: 4.4268 - val_accuracy: 0.5696
# Epoch 17/50
# 12873/12873 [==============================] - 287s 22ms/step - loss: 0.1076 - accuracy: 0.9689 - val_loss: 3.7326 - val_accuracy: 0.6071
# Epoch 18/50
# 12873/12873 [==============================] - 286s 22ms/step - loss: 0.0991 - accuracy: 0.9710 - val_loss: 4.2747 - val_accuracy: 0.5552
# Epoch 19/50
# 12873/12873 [==============================] - 287s 22ms/step - loss: 0.0986 - accuracy: 0.9710 - val_loss: 4.0509 - val_accuracy: 0.5794
# Epoch 20/50
# 12873/12873 [==============================] - 290s 23ms/step - loss: 0.0953 - accuracy: 0.9719 - val_loss: 4.5021 - val_accuracy: 0.5683
# Epoch 21/50
# 12873/12873 [==============================] - 291s 23ms/step - loss: 0.0963 - accuracy: 0.9721 - val_loss: 4.5282 - val_accuracy: 0.5754
# Epoch 22/50
# 12873/12873 [==============================] - 293s 23ms/step - loss: 0.0968 - accuracy: 0.9711 - val_loss: 3.6670 - val_accuracy: 0.5641
# Epoch 23/50
# 12873/12873 [==============================] - 294s 23ms/step - loss: 0.0997 - accuracy: 0.9714 - val_loss: 3.5410 - val_accuracy: 0.6282
# Epoch 24/50
# 12873/12873 [==============================] - 304s 24ms/step - loss: 0.0983 - accuracy: 0.9716 - val_loss: 4.1127 - val_accuracy: 0.5846
# Epoch 25/50
# 12873/12873 [==============================] - 298s 23ms/step - loss: 0.0943 - accuracy: 0.9725 - val_loss: 3.7968 - val_accuracy: 0.5880
# Epoch 26/50
# 12873/12873 [==============================] - 299s 23ms/step - loss: 0.0946 - accuracy: 0.9725 - val_loss: 3.5950 - val_accuracy: 0.6194
# Epoch 27/50
# 12873/12873 [==============================] - 302s 23ms/step - loss: 0.0929 - accuracy: 0.9727 - val_loss: 3.8166 - val_accuracy: 0.5903
# Epoch 28/50
# 12873/12873 [==============================] - 303s 24ms/step - loss: 0.0888 - accuracy: 0.9741 - val_loss: 3.4181 - val_accuracy: 0.5977
# Epoch 29/50
# 12873/12873 [==============================] - 304s 24ms/step - loss: 0.0941 - accuracy: 0.9725 - val_loss: 4.2031 - val_accuracy: 0.5628
# Epoch 30/50
# 12873/12873 [==============================] - 306s 24ms/step - loss: 0.0914 - accuracy: 0.9731 - val_loss: 3.8263 - val_accuracy: 0.5788
# Epoch 31/50
# 12873/12873 [==============================] - 306s 24ms/step - loss: 0.0933 - accuracy: 0.9730 - val_loss: 3.8681 - val_accuracy: 0.5503
# Epoch 32/50
# 12873/12873 [==============================] - 311s 24ms/step - loss: 0.0910 - accuracy: 0.9737 - val_loss: 3.3643 - val_accuracy: 0.5749
# Epoch 33/50
# 12873/12873 [==============================] - 313s 24ms/step - loss: 0.0863 - accuracy: 0.9745 - val_loss: 3.1785 - val_accuracy: 0.6073
# Epoch 34/50
# 12873/12873 [==============================] - 316s 25ms/step - loss: 0.0836 - accuracy: 0.9755 - val_loss: 3.4897 - val_accuracy: 0.5919
# Epoch 35/50
# 12873/12873 [==============================] - 318s 25ms/step - loss: 0.0872 - accuracy: 0.9747 - val_loss: 2.9067 - val_accuracy: 0.6011
# Epoch 36/50
# 12873/12873 [==============================] - 317s 25ms/step - loss: 0.0852 - accuracy: 0.9754 - val_loss: 3.1739 - val_accuracy: 0.5364
# Epoch 37/50
# 12873/12873 [==============================] - 321s 25ms/step - loss: 0.0839 - accuracy: 0.9755 - val_loss: 3.5192 - val_accuracy: 0.5745
# Epoch 38/50
# 12873/12873 [==============================] - 315s 24ms/step - loss: 0.0828 - accuracy: 0.9758 - val_loss: 3.0780 - val_accuracy: 0.6047
# Epoch 39/50
# 12873/12873 [==============================] - 315s 24ms/step - loss: 0.0891 - accuracy: 0.9741 - val_loss: 4.2701 - val_accuracy: 0.5798
# Epoch 40/50
# 12873/12873 [==============================] - 317s 25ms/step - loss: 0.0864 - accuracy: 0.9742 - val_loss: 1.8092 - val_accuracy: 0.6817
# Epoch 41/50
# 12873/12873 [==============================] - 319s 25ms/step - loss: 0.0840 - accuracy: 0.9747 - val_loss: 3.5061 - val_accuracy: 0.5995
# Epoch 42/50
# 12873/12873 [==============================] - 317s 25ms/step - loss: 0.0819 - accuracy: 0.9760 - val_loss: 3.2547 - val_accuracy: 0.6043
# Epoch 43/50
# 12873/12873 [==============================] - 316s 25ms/step - loss: 0.0819 - accuracy: 0.9757 - val_loss: 2.5144 - val_accuracy: 0.6367
# Epoch 44/50
# 12873/12873 [==============================] - 318s 25ms/step - loss: 0.0828 - accuracy: 0.9757 - val_loss: 3.6190 - val_accuracy: 0.5745
# Epoch 45/50
# 12873/12873 [==============================] - 319s 25ms/step - loss: 0.0832 - accuracy: 0.9753 - val_loss: 2.6819 - val_accuracy: 0.6247
# Epoch 46/50
# 12873/12873 [==============================] - 320s 25ms/step - loss: 0.0791 - accuracy: 0.9765 - val_loss: 3.2831 - val_accuracy: 0.5824
# Epoch 47/50
# 12873/12873 [==============================] - 319s 25ms/step - loss: 0.0885 - accuracy: 0.9737 - val_loss: 2.1936 - val_accuracy: 0.6512
# Epoch 48/50
# 12873/12873 [==============================] - 321s 25ms/step - loss: 0.0904 - accuracy: 0.9731 - val_loss: 2.6463 - val_accuracy: 0.6667
# Epoch 49/50
# 12873/12873 [==============================] - 322s 25ms/step - loss: 0.0917 - accuracy: 0.9731 - val_loss: 3.5517 - val_accuracy: 0.6374
# Epoch 50/50
# 12873/12873 [==============================] - 322s 25ms/step - loss: 0.0920 - accuracy: 0.9728 - val_loss: 3.7383 - val_accuracy: 0.6012
# 5517/5517 [==============================] - 44s 8ms/step
# 5517/5517 [==============================] - 43s 8ms/step
# 5517/5517 [==============================] - 43s 8ms/step
# 5517/5517 [==============================] - 43s 8ms/step
# 5517/5517 [==============================] - 43s 8ms/step
# 5517/5517 [==============================] - 43s 8ms/step
# 5517/5517 [==============================] - 43s 8ms/step
# 5517/5517 [==============================] - 43s 8ms/step
# 5517/5517 [==============================] - 43s 8ms/step
# 5517/5517 [==============================] - 43s 8ms/step
# 5517/5517 [==============================] - 43s 8ms/step
# 5517/5517 [==============================] - 43s 8ms/step
# 5517/5517 [==============================] - 44s 8ms/step
# 5517/5517 [==============================] - 44s 8ms/step
# 5517/5517 [==============================] - 43s 8ms/step
# 5517/5517 [==============================] - 44s 8ms/step
# 5517/5517 [==============================] - 43s 8ms/step
# 5517/5517 [==============================] - 42s 8ms/step
# 5517/5517 [==============================] - 43s 8ms/step
# 5517/5517 [==============================] - 43s 8ms/step
# Epoch 1/50
# 12873/12873 [==============================] - 335s 26ms/step - loss: 0.2978 - accuracy: 0.8808 - val_loss: 0.1769 - val_accuracy: 0.9435
# Epoch 2/50
# 12873/12873 [==============================] - 325s 25ms/step - loss: 0.1740 - accuracy: 0.9389 - val_loss: 0.1180 - val_accuracy: 0.9653
# Epoch 3/50
# 12873/12873 [==============================] - 323s 25ms/step - loss: 0.1441 - accuracy: 0.9508 - val_loss: 0.1000 - val_accuracy: 0.9691
# Epoch 4/50
# 12873/12873 [==============================] - 325s 25ms/step - loss: 0.1337 - accuracy: 0.9551 - val_loss: 0.1898 - val_accuracy: 0.9333
# Epoch 5/50
# 12873/12873 [==============================] - 325s 25ms/step - loss: 0.1263 - accuracy: 0.9583 - val_loss: 0.1126 - val_accuracy: 0.9672
# Epoch 6/50
# 12873/12873 [==============================] - 324s 25ms/step - loss: 0.1274 - accuracy: 0.9574 - val_loss: 0.3314 - val_accuracy: 0.8922
# Epoch 7/50
# 12873/12873 [==============================] - 326s 25ms/step - loss: 0.1262 - accuracy: 0.9586 - val_loss: 0.2573 - val_accuracy: 0.9106
# Epoch 8/50
# 12873/12873 [==============================] - 328s 25ms/step - loss: 0.1220 - accuracy: 0.9603 - val_loss: 0.3840 - val_accuracy: 0.9133
# Epoch 9/50
# 12873/12873 [==============================] - 328s 25ms/step - loss: 0.1192 - accuracy: 0.9611 - val_loss: 0.4369 - val_accuracy: 0.8839
# Epoch 10/50
# 12873/12873 [==============================] - 335s 26ms/step - loss: 0.1208 - accuracy: 0.9613 - val_loss: 0.1623 - val_accuracy: 0.9477
# Epoch 11/50
# 12873/12873 [==============================] - 330s 26ms/step - loss: 0.1121 - accuracy: 0.9641 - val_loss: 0.5684 - val_accuracy: 0.8397
# Epoch 12/50
# 12873/12873 [==============================] - 330s 26ms/step - loss: 0.1142 - accuracy: 0.9638 - val_loss: 0.8016 - val_accuracy: 0.8714
# Epoch 13/50
# 12873/12873 [==============================] - 330s 26ms/step - loss: 0.1137 - accuracy: 0.9634 - val_loss: 0.3988 - val_accuracy: 0.8765
# Epoch 14/50
# 12873/12873 [==============================] - 332s 26ms/step - loss: 0.1137 - accuracy: 0.9639 - val_loss: 0.6843 - val_accuracy: 0.8672
# Epoch 15/50
# 12873/12873 [==============================] - 332s 26ms/step - loss: 0.1118 - accuracy: 0.9647 - val_loss: 0.8739 - val_accuracy: 0.8389
# Epoch 16/50
# 12873/12873 [==============================] - 334s 26ms/step - loss: 0.1129 - accuracy: 0.9644 - val_loss: 0.6085 - val_accuracy: 0.8766
# Epoch 17/50
# 12873/12873 [==============================] - 334s 26ms/step - loss: 0.1091 - accuracy: 0.9653 - val_loss: 1.1829 - val_accuracy: 0.8304
# Epoch 18/50
# 12873/12873 [==============================] - 335s 26ms/step - loss: 0.1054 - accuracy: 0.9667 - val_loss: 0.6385 - val_accuracy: 0.8217
# Epoch 19/50
# 12873/12873 [==============================] - 336s 26ms/step - loss: 0.1080 - accuracy: 0.9659 - val_loss: 0.3341 - val_accuracy: 0.8727
# Epoch 20/50
# 12873/12873 [==============================] - 338s 26ms/step - loss: 0.1063 - accuracy: 0.9663 - val_loss: 0.7730 - val_accuracy: 0.8496
# Epoch 21/50
# 12873/12873 [==============================] - 337s 26ms/step - loss: 0.1044 - accuracy: 0.9673 - val_loss: 1.0802 - val_accuracy: 0.8307
# Epoch 22/50
# 12873/12873 [==============================] - 340s 26ms/step - loss: 0.1025 - accuracy: 0.9675 - val_loss: 0.9536 - val_accuracy: 0.8324
# Epoch 23/50
# 12873/12873 [==============================] - 343s 27ms/step - loss: 0.1030 - accuracy: 0.9676 - val_loss: 0.5094 - val_accuracy: 0.8319
# Epoch 24/50
# 12873/12873 [==============================] - 345s 27ms/step - loss: 0.0984 - accuracy: 0.9690 - val_loss: 1.0093 - val_accuracy: 0.8292
# Epoch 25/50
# 12873/12873 [==============================] - 347s 27ms/step - loss: 0.0960 - accuracy: 0.9698 - val_loss: 1.0228 - val_accuracy: 0.8375
# Epoch 26/50
# 12873/12873 [==============================] - 347s 27ms/step - loss: 0.0947 - accuracy: 0.9700 - val_loss: 0.3748 - val_accuracy: 0.8502
# Epoch 27/50
# 12873/12873 [==============================] - 346s 27ms/step - loss: 0.0987 - accuracy: 0.9692 - val_loss: 0.5673 - val_accuracy: 0.8711
# Epoch 28/50
# 12873/12873 [==============================] - 349s 27ms/step - loss: 0.0984 - accuracy: 0.9694 - val_loss: 0.8056 - val_accuracy: 0.8362
# Epoch 29/50
# 12873/12873 [==============================] - 348s 27ms/step - loss: 0.0955 - accuracy: 0.9699 - val_loss: 1.0326 - val_accuracy: 0.8216
# Epoch 30/50
# 12873/12873 [==============================] - 350s 27ms/step - loss: 0.0944 - accuracy: 0.9705 - val_loss: 0.8209 - val_accuracy: 0.8338
# Epoch 31/50
# 12873/12873 [==============================] - 351s 27ms/step - loss: 0.0924 - accuracy: 0.9711 - val_loss: 0.0656 - val_accuracy: 0.9782
# Epoch 32/50
# 12873/12873 [==============================] - 352s 27ms/step - loss: 0.0889 - accuracy: 0.9723 - val_loss: 1.2358 - val_accuracy: 0.8385
# Epoch 33/50
# 12873/12873 [==============================] - 351s 27ms/step - loss: 0.0887 - accuracy: 0.9720 - val_loss: 0.8610 - val_accuracy: 0.7773
# Epoch 34/50
# 12873/12873 [==============================] - 354s 28ms/step - loss: 0.0882 - accuracy: 0.9728 - val_loss: 0.9254 - val_accuracy: 0.8349
# Epoch 35/50
# 12873/12873 [==============================] - 356s 28ms/step - loss: 0.0860 - accuracy: 0.9734 - val_loss: 0.5769 - val_accuracy: 0.8558
# Epoch 36/50
# 12873/12873 [==============================] - 355s 28ms/step - loss: 0.0876 - accuracy: 0.9727 - val_loss: 0.6361 - val_accuracy: 0.8565
# Epoch 37/50
# 12873/12873 [==============================] - 358s 28ms/step - loss: 0.0862 - accuracy: 0.9736 - val_loss: 1.4570 - val_accuracy: 0.8230
# Epoch 38/50
# 12873/12873 [==============================] - 358s 28ms/step - loss: 0.0855 - accuracy: 0.9738 - val_loss: 1.3901 - val_accuracy: 0.8073
# Epoch 39/50
# 12873/12873 [==============================] - 360s 28ms/step - loss: 0.0864 - accuracy: 0.9738 - val_loss: 0.5770 - val_accuracy: 0.8356
# Epoch 40/50
# 12873/12873 [==============================] - 361s 28ms/step - loss: 0.0917 - accuracy: 0.9725 - val_loss: 1.3876 - val_accuracy: 0.8261
# Epoch 41/50
# 12873/12873 [==============================] - 361s 28ms/step - loss: 0.0879 - accuracy: 0.9735 - val_loss: 1.0662 - val_accuracy: 0.7933
# Epoch 42/50
# 12873/12873 [==============================] - 363s 28ms/step - loss: 0.0876 - accuracy: 0.9739 - val_loss: 3.1114 - val_accuracy: 0.5225
# Epoch 43/50
# 12873/12873 [==============================] - 363s 28ms/step - loss: 0.0840 - accuracy: 0.9746 - val_loss: 2.6993 - val_accuracy: 0.5688
# Epoch 44/50
# 12873/12873 [==============================] - 366s 28ms/step - loss: 0.0857 - accuracy: 0.9749 - val_loss: 2.2305 - val_accuracy: 0.6273
# Epoch 45/50
# 12873/12873 [==============================] - 367s 29ms/step - loss: 0.0895 - accuracy: 0.9734 - val_loss: 3.2439 - val_accuracy: 0.5373
# Epoch 46/50
# 12873/12873 [==============================] - 367s 29ms/step - loss: 0.0876 - accuracy: 0.9740 - val_loss: 2.8298 - val_accuracy: 0.5712
# Epoch 47/50
# 12873/12873 [==============================] - 368s 29ms/step - loss: 0.0847 - accuracy: 0.9752 - val_loss: 3.4824 - val_accuracy: 0.5629
# Epoch 48/50
# 12873/12873 [==============================] - 367s 29ms/step - loss: 0.0922 - accuracy: 0.9727 - val_loss: 1.6469 - val_accuracy: 0.6886
# Epoch 49/50
# 12873/12873 [==============================] - 368s 29ms/step - loss: 0.0839 - accuracy: 0.9755 - val_loss: 3.6359 - val_accuracy: 0.4979
# Epoch 50/50
# 12873/12873 [==============================] - 369s 29ms/step - loss: 0.0833 - accuracy: 0.9757 - val_loss: 3.1427 - val_accuracy: 0.6094
# 5517/5517 [==============================] - 49s 9ms/step
# 5517/5517 [==============================] - 49s 9ms/step
# 5517/5517 [==============================] - 48s 9ms/step
# 5517/5517 [==============================] - 49s 9ms/step
# 5517/5517 [==============================] - 49s 9ms/step
# 5517/5517 [==============================] - 49s 9ms/step
# 5517/5517 [==============================] - 50s 9ms/step
# 5517/5517 [==============================] - 48s 9ms/step
# 5517/5517 [==============================] - 49s 9ms/step
# 5517/5517 [==============================] - 49s 9ms/step
# 5517/5517 [==============================] - 49s 9ms/step
# 5517/5517 [==============================] - 49s 9ms/step
# 5517/5517 [==============================] - 49s 9ms/step
# 5517/5517 [==============================] - 50s 9ms/step
# 5517/5517 [==============================] - 48s 9ms/step
# 5517/5517 [==============================] - 50s 9ms/step
# 5517/5517 [==============================] - 49s 9ms/step
# 5517/5517 [==============================] - 49s 9ms/step
# 5517/5517 [==============================] - 50s 9ms/step
# 5517/5517 [==============================] - 49s 9ms/step
# Epoch 1/50
# 12873/12873 [==============================] - 374s 29ms/step - loss: 0.2795 - accuracy: 0.8909 - val_loss: 0.2940 - val_accuracy: 0.8715
# Epoch 2/50
# 12873/12873 [==============================] - 378s 29ms/step - loss: 0.1675 - accuracy: 0.9418 - val_loss: 0.0979 - val_accuracy: 0.9603
# Epoch 3/50
# 12873/12873 [==============================] - 376s 29ms/step - loss: 0.1416 - accuracy: 0.9520 - val_loss: 0.1585 - val_accuracy: 0.9403
# Epoch 4/50
# 12873/12873 [==============================] - 378s 29ms/step - loss: 0.1325 - accuracy: 0.9554 - val_loss: 1.3066 - val_accuracy: 0.7166
# Epoch 5/50
# 12873/12873 [==============================] - 377s 29ms/step - loss: 0.1270 - accuracy: 0.9575 - val_loss: 0.2626 - val_accuracy: 0.8994
# Epoch 6/50
# 12873/12873 [==============================] - 379s 29ms/step - loss: 0.1225 - accuracy: 0.9594 - val_loss: 0.0835 - val_accuracy: 0.9775
# Epoch 7/50
# 12873/12873 [==============================] - 381s 30ms/step - loss: 0.1194 - accuracy: 0.9605 - val_loss: 1.0540 - val_accuracy: 0.7222
# Epoch 8/50
# 12873/12873 [==============================] - 382s 30ms/step - loss: 0.1188 - accuracy: 0.9607 - val_loss: 0.9554 - val_accuracy: 0.7571
# Epoch 9/50
# 12873/12873 [==============================] - 392s 30ms/step - loss: 0.1165 - accuracy: 0.9625 - val_loss: 2.4483 - val_accuracy: 0.6171
# Epoch 10/50
# 12873/12873 [==============================] - 424s 33ms/step - loss: 0.1132 - accuracy: 0.9638 - val_loss: 3.5184 - val_accuracy: 0.5821
# Epoch 11/50
# 12873/12873 [==============================] - 404s 31ms/step - loss: 0.1075 - accuracy: 0.9659 - val_loss: 4.8166 - val_accuracy: 0.5520
# Epoch 12/50
# 12873/12873 [==============================] - 407s 32ms/step - loss: 0.1039 - accuracy: 0.9675 - val_loss: 3.7807 - val_accuracy: 0.5893
# Epoch 13/50
# 12873/12873 [==============================] - 414s 32ms/step - loss: 0.1029 - accuracy: 0.9680 - val_loss: 3.4765 - val_accuracy: 0.6192
# Epoch 14/50
# 12873/12873 [==============================] - 408s 32ms/step - loss: 0.0994 - accuracy: 0.9697 - val_loss: 3.2561 - val_accuracy: 0.6026
# Epoch 15/50
# 12873/12873 [==============================] - 392s 30ms/step - loss: 0.0993 - accuracy: 0.9697 - val_loss: 3.1833 - val_accuracy: 0.6433
# Epoch 16/50
# 12873/12873 [==============================] - 391s 30ms/step - loss: 0.0982 - accuracy: 0.9701 - val_loss: 2.6899 - val_accuracy: 0.6425
# Epoch 17/50
# 12873/12873 [==============================] - 392s 30ms/step - loss: 0.0909 - accuracy: 0.9725 - val_loss: 1.1119 - val_accuracy: 0.8056
# Epoch 18/50
# 12873/12873 [==============================] - 394s 31ms/step - loss: 0.0901 - accuracy: 0.9726 - val_loss: 1.4158 - val_accuracy: 0.7404
# Epoch 19/50
# 12873/12873 [==============================] - 417s 32ms/step - loss: 0.0895 - accuracy: 0.9731 - val_loss: 2.5291 - val_accuracy: 0.6453
# Epoch 20/50
# 12873/12873 [==============================] - 415s 32ms/step - loss: 0.0865 - accuracy: 0.9743 - val_loss: 3.2672 - val_accuracy: 0.6228
# Epoch 21/50
# 12873/12873 [==============================] - 419s 33ms/step - loss: 0.0836 - accuracy: 0.9751 - val_loss: 1.8585 - val_accuracy: 0.6601
# Epoch 22/50
# 12873/12873 [==============================] - 413s 32ms/step - loss: 0.0855 - accuracy: 0.9745 - val_loss: 3.6819 - val_accuracy: 0.5957
# Epoch 23/50
# 12873/12873 [==============================] - 407s 32ms/step - loss: 0.0862 - accuracy: 0.9744 - val_loss: 0.8620 - val_accuracy: 0.7880
# Epoch 24/50
# 12873/12873 [==============================] - 397s 31ms/step - loss: 0.0781 - accuracy: 0.9766 - val_loss: 1.5838 - val_accuracy: 0.6975
# Epoch 25/50
# 12873/12873 [==============================] - 406s 32ms/step - loss: 0.0821 - accuracy: 0.9759 - val_loss: 2.9982 - val_accuracy: 0.6208
# Epoch 26/50
# 12873/12873 [==============================] - 418s 32ms/step - loss: 0.0828 - accuracy: 0.9761 - val_loss: 2.8922 - val_accuracy: 0.6144
# Epoch 27/50
# 12873/12873 [==============================] - 410s 32ms/step - loss: 0.0797 - accuracy: 0.9765 - val_loss: 1.8528 - val_accuracy: 0.7178
# Epoch 28/50
# 12873/12873 [==============================] - 409s 32ms/step - loss: 0.0763 - accuracy: 0.9775 - val_loss: 3.6463 - val_accuracy: 0.5764
# Epoch 29/50
# 12873/12873 [==============================] - 412s 32ms/step - loss: 0.0806 - accuracy: 0.9764 - val_loss: 0.0865 - val_accuracy: 0.9753
# Epoch 30/50
# 12873/12873 [==============================] - 408s 32ms/step - loss: 0.0782 - accuracy: 0.9769 - val_loss: 2.1082 - val_accuracy: 0.6528
# Epoch 31/50
# 12873/12873 [==============================] - 419s 33ms/step - loss: 0.0754 - accuracy: 0.9780 - val_loss: 3.4040 - val_accuracy: 0.6339
# Epoch 32/50
# 12873/12873 [==============================] - 416s 32ms/step - loss: 0.0787 - accuracy: 0.9771 - val_loss: 0.6333 - val_accuracy: 0.8111
# Epoch 33/50
# 12873/12873 [==============================] - 439s 34ms/step - loss: 0.0739 - accuracy: 0.9784 - val_loss: 3.5280 - val_accuracy: 0.6170
# Epoch 34/50
# 12873/12873 [==============================] - 422s 33ms/step - loss: 0.0735 - accuracy: 0.9788 - val_loss: 2.1535 - val_accuracy: 0.7081
# Epoch 35/50
# 12873/12873 [==============================] - 413s 32ms/step - loss: 0.0751 - accuracy: 0.9783 - val_loss: 0.0595 - val_accuracy: 0.9922
# Epoch 36/50
# 12873/12873 [==============================] - 418s 32ms/step - loss: 0.0751 - accuracy: 0.9781 - val_loss: 0.1098 - val_accuracy: 0.9695
# Epoch 37/50
# 12873/12873 [==============================] - 434s 34ms/step - loss: 0.0708 - accuracy: 0.9793 - val_loss: 2.1275 - val_accuracy: 0.6643
# Epoch 38/50
# 12873/12873 [==============================] - 427s 33ms/step - loss: 0.0736 - accuracy: 0.9787 - val_loss: 3.1330 - val_accuracy: 0.6179
# Epoch 39/50
# 12873/12873 [==============================] - 423s 33ms/step - loss: 0.0703 - accuracy: 0.9796 - val_loss: 1.8277 - val_accuracy: 0.6774
# Epoch 40/50
# 12873/12873 [==============================] - 416s 32ms/step - loss: 0.0705 - accuracy: 0.9796 - val_loss: 2.7520 - val_accuracy: 0.6624
# Epoch 41/50
# 12873/12873 [==============================] - 426s 33ms/step - loss: 0.0710 - accuracy: 0.9794 - val_loss: 3.2696 - val_accuracy: 0.6349
# Epoch 42/50
# 12873/12873 [==============================] - 430s 33ms/step - loss: 0.0705 - accuracy: 0.9798 - val_loss: 3.2288 - val_accuracy: 0.6233
# Epoch 43/50
# 12873/12873 [==============================] - 449s 35ms/step - loss: 0.0687 - accuracy: 0.9799 - val_loss: 3.1269 - val_accuracy: 0.6010
# Epoch 44/50
# 12873/12873 [==============================] - 460s 36ms/step - loss: 0.0675 - accuracy: 0.9805 - val_loss: 2.1055 - val_accuracy: 0.7098
# Epoch 45/50
# 12873/12873 [==============================] - 435s 34ms/step - loss: 0.0696 - accuracy: 0.9797 - val_loss: 2.8613 - val_accuracy: 0.6609
# Epoch 46/50
# 12873/12873 [==============================] - 438s 34ms/step - loss: 0.0685 - accuracy: 0.9804 - val_loss: 3.4319 - val_accuracy: 0.6039
# Epoch 47/50
# 12873/12873 [==============================] - 415s 32ms/step - loss: 0.0692 - accuracy: 0.9804 - val_loss: 2.1440 - val_accuracy: 0.5950
# Epoch 48/50
# 12873/12873 [==============================] - 416s 32ms/step - loss: 0.0671 - accuracy: 0.9807 - val_loss: 3.1463 - val_accuracy: 0.6307
# Epoch 49/50
# 12873/12873 [==============================] - 427s 33ms/step - loss: 0.0679 - accuracy: 0.9805 - val_loss: 3.6899 - val_accuracy: 0.5505
# Epoch 50/50
# 12873/12873 [==============================] - 449s 35ms/step - loss: 0.0669 - accuracy: 0.9805 - val_loss: 2.7827 - val_accuracy: 0.6804
# 5517/5517 [==============================] - 59s 11ms/step
# 5517/5517 [==============================] - 62s 11ms/step
# 5517/5517 [==============================] - 62s 11ms/step
# 5517/5517 [==============================] - 63s 11ms/step
# 5517/5517 [==============================] - 60s 11ms/step
# 5517/5517 [==============================] - 59s 11ms/step
# 5517/5517 [==============================] - 57s 10ms/step
# 5517/5517 [==============================] - 58s 11ms/step
# 5517/5517 [==============================] - 56s 10ms/step
# 5517/5517 [==============================] - 57s 10ms/step
# 5517/5517 [==============================] - 57s 10ms/step
# 5517/5517 [==============================] - 56s 10ms/step
# 5517/5517 [==============================] - 56s 10ms/step
# 5517/5517 [==============================] - 56s 10ms/step
# 5517/5517 [==============================] - 56s 10ms/step
# 5517/5517 [==============================] - 55s 10ms/step
# 5517/5517 [==============================] - 55s 10ms/step
# 5517/5517 [==============================] - 61s 11ms/step
# 5517/5517 [==============================] - 62s 11ms/step
# 5517/5517 [==============================] - 59s 11ms/step
#
# Best Average Accuracy:
# 0.6807615400737522
# 5517/5517 [==============================] - 59s 11ms/step
# 5517/5517 [==============================] - 62s 11ms/step
#
# Confusion Matrix:
# [[58127   219    19]
#  [  174 32256     1]
#  [56150    34 29557]]
#
# Accuracy: 0.6794043175085109
#
# Precision: 0.8331393573101716
#
# Recall: 0.7784167898704464
#
# F1 Score: 0.7262435005253421
# ROC AUC score: 0.9377079923821242

# %% [markdown]
# ### Mapping alteration zones

# %%
pred_features_chips = features_chips
dsPred = dsFeatures

# predict and export the probability raster
pred = best_model.predict(pred_features_chips)
pred_array = np.reshape(pred.argmax(axis=1), (dsPred.RasterYSize, dsPred.RasterXSize))

fig, ax = plt.subplots(figsize=(10, 10))
ax.set_xlim(min_x, max_x)
ax.set_ylim(min_y, max_y)
cx.add_basemap(ax, crs='EPSG:32754', source=cx.providers.Esri.WorldShadedRelief)
ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
plt.yticks(rotation=90, va='center')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.f'))
cmap = mpl.colors.ListedColormap(['blue', 'green'])

pred_array_copy = pred_array.copy()
pred_array_copy = pred_array_copy.astype('float')
pred_array_copy[pred_array_copy==0] = np.nan
image = plt.imshow(pred_array_copy, cmap=cmap, extent=extent, interpolation='nearest')

divider = make_axes_locatable(ax)
cax = divider.new_vertical(size='5%', pad=0.5, pack_start=True)
fig.add_axes(cax)
cbar = plt.colorbar(image, orientation='horizontal', label='Alteration Type', cax=cax)
tick_locs = (np.arange(n_class_pos-1) + 2.5)*(n_class_pos-2)/(n_class_pos-1)
cbar.set_ticks(tick_locs)
cbar.set_ticklabels(['Argillic', 'Propylitic'])
plt.grid(False)

outFile = './Outputs/BrokenHill_ASTER_PCA_CNN_AlterationMap_ks_5.tif'
raster.export(pred_array, dsPred, filename=outFile, dtype='float')
# Out:
# 367904/367904 [==============================] - 3614s 10ms/step

# %%
pred_manual = pred.argmax(axis=1)[arrPositiveLabels_manual_flat!=0]
aScore = accuracy_score(positiveLabels_manual, pred_manual)
print(f'Accuracy based on ground truth data: {aScore}')
# Out:
# Accuracy based on ground truth data: 0.8834975369458128
